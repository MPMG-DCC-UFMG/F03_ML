# %%
import pandas as pd
import numpy as np
from item.item_list import (
    ItemList,
    Item
)
from item.clustering.utils import (
    load_clustering_results_pickle,
    load_clustering_results
)
from collections import defaultdict
import re

# %%
results, outliers = load_clustering_results_pickle('../data/output/druid_fasttext/')

itemlist = ItemList()
itemlist.load_items_from_file('../data/output/druid_fasttext/f03_items.csv.zip')
items_df = itemlist.items_df

groups_df = pd.read_csv('../data/output/druid_fasttext/clusters.csv.zip', sep=';')

# %%
# Adiciona a informação de grupo e ruído no dataframe de itens
items_df = items_df.merge(groups_df, left_on='item_id', right_on='item_id')

# Exclui grupos de ruídos e grupos não particionados
items_df = items_df[(~items_df['grupo'].str.contains('_')) & (~items_df['grupo'].str.contains('-1'))]
items_df['original_desc'] = items_df['original_prep'].apply(lambda x: ' '.join(eval(x)))
items_df.set_index('grupo', inplace=True)

# Quantidade de descrições por grupo
groups_count_df = items_df.groupby('grupo').count().sort_values('item_id', ascending=False)['original_desc']
print(f'Quantidade de grupos considerados: {len(groups_count_df)}')
# Out:
# Quantidade de grupos considerados: 33121

# %%
items_df.head()
# Out:
#                                                    palavras unidades_medida  \
# grupo
# xyloproct                              ['xyloproct', 'pom']          ['gr']
# promestrieno           ['promestrieno', 'creme', 'vaginal']              []
# naloxone                                       ['naloxone']    ['mg', 'ml']
# ete           ['ete', 'para', 'pessoa', 'jose', 'limoeiro']              []
# zincar                                 ['zincar', 'sinapi']              []
#
#                  numeros cores materiais tamanho quantidade       preco  \
# grupo
# xyloproct         ['25']    []        []      []         []     28.0600
# promestrieno          []    []        []      []         []     66.3267
# naloxone      ['0', '4']    []        []      []         []     13.2500
# ete              ['240']    []        []      []         []  79194.2500
# zincar        ['2', '4']    []        []      []  ['caixa']      5.4300
#
#              dsc_unidade_medida  \
# grupo
# xyloproct                  tubo
# promestrieno            unidade
# naloxone       unidade 1 ampola
# ete                     unidade
# zincar                  unidade
#
#                                                      original  licitacao  \
# grupo
# xyloproct                                XILOPROCT POM. 25 GR     297301
# promestrieno                       PROMESTRIENO CREME VAGINAL     301754
# naloxone                                   NALOXONE, 0,4MG/ML      32000
# ete           ETE PARA ATE 240 PESSOAS - SAO JOSE DO LIMOEIRO       2285
# zincar                       CAIXA ZINCADA 2X4 - SINAPI 83387      33269
#
#                                                   original_prep   ano  \
# grupo
# xyloproct                      ['xyloproct', 'pom', '25', 'gr']  2014
# promestrieno               ['promestrieno', 'creme', 'vaginal']  2014
# naloxone                     ['naloxone', '0', '4', 'mg', 'ml']  2014
# ete           ['ete', 'para', '240', 'pessoa', 'jose', 'limo...  2014
# zincar             ['caixa', 'zincar', '2', 'x', '4', 'sinapi']  2014
#
#               item_id  grupo_ruido  item_ruido  \
# grupo
# xyloproct          54            1           1
# promestrieno       92            1           1
# naloxone          101            1           1
# ete               142            1           1
# zincar            146            1           1
#
#                                   original_desc
# grupo
# xyloproct                   xyloproct pom 25 gr
# promestrieno         promestrieno creme vaginal
# naloxone                     naloxone 0 4 mg ml
# ete           ete para 240 pessoa jose limoeiro
# zincar                caixa zincar 2 x 4 sinapi

# %%
def extract_descriptions(group, groups_dict, desc_column):
    if type(desc_column) == str:
        descriptions = {desc_column: 1}
    else:
        descriptions = dict(desc_column.value_counts())
    groups_dict[group]['descriptions'] = descriptions # descrições do grupo
    d_size = [len(d.split(' ')) for d in descriptions.keys()]  # quantidade de tokens por descrição
    groups_dict[group]['sum'] = sum(d_size) # total de tokens do grupo
    groups_dict[group]['median'] = np.median(d_size) # mediana da quantidade de tokens do grupo
    groups_dict[group]['mean'] = np.mean(d_size) # média da quantidade de tokens do grupo
    groups_dict[group]['std'] = np.std(d_size) # desvio padrão da quantidade de tokens do grupo

def extract_tokens(group, groups_dict, desc_column):
    groups_dict[group]['tokens'] = defaultdict(int)
    for desc in desc_column:
        tokens = desc.split(' ')
        for token in tokens:
            groups_dict[group]['tokens'][token] += 1
    groups_dict[group]['tokens'] = {k: v for k, v in sorted(groups_dict[group]['tokens'].items(), key=lambda item: item[1], reverse=True)}

# %%
groups_dict = defaultdict(lambda: defaultdict(int))

for group, num_items in groups_count_df.iloc[:1000].iteritems():
    desc_column = items_df.loc[group]['original_desc']
    extract_descriptions(group, groups_dict, desc_column)
    extract_tokens(group, groups_dict, desc_column)

# %%
def description_description_strategy(info):
    return list(info['descriptions'].keys())[0]

def get_tokens_frequency(descriptions):
    tokens = set(' '.join(descriptions.keys()).split(' '))
    print(f'** {tokens} **')
    tokens_freq = defaultdict(int)
    for token in tokens:
        for desc in descriptions:
            if token in desc.split(' '):
                tokens_freq[token] += 1
        tokens_freq[token] = round(tokens_freq[token]/len(descriptions), 2)
    tokens_freq = {k:v for k,v in sorted(tokens_freq.items(), key=lambda item: item[1], reverse=True)}
    return list(tokens_freq.items())[:10], np.mean(list(tokens_freq.values()))

def description_token_strategy(info, min_tokens, max_tokens, min_freq):
    tokens = list(info['tokens'].items())
    description = ''
    tokens_freq, mean = get_tokens_frequency(info['descriptions'])
    print(' - 10 tokens mais frequentes nas descrições:', tokens_freq)
    print(' - Média das frequências dos tokens:', mean)
    for i in range(len(tokens_freq[:max_tokens])):
        token = tokens_freq[i][0]
        freq = tokens_freq[i][1]
        if freq >= mean:
            description += f'{token} '
    
#     for i in range(len(tokens[:max_tokens])):
# #         print(tokens[i])
#         key = tokens[i][0]
#         freq = tokens[i][1]/info['sum']
# #         print('freq: ', freq)
#         if freq >= min_freq:
#             description += f'{key} '
    return description

def build_descriptions(groups_dict, min_tokens=3, max_tokens=6, min_freq=0.4):
    for group, info in groups_dict.items():
        tokens = info['tokens']
        
        print(f'## {group} ##')
        print(' - Descrições:', info['descriptions'].keys())
        print(f' - 10 tokens mais frequentes: {list(tokens)[:10]}')
#         print(' - median: ', info['median'])
#         print(' - mean: ', info['mean'])
#         print(' - std: ', info['std'])
        
        # considerando descrição mais frequente
        desc_d = description_description_strategy(info)
        desc_t = description_token_strategy(info, min_tokens, max_tokens, min_freq)
        print(f'ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: {desc_d} ----')
        print(f'ESTRATÉGIA TOKENS MAIS FREQUENTES: {desc_t} ----')
        print('-'*100)
#         print(f'**** {desc_t} ****')

        
build_descriptions(groups_dict)
# Out:
# ## bibi ##
#  - Descrições: dict_keys(['bibi ir para escola', 'bibi compartilhar coisa', 'bibi ir para cama', 'bibi ir para escola 1 volume editor scipione', 'bibi compartilhar coisa 1 volume editor scipione', 'bibi compartiha coisa', 'bibi fala publico', 'bibi chupa mais dedo', 'bibi corta cabelo', 'bibi comer tudo', 'bibi tomar banho', 'bibi ir para escola editor scipione', 'bibi ir para cama 1 volume editor scipione', 'bibi fonfon fonfonvolante com 8 som diferente pilha', 'bibi compartilhar', 'bibi compartilhar coisa editor scipione'])
#  - 10 tokens mais frequentes: ['bibi', 'ir', 'para', 'coisa', 'escola', 'compartilhar', 'editor', 'scipione', 'cama', '1']
# ** {'corta', 'pilha', 'fonfonvolante', 'cama', 'cabelo', 'diferente', 'volume', 'mais', 'compartilhar', 'scipione', 'ir', 'comer', 'escola', 'fonfon', 'coisa', 'chupa', '1', 'com', 'dedo', 'som', 'publico', 'compartiha', 'banho', 'tomar', 'bibi', 'editor', 'tudo', '8', 'fala', 'para'} **
#  - 10 tokens mais frequentes nas descrições: [('bibi', 1.0), ('scipione', 0.31), ('ir', 0.31), ('editor', 0.31), ('para', 0.31), ('compartilhar', 0.25), ('coisa', 0.25), ('volume', 0.19), ('escola', 0.19), ('1', 0.19)]
#  - Média das frequências dos tokens: 0.15233333333333327
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: bibi ir para escola ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: bibi scipione ir editor para compartilhar  ----
# ----------------------------------------------------------------------------------------------------
# ## bezetacil ##
#  - Descrições: dict_keys(['bezetacil 1 200 000 u 300 ml ampola c 4', 'bezetacil 600 000 u 150 ml ampola c 4', 'bezetacil', 'bezetacil 1 200 000 inj', 'bezetacil 1 200', 'bezetacil ui cx 50 amp', 'bezetacil 600 000 ui com diluente caixa 50 frasco', 'bezetacil u mls', 'bezetacil u ms', 'bezetacil 1200 000 ui com diluente', 'bezetacil injetavel', 'bezetacil 1200 000 ui com diluente caixa 50 frasco', 'bezetacil 600 000', 'bezetacil inj 1 200', 'bezetacil 600 000 ui com diluente frasco', 'bezetacil 1200 000'])
#  - 10 tokens mais frequentes: ['bezetacil', '000', 'u', '1', '200', 'ml', 'ampola', 'c', '4', '600']
# ** {'1200', '4', 'amp', '300', '50', 'frasco', '150', '000', '600', 'bezetacil', '1', 'caixa', 'c', 'com', 'ml', 'inj', 'ui', 'mls', '200', 'cx', 'ampola', 'diluente', 'u', 'ms', 'injetavel'} **
#  - 10 tokens mais frequentes nas descrições: [('bezetacil', 1.0), ('000', 0.56), ('ui', 0.31), ('600', 0.25), ('1', 0.25), ('com', 0.25), ('200', 0.25), ('diluente', 0.25), ('u', 0.25), ('1200', 0.19)]
#  - Média das frequências dos tokens: 0.2032
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: bezetacil 1 200 000 u 300 ml ampola c 4 ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: bezetacil 000 ui 600 1 com  ----
# ----------------------------------------------------------------------------------------------------
# ## prensagem ##
#  - Descrições: dict_keys(['prensagem mangueira hidraulico geral', 'prensagem roach', 'prensagem simples protese dentario dentadura cor rosa', 'prensagem mang hid mangueira 1 2 trama', 'prensagem mang hid mangueira 1 4 2 trama', 'prensagem mang hid mangueira 1 2 trama polegada com conexao capa', 'prensagem mang hid mangueira retorno 1 2', 'prensagem', 'prensagem mang hid mangueira 3 8 2 trama', 'prensagem mang hid mangueira 3 4 2 trama polegada com conexao capa', 'prensagem mang hid mangueira 5 8 2 trama', 'prensagem mang hid mangueira 5 8 2 trama polegada com conexao capa', 'prensagem mang hid mangueira 1 4 2 trama polegada com conexao capa', 'prensagem mang hid mangueira 1 4 trama alegado com 2 conexao capa', 'prensagem mang hid mangueira retorno 5 8', 'prensagem mang hid mangueira 1 4 trama', 'prensagem mang hid mangueira 1 2 trama polegada trmas com conexao capa', 'prensagem montagem acabemento protese prestacao servico acabamento', 'prensagem mang hid mangueira 3 8 2 trama polegada com conexao capa', 'prensagem mang hid mangueira 1 4 2 trama polegada com conexoos capa', 'prensagem mang hid mangueira retorno 1 2 c com conexao capa'])
#  - 10 tokens mais frequentes: ['prensagem', 'mangueira', 'mang', 'hid', '2', 'trama', '1', 'com', 'capa', 'conexao']
# ** {'roach', 'hidraulico', '4', 'geral', 'dentario', 'capa', '2', 'simples', 'conexoos', 'prensagem', 'mangueira', 'conexao', 'retorno', '3', '5', 'cor', 'prestacao', 'hid', 'trmas', 'acabemento', 'acabamento', '1', 'rosa', 'c', 'montagem', 'com', 'servico', 'polegada', 'alegado', 'dentadura', 'protese', 'trama', '8', 'mang'} **
#  - 10 tokens mais frequentes nas descrições: [('prensagem', 1.0), ('mangueira', 0.81), ('hid', 0.76), ('mang', 0.76), ('2', 0.67), ('trama', 0.62), ('1', 0.48), ('capa', 0.43), ('com', 0.43), ('conexao', 0.38)]
#  - Média das frequências dos tokens: 0.25205882352941184
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: prensagem mangueira hidraulico geral ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: prensagem mangueira hid mang 2 trama  ----
# ----------------------------------------------------------------------------------------------------
# ## captura ##
#  - Descrições: dict_keys(['captura hibrido para hpv', 'captura morcego', 'captura animal', 'bloco captura grande animal 50 x 2 1 ver confeccionada papel off set 56 g super bond amarelo medir 150 21 mm com escrito cor 0 tinta preto arte fotolito incluir acabamento colado conformar modelo anexo', 'captura transporte animal efetuar encontrado ver publico municipio bovino equino suino caprino ovino', 'captura hibrido hpv 5222', 'captura transp guarda an', 'kit captura imagem para emissao ctps mte', 'captura hibrido hpv', 'captura animal confeccionado papel a4 75 g medir 30 x 21 cm impressao 1 0 frente retrato bloco com 50 folha', 'captura animal grande porte ccz papel ap branco 75 g medir 30 x 21 cm impressao 1 0 cor bloco com 50 folha', 'captura animal pequeno porte acima franquia mes partir 61 animal 100', 'captura animal grande porte', 'captura hibrido para hpv servico', 'captura animal peq porte', 'captura animal medio grande porte acima franquia mes partir 16 animal 30', 'kit captura', 'captura apreens animal'])
#  - 10 tokens mais frequentes: ['captura', 'animal', 'hibrido', 'hpv', 'para', 'grande', 'porte', 'ver', 'papel', 'g']
# ** {'2', 'conformar', 'municipio', 'mes', 'escrito', 'guarda', 'kit', 'hibrido', 'bloco', 'colado', 'captura', 'bond', 'partir', 'off', 'grande', 'branco', 'retrato', 'arte', 'g', 'mte', '50', 'preto', 'a4', '150', 'porte', 'animal', 'ccz', 'impressao', '1', 'x', 'ver', 'mm', 'folha', 'confeccionada', 'incluir', 'emissao', '100', 'para', 'super', 'apreens', 'set', 'transp', 'anexo', 'imagem', 'morcego', 'cor', 'efetuar', '5222', 'transporte', 'tinta', 'equino', 'com', 'servico', 'suino', 'fotolito', 'caprino', '16', 'medio', 'bovino', '30', 'ctps', 'medir', 'hpv', 'franquia', 'papel', 'encontrado', 'pequeno', '0', 'modelo', '21', 'confeccionado', 'acabamento', 'peq', 'an', '61', '75', 'publico', 'ovino', '56', 'frente', 'ap', 'acima', 'amarelo', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('captura', 1.0), ('animal', 0.56), ('porte', 0.28), ('hibrido', 0.22), ('grande', 0.22), ('hpv', 0.22), ('bloco', 0.17), ('g', 0.17), ('50', 0.17), ('1', 0.17)]
#  - Média das frequências dos tokens: 0.10773809523809529
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: captura hibrido para hpv ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: captura animal porte hibrido grande hpv  ----
# ----------------------------------------------------------------------------------------------------
# ## cerazette ##
#  - Descrições: dict_keys(['cerazette', 'cerazette c 28', 'cerazette c 28 cpr', 'cerazette comprimido', 'cerazette 75 mg cx c 28 comprimido', 'cerazette 75 mg', 'cerazette 28 desogestrel 75 mcg comprimido', 'cerazette desogestrel 75 mcg embalagem com 28 comprimido', 'cerazette 75 mcg c 28 comp', 'cerazette 0 75 c 84', 'cerazette c 21', 'cerazette desogestrel 75 mcg', 'cerazette 0 7 mg'])
#  - 10 tokens mais frequentes: ['cerazette', 'c', '28', '75', 'comprimido', 'mcg', 'mg', 'cpr', 'desogestrel', '0']
# ** {'cx', 'desogestrel', '7', 'cerazette', 'c', 'comp', '28', 'embalagem', '84', 'mg', 'com', '21', '75', 'mcg', 'cpr', '0', 'comprimido'} **
#  - 10 tokens mais frequentes nas descrições: [('cerazette', 1.0), ('75', 0.54), ('c', 0.46), ('28', 0.46), ('mcg', 0.31), ('comprimido', 0.31), ('desogestrel', 0.23), ('mg', 0.23), ('0', 0.15), ('cx', 0.08)]
#  - Média das frequências dos tokens: 0.25470588235294117
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: cerazette ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: cerazette 75 c 28 mcg comprimido  ----
# ----------------------------------------------------------------------------------------------------
# ## calceteiro ##
#  - Descrições: dict_keys(['calceteiro', 'calceteiro com encargo complementar', 'calceteiro com cabo', 'calceteiro 2', 'calceteiro 1', 'calceteiro com encargo', 'calceteiro 3', 'calceteiro com encargo complementaresmao obra assentamento bloco incluir colchao areia contratar', 'calceteiro 2 para execucao pavimentacao bloquetes sextavar intertravado fabrica almoxarifado', 'calceteiro 1 para execucao pavimentacao bloquetes sextavar intertravado fabrica almoxarifado', 'calceteiro 4'])
#  - 10 tokens mais frequentes: ['calceteiro', 'com', 'encargo', 'complementar', '1', '2', 'cabo', 'para', 'execucao', 'pavimentacao']
# ** {'calceteiro', '4', '2', 'cabo', '3', 'intertravado', 'almoxarifado', 'obra', 'assentamento', 'bloco', 'sextavar', 'colchao', 'complementaresmao', '1', 'areia', 'fabrica', 'com', 'pavimentacao', 'incluir', 'complementar', 'bloquetes', 'execucao', 'para', 'contratar', 'encargo'} **
#  - 10 tokens mais frequentes nas descrições: [('calceteiro', 1.0), ('com', 0.36), ('encargo', 0.27), ('2', 0.18), ('intertravado', 0.18), ('almoxarifado', 0.18), ('sextavar', 0.18), ('1', 0.18), ('fabrica', 0.18), ('pavimentacao', 0.18)]
#  - Média das frequências dos tokens: 0.1804
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: calceteiro ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: calceteiro com encargo  ----
# ----------------------------------------------------------------------------------------------------
# ## sp ##
#  - Descrições: dict_keys(['sp 11 fone ouvido p headset', 'sp 4 distrito jose almeida', 'sp 4', 'rolo espuma sp 9 cm', 'rolo espuma sp 15 cm', 'p sp 109 899 ab 5 b 6 arruela pressao', 'sp 25 placa sinalizacao total refletivo g c sentido proibir', 'rolo espuma sp 5 cm', 'sp 25 placa sinalizacao total refletivo g c proibir virar direito', 'sp 25 placa sinalizacao total refletivo g c proibir virar esquerda', 'sp 25 placa sinalizacao total refletivo g c proibir parar estacionar termino', 'sp 25 placa sinalizacao total refletivo g c seguir frente esquerda', 'sp 25 placa sinalizacao total refletivo g c r 6 proibir parar estacionar', 'sp 25 placa sinalizacao total refletivo g c seguir frente direito', 'sp 25 placa sinalizacao total refletivo g c parar obrigatorio', 'sp 25 placa sinalizacao total refletivo g c preferencia', 'sp 105 586 aa 9 d 1 retentor', 'sp 25 placa sinalizacao total refletivo g c', 'sp 377 para impressor bicho bnw compativel novo primeiro uso caixa fabricante toner', 'sp 25 placa sinalizacao total refletivo g c ponto parar', 'sp 105 570 bd 10 e 1 rolamento', 'sp 4500 originalricoh 4510 sf', 'sp 25 placa sinalizacao total refletivo g c proibir parar estacionar', 'sp 25 placa sinalizacao total refletivo g c saliencia lombada'])
#  - 10 tokens mais frequentes: ['sp', '25', 'placa', 'sinalizacao', 'total', 'refletivo', 'g', 'c', 'p', 'proibir']
# ** {'4', '109', 'virar', '15', '105', 'toner', 'parar', '11', 'placa', '377', 'compativel', 'ab', 'bd', '586', '4510', 'espuma', '6', 'd', '10', 'jose', 'e', 'saliencia', 'preferencia', 'total', 'sf', '25', '5', 'ponto', 'estacionar', 'lombada', 'sentido', 'esquerda', 'impressor', 'arruela', 'seguir', 'bnw', 'ouvido', 'almeida', '899', 'fabricante', 'proibir', 'r', '4500', 'rolo', 'originalricoh', '1', 'uso', 'caixa', 'c', 'bicho', 'sinalizacao', 'b', 'refletivo', 'sp', 'termino', 'g', 'aa', 'pressao', 'novo', 'rolamento', 'retentor', 'primeiro', 'headset', '570', 'fone', 'frente', '9', 'para', 'direito', 'p', 'distrito', 'cm', 'obrigatorio'} **
#  - 10 tokens mais frequentes nas descrições: [('sp', 1.0), ('placa', 0.54), ('total', 0.54), ('25', 0.54), ('c', 0.54), ('sinalizacao', 0.54), ('refletivo', 0.54), ('g', 0.54), ('proibir', 0.25), ('parar', 0.21)]
#  - Média das frequências dos tokens: 0.11726027397260277
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: sp 11 fone ouvido p headset ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: sp placa total 25 c sinalizacao  ----
# ----------------------------------------------------------------------------------------------------
# ## tec ##
#  - Descrições: dict_keys(['tec cool', 'tec cool litro', 'tec juta 1 40 largura', 'tec 304 feltro 1 40 cm largura marrom', 'tec d barmam prep drink', 'tec tela branco', 'tec cetim liso vinho', 'tec oxford branco 1 50 m', 'tec cetim liso branco', 'tec 3 8 costura', 'tec bril spray desingripante', 'tec enfermagem amb simples ii', 'tec cetim liso preto', 'tec bond 20 ml', 'tec cetim liso lila medio', 'tec oxford verde band 1 5 mt', 'tec 304 feltro 1 40 cm largura azul', 'tec 304 feltro 1 40 cm largura branco', 'tec cetim liso azul royal', 'tec cuidado espec c idoso', 'tec 3 16', 'tec cetim cor'])
#  - 10 tokens mais frequentes: ['tec', 'cool', '1', 'cetim', 'liso', '40', 'largura', 'branco', 'litro', '304']
# ** {'tec', 'vinho', 'band', 'bril', 'desingripante', 'azul', 'idoso', 'barmam', 'oxford', 'drink', 'd', '50', 'largura', 'simples', 'preto', 'amb', 'verde', '3', '5', 'royal', 'cor', 'mt', 'prep', 'costura', '20', 'feltro', '40', 'm', 'tela', '1', 'c', 'lila', 'enfermagem', 'liso', 'litro', 'bond', 'ml', 'marrom', '304', 'ii', 'cool', 'branco', 'cuidado', 'cetim', '16', 'medio', 'spray', '8', 'juta', 'espec', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('tec', 1.0), ('1', 0.27), ('cetim', 0.27), ('liso', 0.23), ('largura', 0.18), ('40', 0.18), ('branco', 0.18), ('feltro', 0.14), ('304', 0.14), ('cm', 0.14)]
#  - Média das frequências dos tokens: 0.0968627450980392
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: tec cool ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: tec 1 cetim liso largura 40  ----
# ----------------------------------------------------------------------------------------------------
# ## nobre ##
#  - Descrições: dict_keys(['madeira nobre 12 x 6', 'madeira nobre 7 x 8', 'madeira nobre 30 x 6', 'madeira nobre 8 x', 'nobre colonia', 'madeira nobre 15 x 6 cm', 'madeira nobre 16 x 6', 'vermelho nobre cereja', 'nobre', 'nobre ak 1400 vao com saida auxi', 'nobre ust 600 bi 115', 'nobre sentimento', 'nobre especificacao minimo linha producao fabricante break com potencia nominal 1 2 kva real 600 w tensao entrada 115 127 220 volt corrente alternado comutacao automatico saida 110 ser definido solicitante alarme audiovisual bateria interno selado autonomia pleno carga minimo 15 minuto considerar consumo 240 wats possuir 6 tomado padrao brasileiro produto dever novo sem uso reforma recondicionamento garantia 12 mes', 'nobre 1200 vao tensao saida 115 v 5 entrada 90 137 220 187 253 frequncia nominal 60 hz rendimento rede 95 bateria 85 numero tomado 4 2 p t fp 0 42 um 12', 'nobre sentimento 4 volume editor eureka', 'nobre 6054'])
#  - 10 tokens mais frequentes: ['nobre', 'madeira', 'x', '6', '12', '8', '7', '30', '15', 'saida']
# ** {'bateria', 'sem', 'tomado', 'volt', '2', 'mes', '5', 'definido', 't', '600', 'auxi', 'uso', 'entrada', '6054', 'selado', 'linha', 'audiovisual', 'madeira', 'rede', 'break', 'producao', '12', 'saida', 'alternado', '1200', 'bi', 'eureka', '253', 'padrao', 'tensao', '6', 'w', '1', 'nominal', 'x', 'rendimento', 'fp', 'solicitante', '220', 'wats', 'novo', 'consumo', 'minimo', '42', 'interno', 'dever', 'v', 'numero', 'frequncia', '1400', 'ser', 'especificacao', 'ust', 'produto', 'potencia', 'pleno', 'colonia', '90', '85', 'reforma', 'vermelho', 'fabricante', 'brasileiro', '240', 'minuto', 'com', 'carga', 'alarme', 'nobre', 'recondicionamento', '95', '7', '16', '8', '60', '30', 'sentimento', '137', '115', '4', 'kva', '15', 'corrente', '0', 'volume', 'considerar', 'vao', 'comutacao', 'autonomia', 'garantia', 'um', 'ak', '110', 'real', '187', 'cereja', '127', 'hz', 'possuir', 'editor', 'automatico', 'p', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('nobre', 1.0), ('madeira', 0.38), ('x', 0.38), ('6', 0.31), ('12', 0.19), ('saida', 0.19), ('115', 0.19), ('bateria', 0.12), ('tomado', 0.12), ('2', 0.12)]
#  - Média das frequências dos tokens: 0.08970873786407774
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: madeira nobre 12 x 6 ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: nobre madeira x 6 12 saida  ----
# ----------------------------------------------------------------------------------------------------
# ## objeto ##
#  - Descrições: dict_keys(['objeto presente instrumento prestacao servico disponibilizacao estrutura tecnologico armazenamento dado servidor online data center desenvolvimento link internet para site', 'objeto contratacao atividade esportivo para programa neste municipio jose vargem', 'objeto execucao obra engenharia cobertura quadra escolar municipio merce mg termo compromisso pac204974 2013 firmar com fundo nacional desenvolvimento educacao fnde', 'objeto liturgico religioso valor historico cultural pedra sabao pia batismal', 'objeto contratacao empresa especializado construcao civil para ponte conformar', 'objeto prestacao servico publico estacionamento rotativo veiculo automotor ver logradouro publico municipio pouso alegre estado mina gerais com disponibilizacao software equipamento sinalizacao meio pagamento material mao obra', 'objeto ficha arquivo especificacao papel cartao cor bege 240 grama impressao frente verso um medir aproximadamente 20 5 x 13 cm modelo acordo com anexo', 'objeto 3 tres edicao ser cada um composto seguinte caracteristico 1000 jornal 8 pagina papel ap 90 tamanho tabloide colorido', 'objeto 1 3 laudo estado conservacao sobre bem tombar municipio', 'objeto contratacao seguinte acompanhamento processo execucao orcamentario para atendimento exigencia tribunal conta rotina relacionado contabilidade tesouraria camara c', 'objeto 1 4 relatorio bem imaterial registrar', 'objeto presente licitacao escolha proposto mais vantajoso para administracao menor preco item visar futuro eventual aquisicao parcelar forma maquina permanente ser usado fabrica bloquetes presidir', 'objeto prestacao servico realizacao evento reveillon 2014 2015 pre carnaval conformar especificacao constante anexo i estrutura queima fogo 31 12 banda 3 diassonorizacaoilumi', 'objeto prestacao servico engenheiro civil responsavel tecnico servicosde engenharia atividade planejamento elaboracao detalhamento correcao revisao projeto bem assessoria tecnico especializado apoio supervisao fiscalizacao obra responsabilidade camara municipal saogotardo', 'objeto postal auto envelopar para entrega iptu postagem envelope contender parcela 2017 capa carne formato fechado 210 x 99 mm com lombada quadrado aberto 422 4 cor couche brilho 115 grama obs arte colorido', 'objeto 1 2 consultoria', 'objeto 2 coquetel para recepcao 400 quatrocentos pessoa solenidade ser realizado dia 27 11 2015 19 00 hora gremio literario recreativo mario lima composto salgado fino canape assado frito folhado cerveja tipo pilsen primeiro linha skol similar refrigerante guarana cola comum zero agua mineral taca cerveja fino pe longo bandeja inox jarra capacidade litro guardanapo papel folha dupla prestacao servico maitres garcom copeiro servico locucao mestre cerimonia arranjo flor grande com flor copo leite gispsofila boca leao mesa oficial coluna arranjo grande decoracao', 'objeto religioso valor historico cultural madeira oratorio', 'objeto 1 coquetel para recepcao 200 duzentos pessoa solenidade entrega medalha dia 2 10 2015 20 h 00 min plenario camara municipal santo dumont composto salgado fino canape assado folhado vinho tinto seco demi primeiro linha uva merlot cabernet refrigerante tipo guarana cola comum zero agua mineral taca vinho fino pe longo bandeja inox jarra capacidade litro guardanapo papel folha dupla prestacao servico maitres garcom copeiro servico locucao mestre cerimonia arranjo flor grande com flor copo leite gispsofila boca leao frente mesa oficial', 'objeto mdf 3992', 'caixa objeto', 'objeto presente licitacao aquisicao 1 veiculo passeio novo fabrica conformar descrever especificar anexo i acordo com termo compromisso n 652 6821 secretaria estado saude mina gerais destinado atender municipal tudo edital anexo', 'objeto presente contratacao selecao empresa instituto entidade especializado prestacao servico pesquisa opiniao publico compreender planejamento realizacao projeto quantitativo qualitativo coleta analise dado elaboracao relatorio apresentacao result ...
#  - 10 tokens mais frequentes: ['objeto', 'servico', 'prestacao', 'para', 'presente', 'com', 'contratacao', '1', 'municipio', 'conformar']
# ** {'129', 'comum', 'municipio', 'engenheiro', 'dado', 'medalha', '5', 'cabernet', 'merce', 'quadra', 'acordo', 'atualizacao', 'agua', 'inox', '9838', 'flor', 'grande', 'conta', 'edital', 'coluna', 'secretaria', 'material', 'preco', 'dupla', 'tecnologico', 'fundo', 'tipo', 'aproximadamente', 'gispsofila', '27', 'dumont', 'municipal', '10', 'constante', 'queima', 'tinto', 'parcela', '652', 'proposto', 'realizacao', '1', '313', 'ver', 'nacional', 'tres', 'atividade', 'ficha', 'fogo', 'firmar', 'novo', '210', 'i', 'fiscalizacao', 'para', 'site', 'contender', 'ser', 'anexo', 'ponte', 'vargem', 'bege', 'salgado', 'produto', 'pac204974', 'cor', '2017', 'com', 'plano', 'tombar', 'administracao', 'solenidade', 'permanente', 'copeiro', 'meio', 'cobertura', '115', 'retifica', 'pouso', '4', 'mais', 'arranjo', 'auto', 'estrutura', 'lombada', 'diassonorizacaoilumi', 'saude', 'planejamento', 'm', 'taca', 'leao', 'dia', 'litro', 'passeio', 'especializado', 'urna', 'conservacao', 'batismal', '200', 'folhado', 'motor', 'gremio', 'colorido', 'recepcao', 'mdf', 'relacionado', 'demi', 'mineral', 'composto', 'elaboracao', 'jarra', 'filtro', 'entrega', 'desenvolvimento', 'aberto', 'equipamento', 'contabilidade', 'futuro', 'estado', 'forma', 'couche', 'madeira', 'skol', 'cultural', 'revisao', 'cartao', 'sabao', '12', 'usado', 'quantitativo', 'parcelar', 'atender', 'capa', 'jose', 'educacao', 'leite', 'cerveja', 'seguinte', 'impressao', 'x', 'incluir', 'garcom', 'min', 'envelope', '400', 'banda', 'logradouro', 'gtm', 'oficial', 'fino', 'mario', 'instrumento', 'tesouraria', '90', 'escolha', 'santo', 'plenario', 'supervisao', 'caixa', 'uva', '99', 'ano', 'data', 'postagem', 'tudo', 'postal', 'fnde', 'tamanho', 'n', 'guardanapo', 'duzentos', 'papel', 'religioso', 'compromisso', 'recreativo', 'seco', 'maitres', 'liturgico', 'rotina', 'automotor', '2013', 'frente', 'assessoria', 'responsavel', 'tabloide', 'cm', 'historico', '11', 'pesquisa', '2', 'esportivo', '00', 'cdi', 'registrar', 'cristo', '1000', 'brilho', 'c', 'assado', 'coleta', 'sinalizacao', '2014', 'boca', 'similar', 'cerimonia', '31', 'arte', 'compreender', 'tecnico', 'mestre', 'placa', 'orcamentario', 'qualitativo', 'canape', '3', 'detalhamento', 'acompanhamento', 'laudo', 'link', 'folha', 'software', 'pessoa', 'pre', 'verso', 'analise', 'eventual', 'especificacao', 'inventario', 'prestacao', 'engenharia', 'quadrado', 'realizado', 'bandeja', 'fabrica', 'cola', 'benz', 'jornal', 'presente', 'mao', 'bloquetes', 'oratorio', 'escolar', 'especificar', 'center', 'destinado', 'locucao', 'capacidade', 'responsabilidade', 'exigencia', 'um', 'decoracao', '19', 'programa', 'literario', 'vantajoso', '422', 'merlot', 'fechado', 'publico', 'construcao', 'online', 'presidir', 'ap', 'visar', 'referencia', 'apresentacao', '2015', 'rotativo', 'pe', 'conformar', 'objeto', 'empresa', 'mg', 'zero', 'longo', 'termo', 'contratacao', 'servidor', 'linha', 'evento', 'projeto', 'primeiro', 'lubricantes', 'envelopar', 'arquivo', 'completo', 'relatorio', 'iptu', 'licitacao', 'formato', 'h', 'vinho', '13', 'pia', 'valor', 'item', 'guarana', 'copo', 'sobre', 'hora', 'entidade', 'consultoria', 'obra', 'menor', 'cv', 'resultado', 'maquina', 'mm', 'tribunal', 'pilsen', 'frito', 'sprinter', 'veiculo', 'apoio', 'mesa', 'descrever', 'correcao', 'aquisicao', 'refrigerante', 'caracteristico', 'carne', 'estacionamento', 'grama', '20', '240', 'lima', 'servicosde', 'pagina', 'edicao', 'mina', 'servico', 'disponibilizacao', 'pedra', '6821', '3992', '16', 'obs', '8', 'instituto', 'alegre', 'imaterial', 'armazenamento', 'medir', 'selecao', 'civil', 'cada', 'saogotardo', 'modelo', 'opiniao', '2006', 'gerais', 'internet', 'carnaval', 'l', 'coquetel', '2007', 'neste', 'processo', 'quatrocentos', 'pagamento', 'reveillon', 'atendimento', 'camara', 'bem', 'peca', 'execucao'} **
#  - 10 tokens mais frequentes nas descrições: [('objeto', 1.0), ('prestacao', 0.36), ('servico', 0.36), ('para', 0.32), ('com', 0.25), ('presente', 0.25), ('1', 0.21), ('contratacao', 0.21), ('especializado', 0.18), ('conformar', 0.18)]
#  - Média das frequências dos tokens: 0.06364383561643835
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: objeto presente instrumento prestacao servico disponibilizacao estrutura tecnologico armazenamento dado servidor online data center desenvolvimento link internet para site ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: objeto prestacao servico para com presente  ----
# ----------------------------------------------------------------------------------------------------
# ## parcial ##
#  - Descrições: dict_keys(['bloco 100 x 1 parcial campanha vacinacao antirrabico animal f9 ap75 0 bl fls ver 21 31 cm', 'parcial motor mercedes benz 1113 ano 1974', 'parcial motor fiat unir mille way economy ano 2010', 'parcial motor fiat unir vivace ano 2011', 'parcial motor fiat doblo 1 8 114 cv ano 2009', 'parcial motor scania a113 310 cv ano 1993', 'parcial motor gol giv 71 cv ano 2011', 'parcial motor renault sandero 77 cv ano 2013 2014', 'parcial motor vw polo sedan 1 6 ano 2010', 'parcial motor fiat fiorino 1 5 ie 65 cv ano 2011 2012', 'parcial motor vw 15 190 187 cv ano 2010', 'parcial motor mercedes benz 1313 ano 1974', 'parcial motor fiat ducato 127 cv ano 2012 2013', 'kit parcial amortecedor dianteiro', 'tecido parcial 180 fio 2 55 m largura 100 algodao liso cor branco'])
#  - 10 tokens mais frequentes: ['parcial', 'motor', 'ano', 'cv', '1', 'fiat', '2011', '2010', '100', 'bloco']
# ** {'1313', 'sandero', 'ducato', 'way', '2', '5', '1993', 'kit', 'amortecedor', 'bloco', '190', 'polo', 'fiorino', 'dianteiro', 'ie', '114', '2014', 'branco', 'a113', 'campanha', 'doblo', 'vacinacao', '31', 'tecido', 'fio', '180', '77', '6', 'vw', '2009', '1974', 'animal', 'mille', 'vivace', 'cv', '1', 'x', 'ver', '100', 'parcial', '2012', 'bl', 'unir', 'scania', 'largura', 'cor', 'f9', '2010', '71', 'benz', '65', 'ano', '1113', 'liso', 'giv', 'ap75', 'fiat', 'mercedes', '8', '2011', 'fls', '15', 'economy', 'antirrabico', '55', '0', '21', 'gol', '187', 'm', 'algodao', '127', '310', 'sedan', 'motor', '2013', 'renault', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('parcial', 1.0), ('ano', 0.8), ('motor', 0.8), ('cv', 0.47), ('fiat', 0.33), ('1', 0.27), ('2010', 0.2), ('2011', 0.2), ('vw', 0.13), ('1974', 0.13)]
#  - Média das frequências dos tokens: 0.12115384615384621
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: bloco 100 x 1 parcial campanha vacinacao antirrabico animal f9 ap75 0 bl fls ver 21 31 cm ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: parcial ano motor cv fiat 1  ----
# ----------------------------------------------------------------------------------------------------
# ## rebaixamento ##
#  - Descrições: dict_keys(['rebaixamento teto', 'rebaixamento voil branco', 'rebaixamento teto tecido metro quadrado dia fechamento lateral helanca light tencionar corda trancado 3 6 mm com fixacao bola gude amarracao regua pino sob piso existente local pe dir', 'rebaixamento meio fio com acessibilidade pessoa necessidade especial', 'rebaixamento sub leito', 'rebaixamento arvore medio porte acima 6 0 m 10 altura', 'rebaixamento grande porte arvore acima 10 0 m altura', 'rebaixamento com placa acartonar', 'rebaixamento arvore pequeno porte 4 0 m 6 altura', 'rebaixamento teto placa gesso', 'rebaixamento arvore grande porte acima 10 0 m altura', 'rebaixamento medio porte arvore acima 6 0 m 10 altura', 'rebaixamento teto tecido tetometro quadrado dia fechamento lateral helanca light tencionar corda trancado 3 6 mm com fixacao bola gude amarracao regua pino sob piso existente local pe direito minimo 4 m altura', 'rebaixamento pequeno porte arvore 4 0 6 m altura', 'rebaixamento teto com tecido branco compreender 28 tenda tipo chapeu bruxo tam 10 x m utilizar 4 baixar juncao centro cada tenda formando desenho oval', 'rebaixamento teto gesso prestacao servico'])
#  - 10 tokens mais frequentes: ['rebaixamento', 'teto', 'm', 'com', '6', 'altura', 'porte', 'arvore', '0', '10']
# ** {'arvore', 'tecido', 'amarracao', 'compreender', 'necessidade', '4', 'gesso', 'fio', 'dir', 'tipo', 'tam', 'trancado', 'placa', 'juncao', 'desenho', 'pe', 'lateral', 'oval', 'fixacao', '6', 'pequeno', 'cada', '10', '0', 'chapeu', 'minimo', 'tencionar', 'rebaixamento', '3', 'local', 'tetometro', 'centro', 'prestacao', 'helanca', 'bola', 'baixar', 'utilizar', 'formando', 'piso', 'metro', 'porte', 'quadrado', 'direito', 'tenda', 'leito', 'pino', 'm', 'sub', 'existente', 'gude', 'x', 'dia', 'mm', 'light', 'com', 'servico', 'corda', 'fechamento', 'sob', 'altura', 'grande', 'branco', 'voil', 'acessibilidade', 'teto', 'acartonar', 'medio', '28', 'pessoa', 'acima', 'regua', 'meio', 'bruxo', 'especial'} **
#  - 10 tokens mais frequentes nas descrições: [('rebaixamento', 1.0), ('m', 0.5), ('altura', 0.44), ('arvore', 0.38), ('6', 0.38), ('0', 0.38), ('porte', 0.38), ('teto', 0.38), ('10', 0.31), ('com', 0.31)]
#  - Média das frequências dos tokens: 0.14175675675675678
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: rebaixamento teto ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: rebaixamento m altura arvore 6 0  ----
# ----------------------------------------------------------------------------------------------------
# ## vigadexa ##
#  - Descrições: dict_keys(['vigadexa colirio', 'vigadexa colirio 5 ml', 'vigadexa cilodex colirio', 'vigadexa dexametasona 5 mg ml', 'vigadexa 5 mg ml 1', 'vigadexa 5 ml', 'vigadexa colirio c 5 ml', 'vigadexa col 5 ml', 'vigadexa 5 45 1 10 mg ml'])
#  - 10 tokens mais frequentes: ['vigadexa', 'colirio', '5', 'ml', 'mg', '1', 'cilodex', 'dexametasona', '45', '10']
# ** {'vigadexa', '1', '5', 'c', 'cilodex', 'col', 'mg', 'colirio', 'ml', '45', '10', 'dexametasona'} **
#  - 10 tokens mais frequentes nas descrições: [('vigadexa', 1.0), ('5', 0.78), ('ml', 0.78), ('colirio', 0.44), ('mg', 0.33), ('1', 0.22), ('c', 0.11), ('cilodex', 0.11), ('col', 0.11), ('45', 0.11)]
#  - Média das frequências dos tokens: 0.35083333333333333
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: vigadexa colirio ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: vigadexa 5 ml colirio  ----
# ----------------------------------------------------------------------------------------------------
# ## gammar ##
#  - Descrições: dict_keys(['gammar', 'gammar xarope', 'gammar acido gama aminobutirico suspensao', 'gammar xarope ac', 'gammar 250 mg', 'gammar 250 mg com 36 comprimido', 'gammar suspensao acido gama aminobutirico 1952', 'gammar 100 ml', 'gammar 100 ml ac', 'gammar suspensao', 'gammar 250 mg ac'])
#  - 10 tokens mais frequentes: ['gammar', 'suspensao', 'xarope', '250', 'mg', 'acido', 'gama', 'aminobutirico', 'ac', 'com']
# ** {'250', 'gama', 'suspensao', 'acido', 'ac', 'xarope', '36', 'mg', 'com', 'aminobutirico', 'gammar', '100', 'ml', '1952', 'comprimido'} **
#  - 10 tokens mais frequentes nas descrições: [('gammar', 1.0), ('250', 0.27), ('suspensao', 0.27), ('ac', 0.27), ('mg', 0.27), ('gama', 0.18), ('acido', 0.18), ('xarope', 0.18), ('aminobutirico', 0.18), ('100', 0.18)]
#  - Média das frequências dos tokens: 0.23466666666666666
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: gammar ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: gammar 250 suspensao ac mg  ----
# ----------------------------------------------------------------------------------------------------
# ## urucum ##
#  - Descrições: dict_keys(['urucum po fuba', 'urucum po fino homogeneo coloracao vermelho intensar com identificacao produto marca fabricante prazer validade pesar liquido dever ter registro ministerio agricultura saude embalagem 1 kg', 'urucum colorifico po bom qualidade embalagem contender 500 grama com um data validade acima 10 mes', 'urucum colorifico', 'urucum material moer classificado lipossoluvel aplicacao condimento preparado apresentacao frasco sache com minimo 100 grs', 'urucum po', 'urucum po fino homogeneo coloracao vermelho intensar com identificacao produto marca fabricante prazer validade pesar liquido dever ter registro ministerio agricultura saude embalagem 500 grama', 'urucum colorifico po regional primeiro qualidade extrato homogeneo com identificacao produto fabricante prazer validade pesar embalagem atoxicar 500 grama', 'urucum amido milhar oleo soja pacote 90 gr', 'urucum'])
#  - 10 tokens mais frequentes: ['urucum', 'po', 'com', 'embalagem', 'validade', 'fuba', 'colorifico', 'homogeneo', 'identificacao', 'produto']
# ** {'dever', 'contender', 'fino', 'apresentacao', 'extrato', 'validade', 'pacote', 'mes', 'produto', 'ter', '10', 'moer', 'coloracao', 'liquido', 'grama', 'embalagem', 'saude', 'frasco', 'um', 'aplicacao', 'soja', '90', 'condimento', 'grs', 'ministerio', '500', 'pesar', 'fabricante', 'vermelho', 'urucum', 'milhar', 'fuba', 'marca', 'preparado', '1', 'oleo', 'homogeneo', 'com', 'agricultura', 'bom', 'atoxicar', 'po', 'kg', '100', 'amido', 'data', 'qualidade', 'prazer', 'regional', 'registro', 'material', 'primeiro', 'identificacao', 'colorifico', 'classificado', 'lipossoluvel', 'acima', 'sache', 'minimo', 'intensar', 'gr'} **
#  - 10 tokens mais frequentes nas descrições: [('urucum', 1.0), ('po', 0.6), ('com', 0.5), ('validade', 0.4), ('embalagem', 0.4), ('produto', 0.3), ('grama', 0.3), ('500', 0.3), ('pesar', 0.3), ('fabricante', 0.3)]
#  - Média das frequências dos tokens: 0.19016393442622948
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: urucum po fuba ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: urucum po com validade embalagem produto  ----
# ----------------------------------------------------------------------------------------------------
# ## vila ##
#  - Descrições: dict_keys(['vila fatima ponto por gasolina br ver corrego ver alegre jose tatao bom jardim casa salvador x ana mendes dutra m i mariani batista 40 aluno ens fundamental educacao infantil turno matutino 23 km', 'vila pontao sair propriedade sr ananias lucas indo estrada principal com aluno ir onibus para padre andre colli santo rita itueto retorno matutino', 'vila fatima ponto trailer jaci x sebastiao sacramento 35 aluno ensino medio turno noturno 14 km', 'vila baiuca raiz ubai', 'vila pontao sair propriedade sr ananias lucas indo estrada principal com aluno ir onibus para padre andre colli santo rita itueto retorno', 'vila pontao cristo rei sair indo com aluno ensino superior ir para aimore retorno', 'vila bom goyas autor coralino cora', 'vila capitao fonseca centro noberto fenix jardim ponte cod 27 11', 'vila fatima ponto entrada corrego ver alegre x sebastiao sacramento 60 aluno ensino fundamental turno matutino 15 km', 'vila gumercindo oliveira lacerda pavimentacao', 'vila varal paio baixao jose simoes junior matutino', 'vila baiuca raiz ubainoturno', 'vila trajanovargem alegremanha tarde', 'vila joaquim fazenda agua doce vice verso turno manha', 'vila baiuca raiz ubaimatutino', 'vila gumercindo oliveira lacerda drenagem', 'vila novo', 'vila capitao fonseca centro v noberto fenix j ponte c cod 27 11', 'vila klabin pavimentacao', 'vila pontao x cristo rei sair indo com aluno ensino superior ir para aimore retorno noturno', 'vila klabin drenagem'])
#  - 10 tokens mais frequentes: ['vila', 'aluno', 'ver', 'matutino', 'x', 'turno', 'fatima', 'ponto', 'km', 'corrego']
# ** {'cora', '35', 'rita', 'salvador', 'baiuca', '11', 'mendes', 'lacerda', 'fundamental', 'ensino', 'paio', '23', 'casa', 'cristo', 'doce', '40', 'coralino', 'entrada', 'itueto', 'trailer', 'fenix', 'agua', 'c', 'bom', 'principal', 'tarde', 'jaci', 'jardim', 'goyas', 'superior', 'br', 'pontao', 'gasolina', '27', 'raiz', 'mariani', '14', 'jose', 'educacao', 'retorno', 'centro', 'ens', 'noturno', 'aluno', 'klabin', 'estrada', 'infantil', 'vice', 'x', 'ver', 'drenagem', 'propriedade', 'ubainoturno', 'novo', 'i', 'fazenda', 'padre', 'autor', 'para', 'por', 'verso', 'v', 'varal', 'batista', 'ubai', 'simoes', 'corrego', 'ponte', 'ana', 'j', 'vila', 'indo', 'tatao', 'ponto', 'capitao', 'oliveira', 'santo', 'dutra', 'joaquim', 'sacramento', 'km', 'colli', 'sair', 'com', 'pavimentacao', 'fatima', 'medio', '60', 'baixao', 'gumercindo', 'alegre', 'turno', '15', 'rei', 'onibus', 'trajanovargem', 'ir', 'ubaimatutino', 'manha', 'cod', 'aimore', 'andre', 'junior', 'm', 'matutino', 'sr', 'lucas', 'noberto', 'alegremanha', 'ananias', 'sebastiao', 'fonseca'} **
#  - 10 tokens mais frequentes nas descrições: [('vila', 1.0), ('aluno', 0.33), ('ensino', 0.19), ('pontao', 0.19), ('retorno', 0.19), ('x', 0.19), ('para', 0.19), ('indo', 0.19), ('sair', 0.19), ('com', 0.19)]
#  - Média das frequências dos tokens: 0.09750000000000002
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: vila fatima ponto por gasolina br ver corrego ver alegre jose tatao bom jardim casa salvador x ana mendes dutra m i mariani batista 40 aluno ens fundamental educacao infantil turno matutino 23 km ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: vila aluno ensino pontao retorno x  ----
# ----------------------------------------------------------------------------------------------------
# ## artane ##
#  - Descrições: dict_keys(['artane 5 mg', 'artane 2 mg', 'artane 5 mgc 30', 'artane 2 mg caixa 30 c 30', 'artane cloridrato triexifenidil 5 mg com 30 comprimido', 'artane 5 mg comprimido', 'artane cloridrato triexifenidil 2 mg com 30 comprimido', 'artane 2 mg c 30 cpr', 'artane 2 mg triexifenidil'])
#  - 10 tokens mais frequentes: ['artane', 'mg', '5', '2', '30', 'comprimido', 'triexifenidil', 'cloridrato', 'com', 'c']
# ** {'caixa', '5', 'c', 'artane', 'mg', 'com', '30', 'comprimido', 'cpr', '2', 'triexifenidil', 'mgc', 'cloridrato'} **
#  - 10 tokens mais frequentes nas descrições: [('artane', 1.0), ('mg', 0.89), ('30', 0.56), ('2', 0.56), ('5', 0.44), ('comprimido', 0.33), ('triexifenidil', 0.33), ('c', 0.22), ('com', 0.22), ('cloridrato', 0.22)]
#  - Média das frequências dos tokens: 0.39230769230769236
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: artane 5 mg ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: artane mg 30 2 5  ----
# ----------------------------------------------------------------------------------------------------
# ## solifenacina ##
#  - Descrições: dict_keys(['solifenacina 5 mg c 30 comp', 'solifenacina succinato 10 mg comprimido', 'solifenacina succinato 6 mg tansulosina cloridrato 0 4 marca vesomni fabricante astellas comprimido liberacao modificar para atendimento ordem judicial uso exclusivo smsa', 'solifenacina 5 mg vesicare', 'solifenacina 6 mg 0 4', 'solifenacina sal succinato 5 mg comprimido', 'solifenacina succinato 10 mg', 'solifenacina 10 mg', 'solifenacina succinato 5 mg comprimido', 'solifenacina 5 mg', 'solifenacina tansulosina 610 4 mg'])
#  - 10 tokens mais frequentes: ['solifenacina', 'mg', 'succinato', '5', 'comprimido', '10', '4', '6', '0', 'tansulosina']
# ** {'4', 'judicial', 'ordem', 'liberacao', 'vesicare', '6', 'smsa', '10', '0', '5', 'solifenacina', 'mg', 'comprimido', 'fabricante', 'modificar', 'marca', 'atendimento', 'uso', 'c', 'astellas', 'exclusivo', 'sal', 'vesomni', 'succinato', '610', 'comp', '30', 'para', 'tansulosina', 'cloridrato'} **
#  - 10 tokens mais frequentes nas descrições: [('solifenacina', 1.0), ('mg', 1.0), ('5', 0.45), ('succinato', 0.45), ('comprimido', 0.36), ('4', 0.27), ('10', 0.27), ('6', 0.18), ('0', 0.18), ('tansulosina', 0.18)]
#  - Média das frequências dos tokens: 0.20466666666666664
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: solifenacina 5 mg c 30 comp ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: solifenacina mg 5 succinato comprimido 4  ----
# ----------------------------------------------------------------------------------------------------
# ## zyprexa ##
#  - Descrições: dict_keys(['zyprexa 10 mg', 'zyprexa 10 mg c 28 compr', 'zyprexa 10 mg comprimido', 'zyprexa 5 mg olanzapina', 'zyprexa 5 mg c 28 cpr', 'zyprexa 5 mg', 'zyprexa 5 mg caixa com 28 comprimido', 'zyprexa 10 mg c 28 cpr', 'zyprexa 25 mg'])
#  - 10 tokens mais frequentes: ['zyprexa', 'mg', '10', '5', '28', 'c', 'comprimido', 'compr', 'cpr', 'olanzapina']
# ** {'caixa', '25', '5', 'c', '28', 'mg', 'com', 'zyprexa', 'compr', 'cpr', '10', 'comprimido', 'olanzapina'} **
#  - 10 tokens mais frequentes nas descrições: [('mg', 1.0), ('zyprexa', 1.0), ('5', 0.44), ('28', 0.44), ('10', 0.44), ('c', 0.33), ('cpr', 0.22), ('comprimido', 0.22), ('caixa', 0.11), ('25', 0.11)]
#  - Média das frequências dos tokens: 0.356923076923077
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: zyprexa 10 mg ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: mg zyprexa 5 28 10  ----
# ----------------------------------------------------------------------------------------------------
# ## pararestauracoes ##
#  - Descrições: dict_keys(['resina pararestauracoes b 1 e direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 3 d direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 2 e direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 2 d direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 1 d dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao polimento ainda superior resina m', 'resina pararestauracoes a 1 e direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 3 e direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes b 1 direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 6 b direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 4 d direto indireto dente anterior posterior classe i ii iii iv v seringa com g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao', 'resina pararestauracoes a 4 b direto indireto dente anterior posterior classe i ii iii iv v seringa com g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao'])
#  - 10 tokens mais frequentes: ['resina', 'pararestauracoes', 'dente', 'anterior', 'posterior', 'classe', 'i', 'ii', 'iii', 'iv']
# ** {'v', 'classe', 'dente', 'excelente', '4', 'indireto', 'garante', 'polimento', 'composto', 'retencao', '2', '6', 'ceramico', 'e', 'd', 'iii', 'posterior', 'nanoparticulas', '3', 'silanizada', 'um', 'a', 'm', '1', 'direto', 'com', '100', 'b', 'superior', 'iv', 'ii', 'seringa', 'resina', 'anterior', 'i', 'pararestauracoes', 'ainda', 'g'} **
#  - 10 tokens mais frequentes nas descrições: [('v', 1.0), ('classe', 1.0), ('dente', 1.0), ('excelente', 1.0), ('4', 1.0), ('garante', 1.0), ('composto', 1.0), ('retencao', 1.0), ('ceramico', 1.0), ('iii', 1.0)]
#  - Média das frequências dos tokens: 0.7602631578947368
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: resina pararestauracoes b 1 e direto indireto dente anterior posterior classe i ii iii iv v seringa com 4 g composto 100 nanoparticulas ceramico silanizada garante um excelente retencao ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: v classe dente excelente 4 garante  ----
# ----------------------------------------------------------------------------------------------------
# ## semestre ##
#  - Descrições: dict_keys(['i ii semestre linha 49 2018 tres barra fazer skol ponte tabua estivo bocaina barr', 'i ii semestre linha 7 2018 serra bicho brejo cachoeira transbordo', 'i ii semestre linha 6 2018 faxinal estivo fazenda santo clara samuel bernardes kombi manha', 'i ii semestre linha 39 2018 coqueiro rosario peao serrinha campestre manha alm', 'i ii semestre linha 1 2018 chamal santo antonio d ana pinheiro usina escola pedr', 'i ii semestre linha 61 2018 cuca colonia sapo fazer usina escola pedra manha kombi', 'i ii semestre linha 57 2018 aroeira posse rio peixe campestre manha almoco conib', 'i ii semestre linha 60 2018 pinhal trevo cachoeira tijuco preto campestre almoco ta', 'i ii semestre linha 36 2018 serra b caxambu peao meio baixo esc apae manh', 'i ii semestre linha 54 2018 anhuma sitio maranata faisao dourado b colina manha almoco tarde kombi', 'i ii semestre linha 31 2018 brejo cachoeira pinhal tijuco preto campestre almoco tarde van', 'i ii semestre linha 59 2018 b peao baixo meio escola manha almec', 'i ii semestre linha 58 2018 pedra miudo grande ibituruna sertao esc', 'i ii semestre linha 40 2018 rio peixe pesqueiro tres cruz campestre manha almoco tarde', 'i ii semestre linha 1 2018 chamal santo antonio d ana pinheiro usina escola pedra manha almoco van', 'i ii semestre linha 26 2018 b joao serra teixeiras aterro borda manha almoco micro', 'i ii semestre linha 34 2018 caxambu milhar verde peao esc kombi manha almoco', 'i ii semestre linha 5 2018 fazenda santo clara tres barra ponte tabua escola pedra', 'i ii semestre linha 12 2018 pinhal sertao cachoeira tijuco preto lagoa azul campestre', 'i ii semestre linha 37 2018 peao esc estrada campestre onibus manha almoco', 'i ii semestre linha 35 2018 b primo milhar verde peao escola manha almoco van', 'i ii semestre linha 11 2018 divisa botelhos brejo ouro verde cachoeira tijuco preto', 'i ii semestre linha 2 2018 serra negro pinheiro baixo larica usina escola pedra'])
#  - 10 tokens mais frequentes: ['i', 'ii', 'semestre', 'linha', '2018', 'manha', 'almoco', 'campestre', 'escola', 'peao']
# ** {'tijuco', '35', '11', 'pinhal', 'larica', '2', 'brejo', 'campestre', 'rosario', '5', '36', 'divisa', 'posse', 'conib', 'barr', '40', 'lagoa', 'negro', 'borda', 'ibituruna', 'linha', 'bicho', 'tarde', 'almoco', 'sitio', 'skol', 'grande', 'cruz', 'sertao', 'manh', 'tabua', '31', '12', 'micro', 'esc', 'van', '58', '6', '2018', 'serra', 'preto', 'bernardes', 'teixeiras', 'bocaina', 'ouro', '39', '26', 'milhar', 'joao', 'estrada', 'aterro', '1', '34', 'tres', 'peao', '54', 'botelhos', 'primo', 'i', 'fazenda', 'miudo', 'azul', 'maranata', 'serrinha', 'transbordo', 'pedr', 'cachoeira', 'ponte', 'ana', 'apae', 'fazer', 'colonia', 'escola', 'estivo', 'santo', 'coqueiro', 'pinheiro', 'usina', 'aroeira', 'pedra', 'anhuma', '37', 'almec', '7', 'baixo', '60', 'meio', 'semestre', '59', 'cuca', 'pesqueiro', 'd', 'onibus', 'verde', 'kombi', 'rio', 'manha', 'samuel', 'ta', 'antonio', '61', 'colina', 'b', 'barra', 'chamal', 'ii', 'faxinal', 'alm', 'dourado', '57', 'trevo', 'faisao', 'caxambu', 'clara', 'peixe', 'sapo', '49'} **
#  - 10 tokens mais frequentes nas descrições: [('linha', 1.0), ('2018', 1.0), ('i', 1.0), ('semestre', 1.0), ('ii', 1.0), ('manha', 0.52), ('almoco', 0.43), ('campestre', 0.3), ('escola', 0.3), ('peao', 0.26)]
#  - Média das frequências dos tokens: 0.12102564102564102
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: i ii semestre linha 49 2018 tres barra fazer skol ponte tabua estivo bocaina barr ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: linha 2018 i semestre ii manha  ----
# ----------------------------------------------------------------------------------------------------
# ## tribuna ##
# ...
# ----------------------------------------------------------------------------------------------------
# ## maquete ##
#  - Descrições: dict_keys(['maquete escova dente', 'maquete dentario', 'maquete urbano madeira mdf', 'maquete casa', 'maquete casa 58 x 48 17 cm', 'maquete eletronico 3 d', 'maquete casa mdf', 'maquete casa medir 58 x 48 17 cm possuir telhado movel 2 peca', 'maquete chapa mdf 3 0 mm', 'maquete anatomico pelve', 'maquete', 'maquete urbano conjunto confeccionado madeira prensar mdf macico contender 63 peca', 'maquete urbano'])
#  - 10 tokens mais frequentes: ['maquete', 'mdf', 'dentario', 'escova', 'dente', 'urbano', 'casa', 'madeira', '58', 'x']
# ** {'contender', 'dente', 'telhado', '58', 'medir', 'dentario', 'conjunto', '2', 'd', '0', '63', '3', 'confeccionado', 'eletronico', 'chapa', 'casa', 'prensar', 'urbano', 'escova', 'anatomico', 'x', 'macico', 'mm', 'pelve', 'peca', 'madeira', 'maquete', 'possuir', '17', 'movel', '48', 'cm', 'mdf'} **
#  - 10 tokens mais frequentes nas descrições: [('maquete', 1.0), ('casa', 0.31), ('mdf', 0.31), ('urbano', 0.23), ('58', 0.15), ('3', 0.15), ('x', 0.15), ('peca', 0.15), ('madeira', 0.15), ('17', 0.15)]
#  - Média das frequências dos tokens: 0.14333333333333334
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: maquete escova dente ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: maquete casa mdf urbano 58 3  ----
# ----------------------------------------------------------------------------------------------------
# ## pururuca ##
#  - Descrições: dict_keys(['pururuca', 'pururuca fardo com 25 unidade 50 grama', 'pururuca semi frito', 'pururuca pellet base farinha trigo', 'pururuca 1297'])
#  - 10 tokens mais frequentes: ['pururuca', 'fardo', 'com', '25', 'unidade', '50', 'grama', 'semi', 'frito', 'pellet']
# ** {'25', 'base', 'frito', 'farinha', 'grama', 'semi', 'com', 'pellet', 'trigo', 'pururuca', '1297', '50', 'fardo', 'unidade'} **
#  - 10 tokens mais frequentes nas descrições: [('pururuca', 1.0), ('25', 0.2), ('base', 0.2), ('frito', 0.2), ('farinha', 0.2), ('grama', 0.2), ('semi', 0.2), ('com', 0.2), ('pellet', 0.2), ('trigo', 0.2)]
#  - Média das frequências dos tokens: 0.25714285714285723
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: pururuca ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: pururuca  ----
# ----------------------------------------------------------------------------------------------------
# ## ciment ##
#  - Descrições: dict_keys(['ciment assoc c tiroxina clod', 'ciment cola 20 kilos', 'ciment rest temp ox zinc euge', 'ciment forrado hidro d cal', 'ciment odontologico com 20 ml', 'ciment caii', 'ciment rest prov endo po'])
#  - 10 tokens mais frequentes: ['ciment', 'assoc', 'c', 'tiroxina', 'clod', '20', 'cola', 'kilos', 'rest', 'temp']
# ** {'tiroxina', 'ox', 'caii', 'odontologico', 'd', 'endo', '20', 'kilos', 'euge', 'rest', 'assoc', 'cal', 'c', 'cola', 'com', 'clod', 'forrado', 'po', 'ml', 'hidro', 'ciment', 'zinc', 'temp', 'prov'} **
#  - 10 tokens mais frequentes nas descrições: [('ciment', 1.0), ('20', 0.29), ('rest', 0.29), ('tiroxina', 0.14), ('ox', 0.14), ('caii', 0.14), ('odontologico', 0.14), ('d', 0.14), ('endo', 0.14), ('kilos', 0.14)]
#  - Média das frequências dos tokens: 0.18833333333333335
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: ciment assoc c tiroxina clod ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: ciment 20 rest  ----
# ----------------------------------------------------------------------------------------------------
# ## ultima ##
#  - Descrições: dict_keys(['ultima arvore mundo', 'ultima chance marcelo cezar', 'ultima condicao testemunhar nascimento mito humphreys', 'ultima arvore mundo 1 volume editor scipione', 'ultima musico nicolas sparks', 'ultima flor amarelo caulus ed l pm', 'ultima arvore mundo editor scipione', 'ultima historia antar dormir nicola byrne ed brincar book', 'ultima ceia famoso', 'ultima princesa fabio yabu', 'ultima chance cezar marcelo', 'ultima flor abril', 'ultima garoto pompeia', 'ultima arvore', 'ultima arvore mundo lalau laurabeatriz scpione'])
#  - 10 tokens mais frequentes: ['ultima', 'arvore', 'mundo', 'chance', 'cezar', 'marcelo', 'editor', 'scipione', 'flor', 'condicao']
# ** {'arvore', 'princesa', 'yabu', 'antar', 'byrne', 'famoso', 'scpione', 'condicao', 'ceia', 'ultima', 'mito', 'lalau', 'volume', 'marcelo', 'scipione', 'abril', 'caulus', 'garoto', 'fabio', 'sparks', 'nicolas', 'l', 'nicola', 'pompeia', 'chance', 'mundo', 'cezar', 'dormir', '1', 'testemunhar', 'ed', 'book', 'flor', 'laurabeatriz', 'brincar', 'editor', 'musico', 'pm', 'nascimento', 'historia', 'amarelo', 'humphreys'} **
#  - 10 tokens mais frequentes nas descrições: [('ultima', 1.0), ('arvore', 0.33), ('mundo', 0.27), ('marcelo', 0.13), ('scipione', 0.13), ('chance', 0.13), ('cezar', 0.13), ('ed', 0.13), ('flor', 0.13), ('editor', 0.13)]
#  - Média das frequências dos tokens: 0.11309523809523811
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: ultima arvore mundo ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: ultima arvore mundo marcelo scipione chance  ----
# ----------------------------------------------------------------------------------------------------
# ## line ##
#  - Descrições: dict_keys(['line array 2 12 tu distrito jose almeida', 'line array 2 12 tu', 'line absolute 1 8 dl fiat 2011 2012 pun 186', 'p line array para evento durante ano', 'p line array para festa junino entrar outr', 'line array 2 12 tu sede municipio jaboticatubas', 'p line array c 4 cx lines sub grave para festa durante ano', 'caixa line x 10 400 watt rms driver tu 100 altura 27 cm largura 88 profundidade 37 5 cor barbante com ferragem neces', 'caixa line array com 2 falante 12 drive gargaanta snake', 'caixa line array 6 oneal evo ola 260', 'caixa line array dois ver com divisor interno auto falante 10 polegada medio grave drive 1 polegada guia onda conector duplo peaton gabinete pintura texturizada resistente agua tela perfurar eletrostatico', 'line piccolo 6 insidespeakers', 'caixa line array potencia minimo 350 w'])
#  - 10 tokens mais frequentes: ['line', 'array', '2', '12', 'tu', 'caixa', 'p', 'para', '1', 'distrito']
# ** {'88', 'sede', 'gabinete', 'absolute', '2', 'municipio', 'rms', '5', 'tu', '260', 'array', 'driver', 'watt', 'tela', 'c', 'agua', 'evento', 'outr', 'cx', 'drive', 'insidespeakers', 'profundidade', 'dl', 'eletrostatico', '12', 'piccolo', 'peaton', 'pun', 'line', 'conector', '27', '6', '10', 'falante', 'jose', 'perfurar', 'w', 'evo', 'almeida', '1', 'x', 'ver', 'lines', '100', 'festa', 'altura', '2012', 'junino', '400', 'ferragem', 'duplo', 'para', 'minimo', 'interno', 'jaboticatubas', 'pintura', 'largura', 'potencia', 'cor', 'oneal', '186', 'sub', 'caixa', '350', 'com', 'ano', 'polegada', 'snake', 'divisor', 'fiat', '37', 'barbante', 'medio', 'onda', '8', 'resistente', '2011', 'ola', 'grave', 'entrar', '4', 'auto', 'durante', 'texturizada', 'dois', 'guia', 'neces', 'gargaanta', 'p', 'distrito', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('line', 1.0), ('array', 0.77), ('caixa', 0.38), ('2', 0.31), ('tu', 0.31), ('12', 0.31), ('para', 0.23), ('com', 0.23), ('p', 0.23), ('drive', 0.15)]
#  - Média das frequências dos tokens: 0.12043956043956044
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: line array 2 12 tu distrito jose almeida ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: line array caixa 2 tu 12  ----
# ----------------------------------------------------------------------------------------------------
# ## pirvinio ##
#  - Descrições: dict_keys(['pirvinio 100 mg c 6 pir pan', 'pirvinio 100 mg', 'pirvinio embonato suspensao', 'pirvinio embonato', 'pirvinio 10 mg ml suspensao oral', 'pirvinio 10 mg susp', 'pirvinio pamoato 100 mg dragea', 'pirvinio 100 mg c 6', 'pirvinio pamoato 10 mg ml suspensao oral'])
#  - 10 tokens mais frequentes: ['pirvinio', 'mg', '100', 'c', '6', 'embonato', 'suspensao', 'pir', 'pan', '10']
# ** {'susp', 'suspensao', 'pamoato', 'oral', 'dragea', 'c', 'pir', 'pan', 'mg', 'pirvinio', '100', 'ml', '6', 'embonato', '10'} **
#  - 10 tokens mais frequentes nas descrições: [('pirvinio', 1.0), ('mg', 0.78), ('100', 0.44), ('suspensao', 0.33), ('10', 0.33), ('pamoato', 0.22), ('oral', 0.22), ('c', 0.22), ('ml', 0.22), ('6', 0.22)]
#  - Média das frequências dos tokens: 0.3093333333333334
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: pirvinio 100 mg c 6 pir pan ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: pirvinio mg 100 suspensao 10  ----
# ----------------------------------------------------------------------------------------------------
# ## artoglico ##
#  - Descrições: dict_keys(['artoglico', 'artoglico 1 5 g', 'artoglico 755', 'artoglico glicosamina 1 5 g', 'artoglico po oral 30 sch 1 5 sigma', 'artoglico 1 5 grama', 'artoglico 1 5 caixa com 30 sache', 'artoglico atendimento processo judicial', 'artoglico 1 5 grama sache g po or ct x 3 95', 'artoglico 1 5 sache', 'artoglico 1 5 grama sache', 'artoglico glicosamina 1 5 g caixa com 30 sache'])
#  - 10 tokens mais frequentes: ['artoglico', '1', '5', 'g', 'sache', '30', 'grama', 'po', 'caixa', 'com']
# ** {'sigma', 'oral', 'judicial', 'or', 'glicosamina', 'artoglico', '5', '3', 'grama', 'processo', '1', 'sch', 'caixa', 'atendimento', 'x', 'com', 'po', 'ct', '755', '95', '30', 'sache', 'g'} **
#  - 10 tokens mais frequentes nas descrições: [('artoglico', 1.0), ('5', 0.75), ('1', 0.75), ('sache', 0.42), ('g', 0.33), ('grama', 0.25), ('30', 0.25), ('glicosamina', 0.17), ('caixa', 0.17), ('com', 0.17)]
#  - Média das frequências dos tokens: 0.23434782608695653
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: artoglico ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: artoglico 5 1 sache g grama  ----
# ----------------------------------------------------------------------------------------------------
# ## celin ##
#  - Descrições: dict_keys(['celin pvc 150 mm x 100 para esgoto', 'celin pvc', 'celin pvc 150 mm x 100 para esgoto ocre', 'celin ceramico 4 polegada 100 mm 90 ele', 'celin pvc 200 mmx 150 mm para ocre', 'celin ceramico 6 150 mm polegada 90', 'celin ceramico 150 100 mm', 'celin ceramico 8 polegada 45', 'celin ceramico 8 polegada 90', 'celin pvc 200 mm x 150 para ocre', 'celin ceramico 4 100 mm polegada 90', 'celin ceramico 6 150 mm polegada 45', 'celin ceramico 4 100 mm polegada 45', 'celin ceramico 4 polegada 100 mm 45 ele'])
#  - 10 tokens mais frequentes: ['celin', 'mm', 'pvc', '150', '100', 'para', 'ceramico', 'x', 'polegada', 'esgoto']
# ** {'ocre', '4', 'mmx', 'esgoto', 'pvc', '6', '45', 'ceramico', 'ele', '150', '90', 'celin', 'x', 'mm', '100', 'polegada', '200', '8', 'para'} **
#  - 10 tokens mais frequentes nas descrições: [('celin', 1.0), ('mm', 0.79), ('ceramico', 0.64), ('polegada', 0.57), ('150', 0.5), ('100', 0.5), ('pvc', 0.36), ('4', 0.29), ('45', 0.29), ('90', 0.29)]
#  - Média das frequências dos tokens: 0.3531578947368421
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: celin pvc 150 mm x 100 para esgoto ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: celin mm ceramico polegada 150 100  ----
# ----------------------------------------------------------------------------------------------------
# ## matacao ##
#  - Descrições: dict_keys(['matacao', 'matacao pedra metro', 'matacao ardosia 8 cm placa 2 20 m x 1 40 com frete incluir'])
#  - 10 tokens mais frequentes: ['matacao', 'pedra', 'metro', 'ardosia', '8', 'cm', 'placa', '2', '20', 'm']
# ** {'m', '40', '1', 'ardosia', 'x', 'frete', 'placa', '8', 'com', 'matacao', 'metro', '20', 'incluir', 'pedra', '2', 'cm'} **
#  - 10 tokens mais frequentes nas descrições: [('matacao', 1.0), ('m', 0.33), ('40', 0.33), ('1', 0.33), ('ardosia', 0.33), ('x', 0.33), ('frete', 0.33), ('placa', 0.33), ('8', 0.33), ('com', 0.33)]
#  - Média das frequências dos tokens: 0.37187500000000007
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: matacao ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: matacao  ----
# ----------------------------------------------------------------------------------------------------
# ## belimumabe ##
#  - Descrições: dict_keys(['belimumabe 400 mg', 'belimumabe 120 mg po liofilizar para infusao intravenoso frasco ampola', 'belimumabe principio ativo concentracao dosagem 120 mg forma farmaceutico solucao injetavel apresentacao frasco acoplar po liofilizar componente', 'belimumabe 400 mg biologico', 'belimumabe 120 mg', 'belimumabe 120 mg po liofilizar', 'belimumabe 400 mg ms benlysta br0427614 po liofilo para injetavel frasco ampola', 'belimumabe 400 mg po liofilizar para solucao infusao intravenoso', 'belimumabe 400 mg atendimento processo judicial', 'belimumabe 400 mg po liofilizar para infusao intravenoso frasco ampola', 'belimumabe 120 mg frasco', 'belimumabe 400 mg po liofilo injetavel'])
#  - 10 tokens mais frequentes: ['belimumabe', 'mg', '400', 'po', '120', 'liofilizar', 'frasco', 'para', 'infusao', 'intravenoso']
# ** {'dosagem', 'solucao', 'judicial', 'acoplar', 'principio', 'biologico', 'apresentacao', 'ms', 'liofilo', 'frasco', 'mg', '120', 'farmaceutico', 'processo', 'atendimento', 'liofilizar', 'po', 'forma', 'concentracao', 'ampola', 'belimumabe', 'ativo', 'componente', '400', 'br0427614', 'infusao', 'benlysta', 'intravenoso', 'para', 'injetavel'} **
#  - 10 tokens mais frequentes nas descrições: [('mg', 1.0), ('belimumabe', 1.0), ('po', 0.58), ('400', 0.58), ('frasco', 0.42), ('120', 0.42), ('liofilizar', 0.42), ('para', 0.33), ('ampola', 0.25), ('infusao', 0.25)]
#  - Média das frequências dos tokens: 0.2456666666666667
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: belimumabe 400 mg ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: mg belimumabe po 400 frasco 120  ----
# ----------------------------------------------------------------------------------------------------
# ## linho ##
#  - Descrições: dict_keys(['tecido linho com 1 50 m largura cor variar', 'tecido linho cor variar 1 40 largura', 'linho 2 0 com agulha', 'tecido linho cor variar 140 largura peca 50 mts', 'tecido linho com 1 50 m largura', 'linho xadrez', 'linho 2 0 sem agulha', 'linho', 'linho cor branco 2018', 'tecido linho puro grosso liso cor variar', 'linho cor branco 2020', 'linho cor branco 2019'])
#  - 10 tokens mais frequentes: ['linho', 'cor', 'tecido', 'largura', 'variar', '50', 'com', '1', 'm', '2']
# ** {'sem', 'tecido', '2', '50', '0', 'largura', '2018', 'mts', 'grosso', 'variar', 'cor', 'puro', '40', 'm', '2020', '1', '2019', 'com', 'liso', 'peca', 'branco', 'agulha', 'linho', 'xadrez', '140'} **
#  - 10 tokens mais frequentes nas descrições: [('linho', 1.0), ('cor', 0.58), ('tecido', 0.42), ('largura', 0.33), ('variar', 0.33), ('50', 0.25), ('1', 0.25), ('com', 0.25), ('branco', 0.25), ('2', 0.17)]
#  - Média das frequências dos tokens: 0.21200000000000002
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: tecido linho com 1 50 m largura cor variar ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: linho cor tecido largura variar 50  ----
# ----------------------------------------------------------------------------------------------------
# ## colherzinha ##
#  - Descrições: dict_keys(['colherzinha descartavel', 'colherzinha sorvete descartavel', 'colherzinha plastico descartavel tamanho medio pct c 100 unidade pacote com', 'colherzinha descartavel sobremesa cor variar com 100 unid', 'colherzinha plastico com 50 unid', 'colherzinha medio 50 unidade cada pacote', 'colherzinha descartavel sobremesa', 'colherzinha para alimentacao infantil todo silicone'])
#  - 10 tokens mais frequentes: ['colherzinha', 'descartavel', 'com', 'plastico', 'medio', '100', 'unidade', 'pacote', '50', 'unid']
# ** {'tamanho', 'todo', 'unid', 'pacote', 'plastico', 'cada', '50', 'sorvete', 'variar', 'colherzinha', 'cor', 'silicone', 'descartavel', 'pct', 'infantil', 'c', 'com', '100', 'unidade', 'medio', 'para', 'alimentacao', 'sobremesa'} **
#  - 10 tokens mais frequentes nas descrições: [('colherzinha', 1.0), ('descartavel', 0.62), ('com', 0.38), ('unid', 0.25), ('pacote', 0.25), ('plastico', 0.25), ('50', 0.25), ('100', 0.25), ('unidade', 0.25), ('medio', 0.25)]
#  - Média das frequências dos tokens: 0.2365217391304348
# ESTRATÉGIA DESCRIÇÃO MAIS FREQUENTE: colherzinha descartavel ----
# ESTRATÉGIA TOKENS MAIS FREQUENTES: colherzinha descartavel com unid pacote plastico  ----
# ----------------------------------------------------------------------------------------------------

# %%
for group, descriptions in groups_descriptions.items():
    descriptions = list(descriptions)
    print(f'## Grupo {group} ##')
    print(f'Descrição mais frequente: {descriptions[0]}')
    print(f'Próximas 5 descrições mais frequentes: {descriptions[1:6]}')
    print('-'*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-9c6cc571c4e4> in <module>
# ----> 1 for group, descriptions in groups_descriptions.items():
#       2     descriptions = list(descriptions)
#       3     print(f'## Grupo {group} ##')
#       4     print(f'Descrição mais frequente: {descriptions[0]}')
#       5     print(f'Próximas 5 descrições mais frequentes: {descriptions[1:6]}')
#
# NameError: name 'groups_descriptions' is not defined

# %%
# distribuição da quantidade de tokens nas descrições mais frequentes
# distribuição da proporção das descrições mais frequentes
# média da quantidade de tokens nas descrições
