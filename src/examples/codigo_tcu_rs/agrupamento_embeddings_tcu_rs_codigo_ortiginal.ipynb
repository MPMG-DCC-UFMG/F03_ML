# %%
import pandas as pd
import numpy as np
import collections
import copy
import random
import matplotlib.pyplot as plt
import time
import multiprocessing
import nltk
import pickle
import hdbscan
from item.item_list import (
    ItemList,
    Item
)
from nlp.word_embeddings import (
    load_word_embeddings,
    get_item_embedding,
    get_items_embeddings
)

from nlp.preprocessing import (
    clean_text,
    preprocess,
    tokenize,
    preprocess_document,
    tokenize_document,
    get_stopwords, 
    lemmatization_document,
    get_canonical_words)

from nlp.pos_tagging import (
    get_tokens_tags
)
from item.spellcheckeropt import SpellcheckerOpt
from item.utils import get_tokens_set
from textpp_ptbr.preprocessing import TextPreProcessing as tpp

# Import xmeans through pyclustering library:
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer;
from pyclustering.cluster.xmeans import xmeans

# Import agglomerative clustering through scikit learn library:
from sklearn.cluster import AgglomerativeClustering

# Import agglomerative clustering through pyclustering library:
from pyclustering.cluster.agglomerative import agglomerative

# Import OPTICS through pyclustering library:
from pyclustering.cluster.optics import optics

# Import DBSCAN through pyclustering library:
from pyclustering.cluster.dbscan import dbscan

# %% [markdown]
# ### pre processamento

# %%
file1 = '../dados/itens_pregao_pitem_saude.csv'
print(file1)
#items = get_items(file1)
items = pd.read_csv(file1,sep=';')
items.head()
# Out:
# ../dados/itens_pregao_pitem_saude.csv
#    seq_dim_licitacao  num_exercicio   nom_entidade  seq_dim_item  \
# 0            1191385           2018         Viçosa      43920427
# 1            1007594           2018       Bocaiúva      29874027
# 2            1162895           2015      Tarumirim      41678884
# 3            1043060           2018         Divino      32584279
# 4            1021726           2015  Capitão Enéas      30957949
#
#                                             nom_item dsc_unidade_medida  \
# 0                                 COLAGENASE 0,6UI/G            UNIDADE
# 1                         CAMPO OPERATÓRIO 45CMX50CM                PCT
# 2                                            KIT PET            UNIDADE
# 3                     TINTA RELEVO PARA TECIDO BRAN.              CAIXA
# 4  Termômetro clínico digital portátil para medir...            UNIDADE
#
#                                       nom_item_busca  vlr_quantidade  \
# 0                                 COLAGENASE 0,6UI/G          1000.0
# 1                         CAMPO OPERATORIO 45CMX50CM           200.0
# 2                                            KIT PET            10.0
# 3                     TINTA RELEVO PARA TECIDO BRAN.            50.0
# 4  TERMOMETRO CLINICO DIGITAL PORTATIL PARA MEDIR...            30.0
#
#    vlr_unitario_homologado nom_funcao  vlr_licitacao
# 0                     8.97      Saúde     2641219.40
# 1                   161.77      Saúde     2648990.10
# 2                    71.42      Saúde       44405.66
# 3                    24.45      Saúde     2389162.06
# 4                    10.90      Saúde      794927.97

# %%
len(items)
# Out:
# 1728629

# %% [raw]
# #stopwords possivelmente relevantes
# #para, com, não, mais, muito, só(?), sem, mesmo, mesma, há, haja, hajam, houver, houverá, seja, sejam,
# #fosse, fossem, forem, será, serão, seria, seriam, tem, tinha, teve, tinham, tenha, tiver, tiverem, terá,
# #terão, teria, teriam, uma, mais, entre

# %%
#import nltk
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /dados01/workspace/ufmg.f01dcc/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pdb
items_descriptions = []
stopwords_ = get_stopwords()

#nao aplicar forma canonica inicialmente
#canonical_form, word_class = get_canonical_words()

#items['dsc_unidade_medida'] = list(map(lambda x : x.lower(), items['dsc_unidade_medida'].astype(str)))

items['unid_proc'] = list(map(lambda x : preprocess_document(x, remove_numbers=False,stopwords=None)
                                     , items['dsc_unidade_medida'].astype(str)))

items['desc_proc'] = list(map(lambda x : preprocess_document(x, remove_numbers=False,stopwords=None)
                                     , items['nom_item_busca'].astype(str)))

items['desc_token'] = items['desc_proc'].apply(tokenize_document)
                        
items[['nom_item','desc_proc','desc_token','unid_proc']]
    
    
# for item in items: 
#     pdb.set_trace()
#     description = item[0]
#     price = item[1]
#     dsc_unidade = item[2]
#     if type(dsc_unidade) == str:
#         dsc_unidade = tpp.remove_accents(dsc_unidade.lower())
        
#     doc = preprocess_document(description, remove_numbers=False)
#     doc = tokenize_document(doc, stopwords_)
# #     doc = lemmatization_document(doc, canonical_form)
#     items_descriptions.append((doc, price, dsc_unidade, description))
# Out:
#                                                   nom_item  \
# 0                                       COLAGENASE 0,6UI/G
# 1                               CAMPO OPERATÓRIO 45CMX50CM
# 2                                                  KIT PET
# 3                           TINTA RELEVO PARA TECIDO BRAN.
# 4        Termômetro clínico digital portátil para medir...
# ...                                                    ...
# 1728624  BANNER EM LONA COM IMPRESSÃO COLORIDA DIGITAL,...
# 1728625  Jaleco branco longo em microfibra 100% poliest...
# 1728626         CARGA DE CILINDROS DE AR COMPRIMIDO DE 8M3
# 1728627                                              MOCHO
# 1728628                        LAJE PRE MOLDADA PARA FORRO
#
#                                                  desc_proc  \
# 0                                     colagenase 0 6 ui g
# 1                          campo operatorio 45 cm x 50 cm
# 2                                                 kit pet
# 3                           tinta relevo para tecido bran
# 4         termometro clinico digital portatil para medi...
# ...                                                    ...
# 1728624   banner em lona com impressao colorida digital...
# 1728625   jaleco branco longo em microfibra 100 poliest...
# 1728626      carga de cilindros de ar comprimido de 8 m 3
# 1728627                                             mocho
# 1728628                       laje pre moldada para forro
#
#                                                 desc_token         unid_proc
# 0                                [colagenase, 0, 6, ui, g]          unidade
# 1                   [campo, operatorio, 45, cm, x, 50, cm]              pct
# 2                                               [kit, pet]          unidade
# 3                      [tinta, relevo, para, tecido, bran]            caixa
# 4        [termometro, clinico, digital, portatil, para,...          unidade
# ...                                                    ...               ...
# 1728624  [banner, em, lona, com, impressao, colorida, d...              und
# 1728625  [jaleco, branco, longo, em, microfibra, 100, p...               un
# 1728626  [carga, de, cilindros, de, ar, comprimido, de,...               un
# 1728627                                            [mocho]          unidade
# 1728628                  [laje, pre, moldada, para, forro]   metro quadrado
#
# [1728629 rows x 4 columns]

# %%
#REMOVENDO SERVICOS

items_sem_servico = items[~((items['unid_proc'].str.contains('serv')) 
                            | (items['desc_proc'].str.contains('serv'))
                            | (items['desc_proc'].str.contains('prest')))]

# %%
# count = 0
# stopwords_ = get_stopwords()
# not_str = 0

# for item in items_descriptions:
#     dsc_unidade = item[2]
#     if type(dsc_unidade) == str:
#         tokens = tokenize_document(dsc_unidade)
#         flag = False
#         for tok in tokens:
#             if tok == 'servico' or tok == 'prestacao':
#                 flag = True
#                 break
#         if flag:
#             count += 1
#     else:
#         not_str += 1

# count

# %%
#Criando a classe de items
#ao inves de armazenar a descricao original estou armazenando a descricao original tokenizada
#estou fazendo isso para implementar a versão original da proposta do TCU de fazer a media dos
#embeddinds ponderada pela posicao que o item aparece na descricao
items_descriptions = items_sem_servico[['desc_token','vlr_unitario_homologado','unid_proc','desc_token']].values
itemlist = ItemList()
itemlist.load_items_from_list(items_descriptions)

# %%
itemlist.size
# Out:
# 1667928

# %%
itemlist.save_items('../dados/items_preprocessed_teste_tcu')

# %% [markdown]
# # Initial test:

# %%
#  word embeddings file, each line contains an embedding
word_embeddings_file = '../../../embeddings/cbow_s50.txt'

# %%
# read word embeddings from file and store them in a map
word_embeddings = load_word_embeddings(word_embeddings_file)

# %%
# It gets the descpitons processed:
itemlist2 = ItemList()
itemlist2.load_items_from_file('../dados/items_preprocessed_teste_tcu.zip', just_words=False)

# %%
# It gets the descpitons processed:
#itemlistcomplete = ItemList()
#itemlistcomplete.load_items_from_file('../dados/items_preprocessed.zip', just_words=False)

# %%
# Get all tokens 
items_words_complete = [x.original for x in itemlist.items_list]

# %%
items_words_complete = [x.original for x in itemlist2.items_list]

# %%
itemlist2.items_list
# Out:
# [<item.item.Item at 0x7fc0a11c1d90>,
#  <item.item.Item at 0x7fc0a1506ad0>,
#  <item.item.Item at 0x7fc0a11c1fd0>,
#  <item.item.Item at 0x7fc0a1567d90>]

# %%
items_words_complete[:5]
# Out:
# [['colagenase', '0', '6', 'ui', 'g'],
#  ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm'],
#  ['kit', 'pet'],
#  ['tinta', 'relevo', 'para', 'tecido', 'bran'],
#  ['termometro',
#   'clinico',
#   'digital',
#   'portatil',
#   'para',
#   'medir',
#   'temperatura',
#   'com',
#   'leitura',
#   'digital',
#   'em',
#   'escala',
#   'celsius']]

# %%
# Get the tags of tokens descriptions
word_class = get_tokens_tags()

# %%
# Build the vector representation for an item using the word embeddings
#TODO o que eh um embbeding_type??? seria a classe gramatical a ser usada?

def get_item_embedding_weighted(document, word_embeddings, word_class, embedding_type=None,
                       embedding_size=50):

    item_embedding = np.zeros(embedding_size)
    num_tokens = len(document)
    peso_acum = 0
    
    for pos,token in enumerate(document):
        if token in word_embeddings:
            if embedding_type == None:
                #media ponderada pela posicao
                #decresce linearmente
                item_embedding += (1-(pos/num_tokens))*np.array(word_embeddings[token])
                peso_acum += (1-(pos/num_tokens))
            elif token in word_class and word_class[token] in set(embedding_type):
                item_embedding += (1-(pos/num_tokens))*np.array(word_embeddings[token])
                peso_acum += (1-(pos/num_tokens))

    if peso_acum != 0:
        item_embedding /= peso_acum

    return item_embedding


def get_items_embeddings_weighted(documents, word_embeddings, word_class, embedding_type=None,
                         embedding_size=50, type='list'):

    if type == 'list':
        documents_embeddings = []
    elif type == 'dict':
        documents_embeddings = {}

    id = 0
    for doc in documents:
        if type == 'list':
            documents_embeddings.append(list(get_item_embedding(doc, word_embeddings,
                                                    word_class, embedding_type)))
        elif type == 'dict':
            documents_embeddings[id] = list(get_item_embedding(doc, word_embeddings,
                                                    word_class, embedding_type))
        id += 1

    return documents_embeddings

# %%
items_embeddings = get_items_embeddings_weighted(items_words_complete, word_embeddings, word_class)

# %%
# It gets the first tokens of each description and groups
# based on this approach:
#groups = itemlist.get_first_token_groups(just_words=True)

# %%
# HDBSCAN

# %%
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import normalize

sample_ids = random.sample(list(range(0,len(items_embeddings))),50000)            
sampled_items_emb = [items_embeddings[x] for x in sample_ids]
sampled_items_emb_norm = normalize(sampled_items_emb, norm='l2')

#sampled_items_emb_dist = pairwise_distances(sampled_items_emb,metric='cosine')

# %%
hdb_clusterer = hdbscan.HDBSCAN(metric='euclidean',min_cluster_size=30, n_jobs=8)
hdb_clusterer.fit(sampled_items_emb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-5c4e518237f7> in <module>
#       1 hdb_clusterer = hdbscan.HDBSCAN(metric='euclidean',min_cluster_size=30, n_jobs=8)
# ----> 2 hdb_clusterer.fit(sampled_items_emb)
#
# ~/py37/lib/python3.7/site-packages/hdbscan/hdbscan_.py in fit(self, X, y)
#     917          self._condensed_tree,
#     918          self._single_linkage_tree,
# --> 919          self._min_spanning_tree) = hdbscan(X, **kwargs)
#     920
#     921         if self.prediction_data:
#
# ~/py37/lib/python3.7/site-packages/hdbscan/hdbscan_.py in hdbscan(X, min_cluster_size, min_samples, alpha, cluster_selection_epsilon, metric, p, leaf_size, algorithm, memory, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, cluster_selection_method, allow_single_cluster, match_reference_implementation, **kwargs)
#     613                                              approx_min_span_tree,
#     614                                              gen_min_span_tree,
# --> 615                                              core_dist_n_jobs, **kwargs)
#     616         else:  # Metric is a valid BallTree metric
#     617             # TO DO: Need heuristic to decide when to go to boruvka;
#
# ~/py37/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/py37/lib/python3.7/site-packages/hdbscan/hdbscan_.py in _hdbscan_boruvka_kdtree(X, min_samples, alpha, metric, p, leaf_size, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, **kwargs)
#     272         X = X.astype(np.float64)
#     273
# --> 274     tree = KDTree(X, metric=metric, leaf_size=leaf_size, **kwargs)
#     275     alg = KDTreeBoruvkaAlgorithm(tree, min_samples, metric=metric,
#     276                                  leaf_size=leaf_size // 3,
#
# sklearn/neighbors/_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.__init__()
#
# sklearn/neighbors/_dist_metrics.pyx in sklearn.neighbors._dist_metrics.DistanceMetric.get_metric()
#
# TypeError: __init__() got an unexpected keyword argument 'n_jobs'

# %%
from collections import Counter
Counter(hdb_clusterer.labels_)
#items_words[sample_ids[x]] for x in hdb_clusterer.labels_ if x == 10]
# Out:
# Counter({-1: 47435,
#          8: 54,
#          2: 130,
#          15: 178,
#          19: 58,
#          0: 101,
#          20: 58,
#          12: 337,
#          11: 116,
#          26: 215,
#          27: 59,
#          13: 297,
#          5: 36,
#          1: 203,
#          14: 79,
#          3: 53,
#          23: 39,
#          21: 35,
#          9: 96,
#          4: 57,
#          18: 82,
#          17: 34,
#          6: 36,
#          25: 34,
#          7: 33,
#          22: 46,
#          10: 36,
#          24: 32,
#          16: 31})

# %%
samp_desc = [items_words_complete[x] for x in sample_ids]
df_teste = pd.DataFrame(data={'cluster':hdb_clusterer.labels_, 'desc':samp_desc})
df_teste.to_csv('../dados/resultados_teste_tcu/hdbscan_emb_50.csv',index=False,sep=';')

# %%
print(len(df_teste.cluster.unique()),' Clusters')
# Out:
# 29  Clusters

# %%
sorted([" ".join(items_words_complete[sample_ids[pos]]) for pos,x in enumerate(hdb_clusterer.labels_) if x == -1])
# Out:
# ['0 esfignomanometro infantil',
#  '1 0 detergente liguido neutro 500 ml',
#  '1 00 coco ralado desidratado de 100 gr',
#  '1 00 gas de cozinha 13 kg recarga',
#  '1 00 soja grao pcte c 500 grs',
#  '1 004 pia de granito 2 00 mt',
#  '1 0050 maderite cola branca 6 mm 1 10 x 2 20',
#  '1 0054 cabo de bisturi inox n 3',
#  '1 0056 azatioprina 50 mg similar',
#  '1 0076 filtro para agua de barro com tampa',
#  '1 0080 pano de chao',
#  '1 0094 descartex 13 litros com 10 unidades',
#  '1 0099 papel grau cirurgico 20 cm x 100 m',
#  '1 0115 caixa organizadora de 20 litros',
#  '1 0124 travessa de vidro com tampa grande',
#  '1 0133 parafuso atarrachante 2 9 x 19',
#  '1 0147 parafuso atarrachante 4 8 x 38',
#  '1 0157 telha amianto 110 x 220',
#  '1 0168 parafuso frances 1 2 x 6',
#  '1 0169 cesto de lixo 15 litros sem tampa',
#  '1 0169 fluido de freio 500 ml honoropolis',
#  '1 0171 dimenidrato piridoxina 50 50 mg ml similar',
#  '1 0200 escitalopram 10 mg similar',
#  '1 021 tubo ponta azul',
#  '1 0227 cabo elet 35 mm rolo 100 mt',
#  '1 0230 parafuso madeira cabeca chata 3 2 x 16',
#  '1 0266 mouse otico com netscrol ps 2',
#  '1 0273 insulina glargina 3 ml biologico',
#  '1 028 maionese 500 g',
#  '1 0288 parafuso rosca soberba 3 8 x 80',
#  '1 03 cimetida cloridrato 150 mg ml solucao in',
#  '1 0300 levonorgestrel 15 mg similar',
#  '1 0300 saponacio em po',
#  '1 0305 parafuso sextavado s porca 3 8 x 11 2',
#  '1 0307 lidocaina 2 s v 20 ml similar',
#  '1 0319 mebendazol 20 mg ml similar',
#  '1 032 ranitidina sodica 25 mg 2 ml',
#  '1 0345 tabua roxinho 30 cm largura',
#  '1 0375 lamina bisturi carb n 12',
#  '1 0376 noretisterona 35 mg similar',
#  '1 040 sabonete pequeno',
#  '1 041 agulha descartavel p coleta a vacuo cx c 100 un 25 x 0 8 mm',
#  '1 0419 prometazina 25 mg similar',
#  '1 0420 prometazina 50 mg 2 ml similar',
#  '1 0427 ranibizumabe 2 3 mg biologico',
#  '1 0440 termometro clinico prismatico',
#  '1 045 telha amianto 366 x 110 x 6 mm 48 8 kg pc',
#  '1 045 valvula inox pia americana',
#  '1 0462 luva latex tamanho p',
#  '1 0481 tramadol 50 mg similar',
#  '1 0494 alcool absoluto 99 1 lt',
#  '1 0497 prego 19 x 36',
#  '1 050 amendoim 500 gr',
#  '1 0503 prego 8 x 8',
#  '1 0513 gelatina em po diet 12 gramas',
#  '1 0541 bamboles cores variadas',
#  '1 0547 fita micropore cor branco 5 x 10 m',
#  '1 0548 fita micropore cor pele 10 x 10 m',
#  '1 0558 corrente 3 8',
#  '1 058 etinilestradiol 0 3 mg levonorgestrel',
#  '1 059 detergente sabao liquido 1 qualidade',
#  '1 0597 registro 3 4 com acabamento',
#  '1 0603 termistor mp 1500',
#  '1 0611 toner brother 9010 black',
#  '1 064 esponja dupla face',
#  '1 066 copo para oxigenio completo',
#  '1 066 fluoxetina 20 mg',
#  '1 0660 luva para procedimento g',
#  '1 067 copo umidificador com mascara completo',
#  '1 067 copo umidificador com mascara completo',
#  '1 0674 proteinas totais',
#  '1 068 disjuntor unipolar 25 a',
#  '1 0706 serra copo compativel ou similar irwin',
#  '1 0712 recarga para botijao de gas de cozinha',
#  '1 0734 estante aco',
#  '1 0736 sifao p pia americana gold flex',
#  '1 0742 martelo 29 mm',
#  '1 075 micronebulizador ar comprimido h amar in',
#  '1 0756 sist x interruptor 1 inte c t',
#  '1 0758 sist x tomada red 2 tomada',
#  '1 077 cha',
#  '1 077 fita de empacotar 48 x 45',
#  '1 080 fio rigido 4 mm',
#  '1 0801 rolo la para pintura 23 cm',
#  '1 0833 algodao caixa de',
#  '1 0866 tee marrom sold 50 mm',
#  '1 0945 grampos de isolamento n 201',
#  '1 0949 tijolo refratario lajota 25 mm',
#  '1 0956 limas 1 serie 15 40',
#  '1 0969 tinta guache c 6 unid 15 ml',
#  '1 agente de uniao multi uso fotopolimerizavel',
#  '1 alcool combustivel',
#  '1 alicate 109',
#  '1 alicate 114',
#  '1 alicate amarril com widear ref qo',
#  '1 anel elastico p ligadura',
#  '1 anel elastico para ligadura dourado',
#  '1 arco intraoral niti pequeno',
#  '1 arco pre contornado 0 16 aco inf 50 70 2',
#  '1 arco pre contornado 0 20 supereior aco cr ni',
#  '1 arco pre contornado niti 0 14 inferior',
#  '1 arco pre contornado niti 0 16 inferior',
#  '1 arco pre contornado niti 0 17 x 0 25 superior',
#  '1 arco pre contornado retangular niti 0 19 x 25',
#  '1 banda bl 30',
#  '1 banda bl reposicao 38 pct c 10',
#  '1 banda bl reposicao 41 1 2 pct c 10',
#  '1 banda bl reposicao 41 pct c 10',
#  '1 banda bl reposicao 42 pct c 10',
#  '1 banda bl reposicao nr 33 ref',
#  '1 banda para molar bu 30 1 2',
#  '1 banda pre molar no 28',
#  '1 braquete',
#  '1 braquete inf sem gancho',
#  '1 braquete reposicao ref',
#  '1 braquete sup',
#  '1 broca carbide alta rotacao fg 245 cone invertida',
#  '1 broca carbide esfer alta rotacao nr 6',
#  '1 broca carbide esferica ca no 2',
#  '1 broca diam fg 3 e 4 serie kgs 3200',
#  '1 broca ponta arkansas ca esferica',
#  '1 broca tipo gates no 3 19 mm',
#  '1 brunidor para amalgama no 29',
#  '1 cabo comando n',
#  '1 calcador ward 3105 no 2',
#  '1 calcador ward inox no 1',
#  '1 canula de traqueostomia metal 40',
#  '1 canula de traqueostomia metal no 6',
#  '1 compasso de willis',
#  '1 condensador 6332 no 1',
#  '1 condensador duplo p amalgama hollemback no 2',
#  '1 cone de papel absorvente 45 a 80',
#  '1 cureta de gracey 7 8',
#  '1 eixo coluna direcao antigo f4000',
#  '1 escova dental cabo reto cerdas macias em plano',
#  '1 esculpidor hollemback 3 s',
#  '1 espacador condensador tipo max spaden 25 mm',
#  '1 frasco coletor de urina adulto esteril',
#  '1 gasolina comum litro',
#  '1 gesso pedra tipo iii pct c 1 kg',
#  '1 grampo no 201 para isolamento absoluto',
#  '1 grampo no w 8 a para isolamento absoluto',
#  '1 lactulose 667 mg ml xarope frasco 120 mililitr',
#  '1 lima waveone gold primary reciprocante file c',
#  '1 mandril de parafuso para pm para montar discos',
#  '1 matriz de aco inox para amalgama 5 mm',
#  '1 medico plantao ambulatorial de 12 horas presencial noturno ou diurno',
#  '1 mega de velocidade ilimitado zoonoses',
#  '1 mesa de escritorio base aco ferro pintado',
#  '1 mesa de escritorio formato l',
#  '1 mesa de escritorio medindo 1 37 x 0 70 x 0 74',
#  '1 mola onibus marcopolo volare v 8 l',
#  '1 moldeira plastica superior e inferior no5 verde',
#  '1 nortriptilina cloridrato 25 mg capsula',
#  '1 oleo lubrificante p alta rotacao c spray',
#  '1 papel carbono p articulacao ultrafino',
#  '1 papel grau cirurgico 40 cm largura rolo c 100 m',
#  '1 pedra pomes pct 1 kg',
#  '1 pinca clinica perry',
#  '1 pinca de algodao no 315',
#  '1 pinca de algodao no 317',
#  '1 placa com garrote aparelho com garrote para in',
#  '1 placa power drive',
#  '1 placa power suplly',
#  '1 recarga de oxigenio medicinal acondicionados 9',
#  '1 resina na co rb1 fotopolimerizavel',
#  '1 resina na cor a1',
#  '1 seringa p anestesico em tubos modelo carpule',
#  '1 switch de 8 portas',
#  '1 switch tipo gerenciavel layer 3',
#  '1 tira de poliester para resina 0 5 mm cx c 50 un',
#  '1 tubo hematologia edta k3 4 0 ml tubo para coleta de sangue a vacuo com trava de seguranca em pet tamanho 13 x 75 mm esteril descartavel incolor com edta k3 volume 4 0 ml com tampa de borracha siliconizada e capa protetora de rosca na cor roxa apres',
#  '1 tubo segundo molar',
#  '10 10 teminal hidraulico',
#  '100 x 1 1 x 0 220 x 320 sulfite aa 75 g',
#  '100 x 1 ficha de puericultura',
#  '100 x 1 receituario medico',
#  '100 x 1 solicitacao exames laboratoriais',
#  '100 x 1 visita domiciliar',
#  '101 cadeira material de confeccao aco ferro pintado rodizios nao possui bracos nao possui regulagem de altura nao possui assento encosto polipropileno dimensoes minimas altura do assento ao chao minimo de 45 cm capacidade ate 110 kg',
#  '104 disco diamantado economico umido 110 mm diamante',
#  '104 rolamento gaiola piloto',
#  '105 ficha ficha de notificacao de febre tifoide impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '107 curva de pvc ocre je pb 90 o x dn 150 com anel 1500 pa',
#  '108 indicador para controle biologico de esterrlizacao a vapor teste rapido leitura final em 48 horas composto de ampola plastica contendo tira de papel impregnada por esporos de bacilus stearothermophilus e sepradas no meio de cultura tampa plastica co',
#  '108 monitor led 19 5 tipo de monitor led tamanho da tela 19 5 resolucao maxima 1366 x 768 pixel pitch 0 3177 x 0 307 brilho 200 cd m2 angulo de visao 90 65 tempo de resposta 5 ms pedestal incluso sim conexoes d sub cor do produto preto voltagem bivolt conteudo da embalagem 1 monitor 23 m 37aa b awz acessorios cabo d sub ac adapter manual do usuario cd software dual smart solution dimensoes aproximadas do produto cm axlxp 35 7 x 46 3 x 16 8 cm dimensoes aproximadas da embalagem do produto cm axlxp 35 3 x 53 4 x 11 1 cm peso liq aproximado do produto kg 2 2 kg peso aproximado da embalagem c produto kg 3 1 kg garantia do fornecedor 12 meses',
#  '109 folha de cartolina branca',
#  '11 0 sal refinado iodado de cozinha 1 kg',
#  '11 00 alcool acido 3 500 ml',
#  '11 0008 pneu novo 1000 x 20 16 lonas liso',
#  '11 0013 plug p4 femea pacote com 10 unidades',
#  '11 012 papel laminado 45 x 59 pacote com 40 un',
#  '11 03 telhas amianto 3 66 x 1 10',
#  '11 05 bolacha de sal',
#  '11 092 sulfato ferroso gotas 25 mg ml solucao',
#  '11 armario de cozinha aereo em aco com 3 tres portas de abrir com dobradicas de pressao dimensao l 105 cm largura p 28 cm a 55 cm',
#  '11 camisa decote v maior malha',
#  '11 carne suina lombo',
#  '11 cera liquida incolor',
#  '11 destacador p tampas de tubo ref',
#  '11 enalapril maleato comprimido 20 mg',
#  '11 tambor p gaze de aco inoxidavel ref 28 29 0',
#  '110 papel grau cirurgico 20 x 100 m bobinas lisas produzidas em papel grau cirurgico e filme laminado poliester polipropileno indicado para esterilizacao em autoclave a vapor ou oxido de etileno permeavel ao vapor e ao ar impermeavel a microorganismo resistentes ao calor livres de nutrientes microbianos e residuos toxicos dotado de indicadores quimicos que mudam de cor apos o processo de esterilizacao bobinas de 20 x 100 metros',
#  '111 0 tijolos 9 x 19 x 24',
#  '111 broca de alta rotacao diamantada n 1031',
#  '1114 tinta latex 18 litros 2 linha',
#  '1118 nistatina susp oral 50 ml',
#  '112 0002 ondansentrona cloridrato 8 mg comp',
#  '112 ar condicionado split minimo de 12 000 btus apenas frio',
#  '112 ficha ficha de notificacao de leptospirose impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '112 ficha ficha de notificacao de leptospirose impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '112 maxixe 1 qualidade',
#  '1121 0003 silicona de condensacao p impressao catalisador',
#  '1121 0004 silicona de condensacao para impressao denso',
#  '1121 tapete anti derrapante',
#  '1122 0 adesivo plastico 75 gr',
#  '1123 laminula cristais p camara de newbauer',
#  '1124 lampada halogenio para microscopio 6 v 20',
#  '113 0 tubo vacuo seco c ativador 10 ml',
#  '113 0001 paracetamol 200 mg ml solucao oral',
#  '113 aveia flocos',
#  '1133 filme radiografico infantil',
#  '1135 mamao',
#  '114 03 papel craft 1 20 de lagura',
#  '114 coco ralado 100 g',
#  '114 ficha ficha de notificacao de sindrome da rubeola congenita impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '1146 sertralina 50 mg',
#  '115 08 selador acrilico para paredes',
#  '1155 caneta marca texto cor verde 12 un',
#  '116 agua destilada de 10 ml',
#  '116 ficha ficha de notificacao de dermatose relacionada ao trabalho impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '116 toalha de papel tipo folha 3 dobras grofada medindo 27 x 23',
#  '1172 0 etanol',
#  '1182 madeira serrada virgota',
#  '1183 caneta esferografica',
#  '1184 0 teste imunocromatografico p detencao hc',
#  '119 0002 prometazina cloridrato 25 mg ml sol injetavel',
#  '119 02 carne bovina alcatra e contra file',
#  '119 agenda telefonica grande',
#  '119 pao frances',
#  '1194 copo de vidro tipo americano 250 ml',
#  '1196 cola colorida',
#  '12 006 refrigerante de guarana 2 litros',
#  '12 0154 chave grifo p lavatorio 11',
#  '12 02 hidroxido de aluminio 60 mg ml',
#  '12 0223 junta n',
#  '12 08 agulhas descartaveis haste longa',
#  '12 088 oxigenio medicinal t 10 m3',
#  '12 formula infantil de seguimento com predominancia proteica de caseina e acrescida de oleos vegetais maltodextrina e enriquecida com vitaminas minerais ferro e outros oligoelementos lata de 400 g',
#  '121 0004 central de nebulizacao',
#  '121 agulha multipla 32 x 8 mm 21 g 1 agulha para coleta de sangue a vacuo com dispositivo de seguranca que apos o uso da coleta seja acionado e recobrira completamente a agulha garantindo total biosseguranca cada agulha devera ter em seu corpo duas capa',
#  '1215 algodao 1 kg',
#  '122 0 esponja de limpeza dupla face',
#  '122 latex 100 natural para oxigenioterapia flexivel',
#  '122 notebook processador inteli3 memoria ram 4 gb hd 1 tb leitor e gravador de dvd tela 15 6 led windows 10 original',
#  '1222 tijolo de ceramica laminado',
#  '123 0 telha de amianto 2 44 x 1 10',
#  '123 0001 sias de reidratacao oral 3 5 g 1 5 g 2 9 g 20 g po',
#  '123 02 alcool etilico em gel hidratado',
#  '123 07 dexametasona a 1 mg g 10 g',
#  '1233 filtro racor mb 1418',
#  '1236 envelope saco kraft natural',
#  '124 07 filme rx odontologico infantil',
#  '124 batente amortecedor',
#  '1241 0 tesoura multiuso',
#  '1244 0 ficha d sistema de informacao de atencao',
#  '1248 0 latex acri f prof marfim 18 l',
#  '1248 soro fisiologico 0 9 500 ml bolsa',
#  '1249 0 leite em po 800 gr 1',
#  '125 06 saquinho para presente estampado 20 x 29',
#  '125 07 saquinho para presente 44 x 30',
#  '1254 broca diamantada alta rotacao 1302',
#  '1257 0 shampo neutro de 2 lt',
#  '1257 0 shampo neutro de 2 lt',
#  '126 0 aparelho pressao infantil',
#  '126 0002 sulfadiazina de prata 10 mg g creme',
#  '126 sabonete liquido galao de 5 litros para as maos com perfume suave a base de emolientes que contenham no minimo um agente hidratante e um agente antifungico galao plastico resistente de 5 litros com tampa roscavel lacradas e alca para transporte contendo informacoes tecnicas no rotulo volume data de fabricacao e validade registro na anvisa ms',
#  '1262 reparo para valvula de descarga',
#  '1263 caixa para arquivo jumbo gigante',
#  '127 clip p papel 4 0 cx c 500 gr',
#  '127 milho de pipoca pcte 500 grs tipo 1 preparados com materias primas sas limpas isentas de materias terrosas e parasitos e de detritos animais ou vegetais com no maximo de 15 de umidade emb 500 g 7 1 200 cx pnae extrato de tomate simples concentrado com no minimo 1 de carboidrato e 5',
#  '1271 0 alcool gel antessepitico 500 gramas',
#  '1275 broca peeso numero 2',
#  '1276 bilirrubina colorimetrica 250 ml',
#  '1277 calcador paiva jogo com 4',
#  '1278 protetor n 16',
#  '128 pimentao verde',
#  '1283 joelho soldavel 45 x50',
#  '129 00 sabonete mini',
#  '129 08 broca 3168 ff',
#  '1295 0 oleo hidraulico 1 litro',
#  '1295 grampeador de mesa 60 fls semi automati',
#  '13 00 contra angulo esterilizavel',
#  '13 00 grampo para grampeador 23 8 galvanizado',
#  '13 0010 no break 600 va',
#  '13 016 tinta cartucho preto hp 21 original',
#  '13 026 cafe torrado e moido pct de 500 gr',
#  '13 029 farelo de aveia fina',
#  '13 031 farinha de milho pct 500 gr',
#  '13 038 oleo de soja refinado de 900 ml',
#  '13 045 pasta plastica c elastico',
#  '13 050 cebola branca',
#  '13 056 coxa e sobrecoxa de frango',
#  '13 069 suplemento nutricional p diabeticos',
#  '13 07 prego 17 x 21',
#  '13 073 papel crepom',
#  '13 075 suco concentrado de goiaba',
#  '13 081 basculante para banheiro 60 x 40',
#  '13 092 broca de videa longa 8 mm',
#  '13 094 broca fibrocimento mourao 1 4',
#  '13 095 broca fibrocimento mourao 3 8',
#  '13 bacia plastica media',
#  '13 bacia plastica resistente media para cozinha',
#  '13 cereal de milho pacote 230 gr tipo pre cozido ideal para alimentacao infantil acima de 6 meses contem farinha de arroz rico em ferro e acido folico vitaminas acido pentotenico e minerais empacotado em no maximo 60 dias validade minima de12 meses',
#  '131 0001 eletrodo descartavel adulto p monitorizacao',
#  '1311 fio de nylon 5 0 p sutura c 24 unids',
#  '1314 fluor p aplicacao topica em gel neutro',
#  '132 02 luva de raspa cano medio',
#  '132 cabo adaptador ide sata para usb com fonte de alimentacao 100 240 v',
#  '132 cone secundario de gutapercha para obturacao de condutos n',
#  '132 escovao limpeza em geral',
#  '1321 livro de ata',
#  '1322 0 barbante rolo de 1 kg',
#  '1322 0 barbante rolo de 1 kg',
#  '1323 amido de milho de 1 kg',
#  '1325 0 cebola de cabeca',
#  '1325 0 cebola de cabeca',
#  '1327 0 nifedipina concentracao 10 mg capsula',
#  '1327 registro pressao de 1400 x 3 4',
#  '1328 0 olhinhos de enfeite grande',
#  '133 00 turquesa grande',
#  '133 00 turquesa grande',
#  '133 0021 bomba d agua n',
#  '133 cabo de audio e video hdmi 1 8 metro alta qualidade de imagem terminal hdmi macho nas duas pontas sem perda de sinal',
#  '133 ficha ficha de notificacao de difteria impresso uma via capa no papel kraft 90 g em 1 cor e miolo 1 x 0 cor em papel ap 75 gramas formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 10 blocos',
#  '1333 rodo de espuma',
#  '1338 pincel quadro branco',
#  '1339 0 pinca hemostatica curva 18 cm',
#  '134 0001 doxazosina mesilato 2 mg comprimido',
#  '134 benzilpenicilina procaina benzil',
#  '134 gasolina',
#  '134 lapis preto n 2 lapis de alta qualidade com garfite resistente e facil apontabilidde descricao tecnica composicao madeira graduacao 2 hb formato redondo dimensoes altura 17 50 cm x 0 5 cm largura peso minimo 5 0 gramas caixa com 144 unidades',
#  '134 luva de raspa punho 7 cm tamanhos p luva de raspa confeccionada em raspa de couro com reforco externo entre os dedos indicador e polegar e interno na palma das maos com costura em nylon punho 7 cm',
#  '1346 0 tonner p impressora hpp 1102 w hpm1132 o',
#  '135 00 cronometro digital',
#  '135 0003 cruzeta cardan n bg 8 x 4835 aa',
#  '135 08 papel a4 210 x 297 500 x 1',
#  '1351 0 capa para mangueira de 1 polegada',
#  '1363 tinta p piso base d agua 3600 ml chumbo',
#  '1368 resina fotopolimerizavel z100 cor b3',
#  '1369 0 almotolia escura 250 ml',
#  '1369 0 sonda de aspiracao com valvula n 8',
#  '137 pinca anatomica dente de rato serrilhada 12 cm em aco inox registro no ms',
#  '137 salsicha tipo hot dog de 1 qualidade',
#  '1372 agulha para sultura g14',
#  '1374 0 alicate de unha em inox',
#  '1376 filtro de papel para cafe n 103 c 40',
#  '1378 carbamazepina 200 mg comprimido',
#  '1378 rolo de matriz 5 mm para porta matriz',
#  '1379 pneu 175 70 r 13',
#  '138 ovos de galinha branco tipo extra fre',
#  '1382 taca de borracha para profilaxia',
#  '1386 0 acucar impalpavel',
#  '1387 carvedilol 3 125 mg',
#  '1387 mangueira polietileno de 3 4',
#  '139 00 tinta latex 18 l',
#  '139 0005 conjunto nebulizador adulto',
#  '139 0005 suplemento alimentar modulen especializada para',
#  '139 08 fechadura inox',
#  '139 livro de ata folha 100 branca 100 fls',
#  '1393 agua oxigenada vol 10 frasco com 1000 ml',
#  '1397 shampoo neutro 2 l',
#  '1398 canula de guedel 2',
#  '1399 bucha motor partida',
#  '14 0 vassoura piacava n 4',
#  '14 0003 coletor de urina sistema fechado',
#  '14 01 pasta suspensa marmorizado',
#  '14 012 coxa e sobrecoxa',
#  '14 013 maionese light 250 grs',
#  '14 05 catgut cromado n 3',
#  '14 05 vassoura de coqueiro',
#  '14 06 papel contact transparente',
#  '14 dieta enriquecida c mix de carotenoide liquido',
#  '14 propafenona cloridrato 300 mg',
#  '1400 24 tg 14 lonas',
#  '141 08 assadeira 8 litros',
#  '141 filtro combustivel',
#  '1418 copo descartavel 50 ml pc 100 x 1',
#  '142 0001 pilocarpina cloridrato 20 mg ml sol oftalmica',
#  '142 05 calice sedim fezes 125 ml',
#  '142 copo descartavel 200 ml pacote com 100 un',
#  '1427 adesivo scothbond vidro amostra',
#  '143 papel carbono azul 1 face tam oficio 2',
#  '1439 0 forceps n 18 l',
#  '144 0 canula traquial n 8 5 com balao',
#  '1446 0 cortador de e v a laco tamanho jumba',
#  '1449 0 colete refletivo tipo x',
#  '145 barra de ferro 4 2 mm',
#  '146 barra de ferro 5 16 mm',
#  '146 broca de alta rotacao diamantada n 3113',
#  '146 papel oficio 2 branco alcalino 75 g medindo 216 x 330 mm pacote com 500 folhas',
#  '1461 dreno de penrose esterelizado n 1',
#  '1463 bucha red longa 40 x 25',
#  '1463 pneu p motocicleta traseiro 120 80 18',
#  '1465 pneu p patrol reto traseiro 1400 x 2412 l',
#  '1468 pneu para trator 8030 23 1 30 novo',
#  '147 agua sanitaria 2 l',
#  '147 suco em po sabor guarana 1 kg com acucar',
#  '1472 pasta de arquivo',
#  '1475 fita adesiva transparente 45 mm x 45 m',
#  '148 08 espatula chata n 24',
#  '148 detergente limpeza pesada 500 ml',
#  '148 mic chave geral',
#  '149 09 cara',
#  '149 tempero alho sal pc 1 kg concentrado de ingredientes basicos sal alho cebola oleo vegetal salsa pote plastico resistente com 500 g com dizeres de rotulagem contendo informacoes dos ingredientes data de fabricacao prazo de validade minimo de 6 meses a partir data de entrega similar ou superior a marca pirata',
#  '1498 equipo p nutricao enteral esteril c azu',
#  '15 0014 corda capa fibras trancada em poliamida e alma em',
#  '15 006 ampicilina 500 mg po p solucao injetavel',
#  '15 013 lavatorio 50 x 37 cor branco',
#  '15 032 folders formato 16 4 x 0 cores em papel co',
#  '15 035 ficha producao diaria odontologica',
#  '15 037 cartao de visitas domiciliares formato',
#  '15 041 solicitacao de triagem auditiva neonatal',
#  '15 046 guia de informacao itbi',
#  '15 cefalotina f a 1 g 10 ml',
#  '15 frango congelado inteiro',
#  '15 regua antropometrica estrutura em aco carbono tubo retangular 20 x 30 mm extremidades em polietileno pintura eletrostatica a po tratamento antiferruginoso e secagem em estufa escala adesiva milimetrica dimensoes 300 1000 mm',
#  '151 0 isqueiro grande',
#  '151 broca de alta rotacao diamantada n 3118 ff',
#  '1517 malha tubular 10 cm x 15 m',
#  '152 0012 bomba knf pequena limpeza exterior da agulha',
#  '152 condicionador p cabelo',
#  '152 kit anti d soro para classificacao sanguinea monoclonal anti d frasco 10 ml',
#  '153 creme dental 90 grs sem fluor',
#  '154 0 arruela regulagem cambio mb 1418',
#  '154 04 suporte do escapamento ducato 2 5',
#  '154 05 pastilha de freio dianteiro ducato 2 5',
#  '154 06 pastilha de freio traseiro ducato 2 5',
#  '154 flyer eventos e exposicao da educacao impresso 4 x 0 papel couche liso 120 g formato 14 x 20 cm fornecimento parcelado arte e fotolito inclusos tiragem minima 300 unidades',
#  '154 vassoura de pelo c cabo com base e rosca em material plastico que facilite o encaixe do cabo material de boa qualidade',
#  '1542 ponteira azul tipo gilson 200 1000 ul',
#  '1543 broca infantil para alta rot 16 mm 1333',
#  '1543 te soldavel de 50 mm',
#  '1545 joelho soldavel 90 x 20 mm',
#  '155 02 filtro de oleo fiat uno fire',
#  '155 flyer papel reciclado 90 g 1 4 oficio 4 x 1 fornecimento parcelado arte e fotolito incluso tiragem minima de 200 unidades',
#  '1556 sonda de foley 12',
#  '1559 0 balanca antopometrica adulto',
#  '156 08 suporte de hamper armacao tubular inox',
#  '156 09 suporte de soro suporte para soro altura',
#  '157 07 graxa 1 2 kg',
#  '1573 mascara tripla com elastico embal 50 un',
#  '1574 0 graxeiras curva de 1 4',
#  '1575 sindesmotomo descolador molt',
#  '1576 massa de modelar c 6 unid',
#  '1577 0 fluido de freio dot 4 frasco 500 ml',
#  '159 0 valvula p tanque n 8',
#  '1592 0 kit amortecedor diant doblo',
#  '1594 lixa 150',
#  '1599 especulo p descatavel',
#  '16 0 extrato de tomate',
#  '16 017 torneira p jardim 1 2',
#  '16 02 alho',
#  '16 02 alho',
#  '16 029 terminal de bateria',
#  '16 049 cloridrato ondansetrona 2 mg ml',
#  '16 055 jg pistao com aneis l200',
#  '16 058 gentamicina 40 mg ml',
#  '16 06 pasta suspensa',
#  '16 066 escova para degermacao seca',
#  '16 098 fralda descartavel uso infantil tam xg',
#  '16 batata inglesa especial',
#  '161 03 correia alt sprinter',
#  '161 03 correia alt sprinter',
#  '161 08 bandeja suspencao diant sprinter',
#  '1611 0 coxim motor sprinter',
#  '162 0001 extensor p esfregaco sanguineo cx c 100 unid',
#  '162 esponja dupla face pcte c 3 unidades',
#  '1621 ficha a cadastro da familia 100 x 1 3 x 1 co',
#  '1621 tesoura iris reta amostra',
#  '1624 ficha de controle medicam forneci 100 x 1',
#  '1629 ficha de prontuario 3 x 1 cor',
#  '163 00 disco freio d20',
#  '1632 clipe de aco 6 0 pacote 500 gr',
#  '1632 saco plastico p lixo reforcado 100 lt',
#  '1633 canula endotraqueal com balao n 5 5',
#  '1634 borracha de papelaria numero 60 feita',
#  '1638 vassoura p vaso sanitario bola nylon',
#  '164 0001 calco cabine n e 5 ht 5a160aa',
#  '164 0002 tala metalica p imobilizacao flexivel media',
#  '164 benzilpenicilina procaina potassica inje',
#  '1648 pinca kelly 14 cm curva',
#  '1649 bicarbonato sodio 8 4 inj 10 ml',
#  '1649 tinta para pincel cor azul 37 ml',
#  '165 0007 bobina de papel para ecg medida 48 mm x 30 m',
#  '1651 detector fetal portatil md 700 r',
#  '1651 requisicao de fornecimento de mercadoria',
#  '1652 colchete n 10',
#  '1653 tinta para carimbo na cor preta 40 ml',
#  '1654 historico escolar ensino fundamental',
#  '166 folders festivais feiras e eventos turisticos e culturais impresso 4 x 4 cores papel couche liso 180 g formato 21 x 30 cm aberto com duas dobras fornecimento parcelado arte e fotolito inclusos tiragem minima 1 500 unidades',
#  '166 fosforo pacote com 10 caixas pequenas',
#  '166 fralda descartavel tam g',
#  '1661 torneira com bica movel',
#  '1662 0 cesto de lixo telado',
#  '1667 cloridrato de prometazina 25 mg ml 2 ml',
#  '1667 disjuntor bipolar 2 x 10',
#  '1672 disjuntor tripolar 3 x 70',
#  '1675 pao framces 50 gramas',
#  '1678 eletrodo descartavel infantil',
#  '168 08 reator vapor mercurio 250 v',
#  '168 agua oxigenada vol 10 liquida fr 1 lt',
#  '168 agulha hipodermica des 40 x 12 mm 100 x 1',
#  '1687 0 valvula de comando duplo p cadeira odon',
#  '169 04 saco para lixo preto 100 lt',
#  '169 07 alicate porta eletrodo',
#  '169 cloreto de potassio 19 1 10 ml',
#  '1697 0003 ibuprofeno 100 ml suspensao',
#  '1698 fio 2 5 mm flexivel',
#  '17 02 lapis preto n 2 c 144 und',
#  '17 069 oxalato de escitalopram 10 mg cx c 28 c',
#  '17 08 acendedor tipo fosforo pacote com 10 ca',
#  '17 097 cera rosa 7 caixa com 18 unidades',
#  '17 fita crepe branca 19 mm x 50 m',
#  '17 lencol descartavel 20 mg m2 2 0 m x 90 cm com elastico branco',
#  '171 midazolan 15 mg 3 ml',
#  '1714 sonda entubacao n 3 0 endotraqueal sem b',
#  '1717 sonda entubacao n 4 0 endotraqueal s ba',
#  '172 broca zekrya extra longa',
#  '173 0008 calcado de seguranca tipo botina n 41',
#  '173 0010 dreno de penrose n 2 esteril',
#  '173 0027 calcado de seguranca tipo botina cor preto n 44',
#  '173 lixeira c tampa pedal de plastico 20',
#  '1739 clipe de aco 2 0 pacote com 500 gr',
#  '174 0013 forno micro ondas na cor branca',
#  '174 sonda gastrica longa n 10',
#  '1744 achocolatado em po 800 grs',
#  '175 0 seringa desc 60 ml s ag',
#  '175 04 diazepam 10 mg comprimido',
#  '175 lamina para laringoscopio reta n 2',
#  '1753 caixa derivacao 4 x 4 plastica',
#  '176 03 tinta acrilica brilhante 37 ml',
#  '176 05 escova esponja plast c dupla face 50 x 1',
#  '176 lustra moveis',
#  '177 0 lubrif motor diesel la3 40',
#  '177 0 lubrif motor diesel la3 40',
#  '177 0003 pote de plastico resistente redondo c tampa',
#  '177 03 caderno pre livro sem pauta',
#  '177 balde plastico 15 l',
#  '177 brocas n 1014',
#  '177 perneira de pvc cor preta perneira de seguranca confeccionada em tres camadas de laminados de pvc tres hastes embutidas na parte frontal protecao no metatarso com tres camadas de laminados de pvc fechamento em velcro costurado com linha e orestante costurada em solda eletronica',
#  '1774 0 presilha jacare para cracha',
#  '1774 oleo transmissao wbf100 univ 19 bd',
#  '1775 cetoconazol',
#  '1776 sonda de levine curta calibre 14',
#  '1779 sabonete liquido 5 litros',
#  '178 06 leite integarl 1 lt',
#  '1781 lubrif motor flex 5 w 40',
#  '1782 lubrif motor flex 10 w 40',
#  '1785 tubo corrugado amarelo leve 3 4',
#  '179 cloridrato de amiodarona 50 mg ml 3 ml',
#  '179 pilha nao recarregavel comum media 1',
#  '1797 abacaxi',
#  '1797 abacaxi',
#  '1799 oleo transmissao wbf100 univ 19 5 li',
#  '18 0 escova para vaso sanitario c suporte',
#  '18 0 pilha nao recarregavel comum pequena',
#  '18 0002 biperideno cloridrato 2 mg comprimido',
#  '18 0003 grampeador alicate',
#  '18 0097 rolamento da embreagem no b',
#  '18 030 gesso pedra 1 kg',
#  '18 077 pulpo san c 50 gr po',
#  '18 081 resina a 3 5 fotopolimerizavel com 4 gr',
#  '18 bala macia sabor de frutas pcte 1 kg',
#  '18 filtro de ar arl5310 tecfil padrao tecfil o',
#  '180 placa de rede 10 100 1000',
#  '181 0008 massageador de madeira tipo carrinho',
#  '181 cloridrato de bupivacaina 0 5 com',
#  '1814 terminal cabo 16 mm',
#  '1816 cera em pasta cores variadas',
#  '182 regua transparente 30 cms',
#  '1841 0 corda trancada colorida 12 mm',
#  '1842 roldana plastica grande 103 ou 36 x 36',
#  '1846 arame recozido n 14',
#  '1847 0 selador p madeira 900 ml',
#  '1849 0 telha 1 83 x 1 10 x 5 mm amianto',
#  '1852 caneta para retroprojetor preto de boa q',
#  '186 0 vassoura cerdas de piacava 20 cm',
#  '186 cloridrato de dopamina 50 mg ml 10 ml',
#  '186 pano de prato',
#  '1862 cascalho lavado',
#  '187 03 telhas portuguesas',
#  '187 08 albendazol 40 mg ml suspensao',
#  '1871 amendoim sem torrar 1 kg',
#  '1872 0003 lidocaina 2 su 1 8 ml tubete',
#  '1875 cola liquida branca papel nao toxi 1 li',
#  '1877 grampo para grampeador 23 6 arame aco',
#  '1879 bucha plastica n 10',
#  '188 cefalotina 500 mg frasco ampola de 5 ml',
#  '1881 sonda nasogastrica longa n 18',
#  '1882 papel crepom com cores variadas',
#  '189 caneta marca texto cor rosa',
#  '1892 pepino',
#  '19 000 balde de plastico resistente capacidad',
#  '19 0006 colher de inox sobremesa',
#  '19 0012 protetor auricular tipo concha com duas conchas',
#  '19 0028 leite infantil a base de aminoacidos',
#  '19 0029 leite infantil a base aminoacidos nalergenicos',
#  '19 01 feijao carioca kg',
#  '19 026 tesoura 21 cm de metal c cabo plastico r',
#  '19 03 oculos de protecao',
#  '19 03 oculos de protecao',
#  '19 039 clips 4 0 com 500 gramas fabricado com',
#  '190 lampada para microscopio 30 w 127 volts ba 15 d espelhada',
#  '191 0003 papel crepado verde 60 x 60 cm caixa c 500 unid',
#  '191 0009 papel crepado verde 90 x 90 cm cx c 500 uni',
#  '191 prancheta de madeira 21 cm x 14 8 cm possui otimo acabamento dos dois lados com cantos arredondados e prendedor metalico wire mais moderno e eficiente',
#  '1912 cloreto de sodio 20',
#  '1913 giz branco antialergico',
#  '1916 grampo 23 x 10',
#  '192 0005 m 53 purific cleanser solucao de limpeza diaria',
#  '1921 broca 3168',
#  '1921 milho verde',
#  '1923 gelatina',
#  '1925 broca de aco esferica ca 4 c 6 unid',
#  '1926 maizena',
#  '193 abacaxi',
#  '193 cera liquida vermelha embalagem 12 x 850 ml',
#  '1934 pimenta do reino',
#  '194 0 queijo ralado',
#  '1946 tapete de tecido 40 x 60 cm',
#  '195 respirador purificador de ar tipo peca semi facial filtrante para particulas pff1 respirador purificador de ar tipo peca semifacial filtrante para particulas classe pff1 formato dobravel com valvula de exalacao',
#  '1956 forceps adulto n 1',
#  '1958 metformina 850 mg',
#  '1958 vassoura piacava',
#  '196 06 refletor de 250 v',
#  '196 absorvente com abas 8 unidades',
#  '196 itinerario semanal de trabalho impresso uma via capa no papel supremo 250 g em 1 cor e miolo 1 x 1 cor cor em papel ap 75 gr formato 210 x 297 50 x 1 acabamento blocado picotado e colado tiragem minima 2 blocos',
#  '196 maca nacional',
#  '196 maca nacional',
#  '196 rodo medindo 40 cm',
#  '1961 flumazenil ampola',
#  '1961 lixa ferro 40',
#  '1965 forceps infantil n 27',
#  '1967 gesso pedra amarelo 1000 g',
#  '1969 hidroclorotiazida 25 mg',
#  '1969 tempero completo',
#  '197 0001 apm aparelho de protracao mandibular',
#  '1975 cabo de rede trancado cx c 305 mts',
#  '1979 machado c cabo 2 5',
#  '1979 maquina vidro porta dir',
#  '198 creme dental 90 g',
#  '1983 metformina',
#  '199 0 ponteiro 3 4 x 12',
#  '199 0002 planas composto',
#  '199 0003 trava n',
#  '199 abaixador de lingua pacote com 100 palitos de madeira',
#  '199 cloridrato de prometazina de 50 mg 2 ml',
#  '199 vela',
#  '1996 oleo spray lubrificante caneta de ba',
#  '2 0001 gasolina comum',
#  '2 0073 bolacha maisena com 2 kg composicao nut',
#  '2 0082 ovos brancos grandes',
#  '2 012 pote dappin de plastico',
#  '2 0121 pistola p cola quente fina selo inmet',
#  '2 0125 tnt tecido nao tecido rolo c 50 m 1 4',
#  '2 0201 papel encerado na cor preto',
#  '2 0233 diazepam 5 mg comp',
#  '2 0343 cola branca de 1 kg cx 12',
#  '2 0349 envelope branco 250 x 353 cx 250',
#  '2 035 lavatorio medio',
#  '2 0368 marcador de quadro branco cx 12',
#  '2 0386 pasta versatil c ziper transparente',
#  '2 039 oleo diesel comum',
#  '2 039 verniz',
#  '2 0448 conectores rcg 213',
#  '2 045 fenitoina 100 mg',
#  '2 0450 notebook processador 2 1 ghz ou superior hard disk 500 gb item 2',
#  '2 0483 cone de guta percha r7 28 mm com 120',
#  '2 051 acido folico 5 mg',
#  '2 053 hipoclorito de sodio a 1',
#  '2 053 hipoclorito de sodio a 1 gl 5 litros',
#  '2 054 porta objetos duplo caneta clips',
#  '2 0544 seringa 1 ml desc confeccionada em po',
#  '2 0641 fio agulahado seda 4 0 c 12 unidades',
#  '2 0686 caneta p marcar tecido cores variadas',
#  '2 07 escova dental adulto macia cores variada',
#  '2 0799 rolamento da roda dianteira doblo 1 8',
#  '2 080 creatinina cinetica aa liquida',
#  '2 0821 bandeja da suspensao doblo 1 8',
#  '2 083 joelho bucha latao 20 x 1 2',
#  '2 084 joelho lr de reducao 25 x 1 2',
#  '2 0875 amortecedor traseiro ducato',
#  '2 0885 saco de lixo ref preto 40 lts pte c 10',
#  '2 0933 alavanca reta inox n 1 cabo octogonal co',
#  '2 095 agulha desc 25 x 7 0 100 x 1',
#  '2 095 bolacha sabor coco 2 kg',
#  '2 096 calculadora de mesa',
#  '2 0974 esfigmomanometro adulto',
#  '2 aciclovir 200 mg',
#  '2 agua sanitaria com 2 5 de hipoglorito de sodio com cloro ativo 1 litro similar a marca ype qboa brilhante trazer amostra',
#  '2 agua sanitaria galao embalagem 5 litros similar a marca ype qboa brilhante trazer amostra',
#  '2 cera liquida perfumada frasco plastico de 750 ml com tampa flip top na versao incolor similar a marca poliflor caixa com 12 unidades',
#  '2 concha de aluminio',
#  '2 contencao fixa 3 x 3 reta',
#  '2 corda de nylon p varal c 10 m n 3',
#  '2 esponja para limpeza dupla face amarela e verde medindo aproximadamente 90 x 69 x 20 mm similar a marca scotch brite',
#  '2 guardanapo de papel 28 x 32 pct 100 folhas',
#  '2 hemocultura para bacterias nao exigentes',
#  '2 limpador instantaneo multi uso limpeza total frasco de 500 ml similar a marca veja ou mr musculus',
#  '2 luva plastica descartavel pacote com 100 unidades',
#  '2 mangueira de borracha completa com 50 mt e esguicho de metal',
#  '2 metildopa 250 mg cp',
#  '2 mola dianteira cam m benz',
#  '2 o mola diant onibus m 1813',
#  '2 p inferior cor 66',
#  '2 papel higienico fino extra branco rolo de 300 metros',
#  '2 saco de lixo de 200 lt com 100 unidades na gramatura 0 15 reforcado trazer amostra',
#  '2 saco de lixo preto pct c 100 und de 40 lt na gramatura 0 15 reforcado trazer amostra pacote com 5 kg',
#  '20 atadura de crepom 20 cm com 13 fios cm atadura de crepom 20 cm com 13 fios cm confeccionada em fios de algodao cru ou componentes sinteticos com as bordas delimitadas elasticidade adequada enrolada uniformemente de forma cilindrica isentas de defeitos embalada em pacotes com 12 rolos contendo dados de identificacao e procedencia numero de lote metodo data de fabricacao e ou validade tamanho esticado 20 cm x 4 5 metros registro no ms',
#  '20 bi c 36 unid',
#  '20 caldo de galinha concentrado cx 6 unidades a base de carne frango desidratada liofilizada ou extrato de carne sal amido de milho gordura vegetal condimentos podendo conter corante natural sem sujidades materias terrosas parasitas larvas e detritos animais ou vegetal',
#  '20 formula infantil de seguimento para lactentes a partir dos 6 meses de vida com proteinas lacteas lata de 400 g',
#  '200 cpu 1150 g1820 2 7 ghz 2 mb cache box',
#  '2016 amoxicilina 500 mg',
#  '2016 espiral 7 mm a z pacote com 100',
#  '2016 filtros de ar interno as 820 ou similar veiculo mb 1113 onibus motor om 352 a',
#  '2016 oleo lubrificante motor gasolina 5 w 30 1 000 ml sintetico',
#  '2016 tnt amarelo',
#  '2016 tnt marrom',
#  '2017 agenda',
#  '2017 banner impresao colorida em apenas 1 dos lados tamanho 80 cm comp x 1 20 cm altura',
#  '2017 blocos de 100 folhas declaracao de comparecimento',
#  '2017 cartaz tam a4 couche 120 gr 4 x 0 cm',
#  '2017 cola c gliter vermelho',
#  '2017 dexametasona acetado creme 0 1 bisnaga c 10 g',
#  '2017 fenobarbital solucao oral 40 mg ml',
#  '2017 filtros de ar ars 1013 ou similar veiculo fiat ducato motor 2 8',
#  '2017 filtros de combustivel psc75 ou similar caminhao vertis',
#  '2017 historico escolar ensino fundamental',
#  '2017 sertralina comprimido 50 mg',
#  '2017 tesoura escolar caixa com 20 unid sem ponta',
#  '2018 alfinete mapa n 13 c cabeca colorida cx c 50 cor azul',
#  '2018 bastao de cola quente grosso',
#  '2018 blocos com 100 folhas atestado medico',
#  '2018 cd virgem',
#  '2018 cloreto de sodio sol injetavel 0 9 frasco c 10 ml',
#  '2018 elastico latex 1 kg',
#  '2018 filtro de ar arl 6096 veiculo gol motor ap 1 6',
#  '2018 filtro de combustivel fcd 775 veiculo fiat ducato 2 8 diesel',
#  '2018 filtro de combustivel psc 498 1 veiculo iveco cittyclass 70 c 16',
#  '2018 folhas de eva verde claro',
#  '2018 guache laranja c 6',
#  '2018 lamina dosadora para cartucho de toner compativel a impressora xerox phaser utilizado em impressoras modelos xerox phaser 3117 3122 3124 3125 produto compativel com o original ou original',
#  '2018 mandioca extra de primeira sem rama fresca compacta e firme',
#  '2018 papel crepom lilas c 10 fls',
#  '2018 pasta de papelao c elastico',
#  '2018 querosene 1000 ml',
#  '2018 refil de tinta epson t664 ciano utilizados na recarga de bulk ink dos seguintes modelos epson l 200 l 210 l 110 l 355 l 555 l 455 l 365 l565 l 565 l220 l 220 l 1300 l1300 tinta corante produto original',
#  '2018 registro de visita ao pit',
#  '2018 rolo de renda 13 cm x 70 cm',
#  '2019 alcool etilico hidratado uso domestico 1 l 70',
#  '2019 cacarola 5 6 litros 24 cm com tampa e com alca de madeira',
#  '2019 caderno de ata c 50 folhas',
#  '2019 doce de leite 800 g',
#  '2019 folhas de eva amarelo',
#  '2019 lapis de cor com 12 unidades',
#  '2019 panela de pressao 10 litros',
#  '2019 pano de prato 70 x 50 cm',
#  '2019 papel camurca branco c 25 fls',
#  '2019 papel camurca verde c 25 fls',
#  '2019 papel cartao verde tam a4',
#  '2019 papel crepom branco c 10 fls',
#  '2019 papel crepom verde c 10 fls',
#  '2019 papel laminado rosa',
#  '2019 refrigerante 2 l sabor diverso diet',
#  '2019 saquinho para presente de plastico transparente 30 x 44 cm',
#  '2019 semente de jilo similar a top seed garden ou de melhor qualidade',
#  '2019 semente de rucula similar a top seed garden ou de melhor qualidade',
#  '2019 tinta para carimbo azul',
#  '2019 tnt lilas',
#  '2019 tnt marrom',
#  '202 cpu 1151 core i3 6100 3 7 ghz 3 mb 6 geracao box',
#  '208 cpu 1151 core i7 7700 k 4 2 ghz 7 geracao box sem cooler',
#  '208 panfletos para evento educadores formato 10 5 x 15 0 cm impressos 4 x 1 cores em papel ap 75 gramas fornecimento parcelado arte e fotolito inclusos tiragem minima 500 unidades',
#  '21 0 deslanosideo 0 2 mg ml 2 ml',
#  '21 0009 equipo para bomba de infusao',
#  '21 0015 equipo para aferir pressao venosa',
#  '21 019 kit toxoplasmose igm c 96 testes',
#  '21 07 atadura algodao ortop 10 cm x 1 m 12 x 1',
#  '2117 cateter intravenoso angiocath 24 g',
#  '212 03 filtro combustivel c separador 326 1644',
#  '212 03 filtro combustivel c separador 326 1644',
#  '212 07 filtro combustivel c separador n',
#  '2127 anticoagulante edta frasco c 20 ml',
#  '2129 macarrao picado tipo parafuso pcte 1 kg',
#  '213 0 bilirrubina',
#  '213 0 luvas cir pre talcadas lat nat 8 100 un',
#  '214 talco infantil 200 grs',
#  '2142 fio mononylon 3 0 c agulha 3 8 ct 2 0 cm',
#  '2143 fio mononylon 4 0 c agulha 3 8 ct 2 0 cm',
#  '2143 hemoglobina padrao',
#  '2143 prego 17 x 21 com cabeca',
#  '215 cimento provisorio po 38 grs',
#  '2154 luvas cirugicas esterilizadas 7 0',
#  '2159 mandril para entubacao adulto',
#  '216 pasta de processo divida ativa cartao branco impresso 1 x 1 cor em cartao branco 120 gramas formato aberto 325 x 480 com 3 vincos a frente da capa e a contracapa devera ter a especificacao padrao do municipio tiragem minima 200 unidades',
#  '216 retentor volante',
#  '216 touca tela 100 poliester boa qualida',
#  '2164 pincel atomico preto',
#  '2164 soro glicosado 5 500 ml',
#  '2166 parafuso frances 1 4 4',
#  '2168 scalp n 25 g',
#  '217 0 soro anti b 10 ml',
#  '217 vassoura de palha coqueiro com cabo',
#  '2179 agrofilito sc 18 kg',
#  '218 0 argamassa 20 kg',
#  '218 gabinete preto 500 w mod ft403 black material composicao metais e plasticos',
#  '218 vassoura de pelo sintetico 30 cm',
#  '2186 rejunte cores variadas pct 1 kg',
#  '219 filme radiografico odontologico adulto caixa com 150 unidades',
#  '2191 espatula de ayres',
#  '2194 tubo vacuo citrato azul 5 ml c 100 unid',
#  '22 0001 escova p laboratorio de lavagem de tubos de',
#  '22 07 valvula succao 1 1 2',
#  '221 fluor gel em 200 ml',
#  '2214 gel para ecg un c 5 kg galao',
#  '2218 agulha vacuo p coleta 25 x 8 c 100 unid',
#  '223 0005 ceftriaxona 1 g iv',
#  '223 gas lp45',
#  '2235 linguica mista',
#  '2235 linguica mista',
#  '2239 paracetamol 200 mg 15 ml',
#  '224 02 complexo b comprimidos',
#  '224 03 salsicha tipo hot dog composicao nutric',
#  '2241 0 escova dental com cerdas macias e com as',
#  '225 0 loratadina 1 mg ml sol oral fr c 100 m',
#  '2252 mortadela',
#  '2255 0 fralda desc uso adulto tam p unid',
#  '226 assadeira em aluminio retang 35 6 x 24 7',
#  '2261 oxalato de ecitalopram 10 mg',
#  '2263 papel celofane',
#  '2267 lancetas premium',
#  '2277 reator eletrico 1 x 20 w',
#  '228 0 agua destilada 10 ml pltco',
#  '228 beterraba selecionada otima qualidade',
#  '228 malha tubular 12 cm x 25 m malha tubular com aproximadamente 12 cm de largura constituida de fios de algodao tipo punho simples a malha devera apresentar elasticidade adequada isenta de defeitos em rolo de 25 metros de comprimento embalados de acordo com a praxe do fabricante e constar externamente os dados de identificacao e procedencia',
#  '2287 hidroclorotiazida 25 mg',
#  '229 avental tecido',
#  '229 lapis de cor grande c 36 cores fabrica',
#  '23 0 bacia plastica 5 lts',
#  '23 017 maionese c reduzido teor de gordura c',
#  '23 029 luva de borracha tipo latex flocos algod',
#  '23 esfigmomanometro adulto esfigmomanometro aneroide em nylon com fecho de metal feito em material ultra resistente e com padrao de qualidade internacional corpo metalico cromado de alta durabilidade bracadeira em nylon com fecho metal esfigmomanometro para uso adulto pera de latex com valvula de alta precisao na liberacao da precisao ajuste preciso garantia do fabricante de 1 ano faixa de medicao de 0 a 300 mmhg',
#  '231 detergente neutro 2 litros',
#  '2311 pistola para cola quente grande',
#  '2311 rodo 60 cm c cabo',
#  '2311 torneira esfera de 1 2 metal',
#  '2313 blocos cimento 20 x 20 x 40',
#  '2324 mamao papaia',
#  '2324 rodo de madeira 40 cm c cabo 1 60 cm 1 q',
#  '233 02 pneu 18 4 15 34 agricola',
#  '234 bacia plastica 60 lts',
#  '234 vassoura piacava',
#  '2349 papel contact transparente',
#  '235 0 fluoxetina 20 mg',
#  '236 01 balanca digital capacidade 250 kg capa',
#  '236 balde plastico 30 lts com alca',
#  '236 limpador instantaneo multi uso 500 ml',
#  '2367 0 absorvente intimo fluxo normal com abas',
#  '237 fenitoina sodica 50 mg ml 5 ml',
#  '237 pano de chao alvejado tam 54 x 65 cm',
#  '2373 amoxicilina 500 mg',
#  '2374 ampicilina 500 mg',
#  '239 0 sabonete liquido',
#  '239 0002 bimatoprosta 3 ml',
#  '2396 vassoura de pelo sintetico 40 cm',
#  '24 0022 cilindro n a0012955607',
#  '24 036 seringa 10 ml descartavel confeccionada',
#  '24 036 seringa 10 ml descartavel confeccionada',
#  '24 05 cefalexina 500 mg',
#  '24 05 quiabo',
#  '24 09 cloreto de sodio 9 mg ml',
#  '24 cereal matinal flocos de milho 300 g tipo mucilon sabor multi cereais e milho lata 400 g ingredientes farinha de trigo enriquecida com ferro e acido folico acucar farinha de milho enriquecida com ferro e acido folico farinha de arroz sais minerais carbonato de calcio fosfato de sodio difasico fumarado ferroso sulfato de zinco vitaminas vitamina c niacina vitamina e acido pantote nico vitamina a vitamina b1 vitamina b6 acido folico vitamina d e aromatizante vanilina contem gluten contem tracoes de leite',
#  '24 espironolactona comprimido 25 mg',
#  '24 estetoscopio adulto simples baixo peso diafragmas de alta sensibilidade tubo excelente transmissao do som garantia 1 ano',
#  '24 filtro de linha de 5 tomadas bivolt tensao de alimentacao 127 220 v potencia maxima 1270 va para 127 v ou 2200 va para 220 v com protetor contra sobretensao e surtos',
#  '24 x 1 lubrificante para motores',
#  '2411 cloridrato de bambuferol 1 mg ml fr 100 m',
#  '242 adaptador pvc 2',
#  '242 brilho aluminio',
#  '2427 enxadao estreito c cabo',
#  '2445 estradiol noretisterona 1 0 5 mg',
#  '2452 dolosal 50 mg ml',
#  '246 0 diazepam 10 mg',
#  '246 sabonete 90 gr',
#  '2466 papel crepom cores variadas com 10 unid',
#  '247 garrafa termica 1 l',
#  '247 vassoura de cerdras de coqueiro',
#  '2484 goma de panela de pressao 7 litros',
#  '2486 albendazol 400 mg',
#  '2488 maleato de timolol 0 5 solucao oft',
#  '25 0 colher de sobremesa em aco inox',
#  '25 075 escada 2 degraus hospitalar',
#  '25 caderno de protocolo 100 fls a 104 fls formato de 154 mm x 216 mm aproximadamente capa contra capa em papelao 700 grs revestido com papel 90 grs papel off set 63 grs feito em material de 1 qualidade',
#  '25 filtro de ar de motor da retro jcb 3 c 2012',
#  '25 macarrao espaguette pct c 500 gr',
#  '25 metilprednisolona 500 mg ampola',
#  '252 inseticida',
#  '252 paracetamol 500 mg cx com 500 comp',
#  '2527 pasta suspensa dello kraft',
#  '2528 prednisona 20 mg',
#  '253 colheres descartaveis pcte c 100 unds',
#  '2536 computador desktop processador 4 nucleos',
#  '2538 sinvastatina 40 mg',
#  '254 ovos brancos tipo a',
#  '2548 agulha hipod desc 25 x 6 0',
#  '2551 pincel atomico verde',
#  '2554 0 fio cat gut simples 0 70 m cortante 3 0',
#  '2557 espude preto p vaso sanitario',
#  '2558 furosemida 40 mg cloreto de potassio',
#  '256 envelope pequeno carta 1000 x 1 na cor bra',
#  '2565 fosfato de sitagliptina 100 mg',
#  '257 copo descartavel para cafe pcte c 100',
#  '257 escova dental com protetor de cerdas',
#  '258 arroz 5 kg',
#  '258 arroz 5 kg',
#  '258 glicose 50 10 ml',
#  '258 tee esgoto 100 x100 mm',
#  '2582 tubo polietileno 1 2',
#  '259 0003 destilador de agua com capacidade para destilar',
#  '2591 equipo p transfusao sangue c rolete cam',
#  '2594 dimenidrato piridoxina inj 10 ml',
#  '2595 dipirona sodica inj 500 mg ml amp 2 ml',
#  '26 0 extrato de tomate 350 gr',
#  '26 0021 fio cat gut simples no 1 c ag 3 75 cm ise',
#  '261 heparina 5 000 ui ml 0 25 ml',
#  '2612 fralda descartavel pacotao eg c 70',
#  '2619 cartucho para impressora hp 60 preto',
#  '262 fita para maquina de escrever eletrica',
#  '263 hidroclorotiazida 25 mg',
#  '263 hidroclorotiazida 25 mg',
#  '2656 jilo',
#  '2662 gas nitrogenio',
#  '2664 valvula metal p piaamericana',
#  '267 faca p mesa em aco inox',
#  '2675 tiamina 300 mg',
#  '2697 corrente 3 16 5 00 mm',
#  '2699 ar condicionado btus',
#  '27 023 toldo com estrutura em tubo metalon 30 x',
#  '27 052 agua destilada c 5 lts',
#  '27 coco ralado 100 grs fino sem acucar a base a base de polpade coco desidratado insento de impurezas sujidades e ranco acondicionado em apropriada a embalagem devera estar integra e conter todas as informacaoes de acordo as especificacoes tecnicasda anvisa prazo de validades minimo de 6 meses de a partir da data da entrga',
#  '271 sabao de barra glicerinado pct c 5',
#  '2715 joelho lr 20 x 1 2',
#  '2724 garrafa termica 1 l',
#  '273 01 midazolan 5 mg ml sol inj 3 ml',
#  '273 frigideira media',
#  '273 frigideira media',
#  '2731 envelope pardo 24 x 34',
#  '2732 prumo diversos 400 gramas',
#  '275 0017 tinta latex na cor azul sereno pva lta c 18 l',
#  '2757 creme dental 90 g',
#  '276 06 barra de ferro ca 50 5 16',
#  '276 sonda de aspiracao traqueal c v numero 8 dispositivo utilizado para aspiracao de secrecoes da arvore traqueobronica do sistema respiratorio e vias aereas em pacientes tubo em pvc atoxico flexivel transparente e com a superficie rigorosamentolisa com a ponta arredondada aberta no lado proximal do tubo e 2 orificios alternados em lados opostos conector especial com valvula que permite controlar a succao desejada com cores diferenciadas para cada numeracao no lado distal do tubo esterilizacao a oxido de etileno embalagem em papel grau cirurgico',
#  '2762 liquido de turck frasco 500 ml',
#  '2779 cavalete para agua muro',
#  '278 0036 tinta esmalte brilhante laranja lta c 3600 ml',
#  '278 0070 tinta esmalte brilhante na cor azul franca lt3600',
#  '278 espelho odontologico n 5',
#  '278 luva procedimento vinil tam p 100 uni',
#  '2782 cartaz a3 a 4 x 0 cores couche 145 gr',
#  '2786 joelho polietileno 3 4',
#  '279 isossorbida 5 mg sublingual',
#  '2791 cartaz a3 4 x 0 cores couche 145 gr',
#  '2796 impresso jornal colorido 4 x 4 cores',
#  '2797 bone tipo arabe',
#  '2798 panela de presao 10 lts',
#  '2799 impressora jato de tinta',
#  '28 038 terminal triplo',
#  '28 0413 cacarola reforcada toda em aluminio lixado e polido n 28',
#  '28 0423 escumadeira encartelada totalmente em aco inox',
#  '28 06 presunto',
#  '28 077 escova de robson',
#  '28 082 filme rx odontologica c 150 und',
#  '280 talhadeira aco cromado n 12',
#  '282 pincel atomico azul',
#  '2823 tubo ponta azul 1001',
#  '2836 dipirona sodica 500 mg 2 ml injetavel',
#  '284 0 prendedor roupa c 12 un',
#  '284 cartolina branca',
#  '284 copo descartavel 50 ml c 100',
#  '284 copo descartavel 50 ml c 100',
#  '284 sonda foley 2 v 30 cc nr 12 esteril confeccionada em borracha natural siliconizada em duas vias sendo uma em funil e outra com valvula p enchimento do balao ponta cilindrica macia de fundo cego e com dois orificios laterais em lados opostosapos o balao calibre n 12 embalagem individual em papel grau cirurgico com face em polipropileno com abertura em petala constando externamente identificacao e procedencia data e tipo da esterilizacao e tempo de validade',
#  '2844 sonda nasogastrica longa n 8 rg pvc',
#  '2847 malha tubular 10 cm',
#  '2848 malha tubular 12 cm',
#  '286 08 parafuso 3 8 c arruela e porca',
#  '286 glicose 25 c 10 ml injetavel',
#  '2865 tubo para coleta a vacuo de 8 5 ml',
#  '2889 pres ser de taxi sec mun agricultura',
#  ...]

# %%
# X-means clustering:

# %%
# Prepare initial centers - amount of initial centers defines amount of clusters from which X-Means will
# start analysis.
amount_initial_centers = 10
initial_centers = kmeans_plusplus_initializer(items_embeddings[:100], amount_initial_centers).initialize()

# %%
# Create instance of X-Means algorithm. The algorithm will start analysis from 2 clusters, the maximum
# number of clusters that can be allocated is 20.
xmeans_instance = xmeans(items_embeddings[:100], initial_centers, 20, ccore=False)
xmeans_instance.process()

# %%
# Extract clustering results: clusters and their centers
clusters = xmeans_instance.get_clusters()
centers = xmeans_instance.get_centers()

# %%
clusters

# %%
agglomerative = AgglomerativeClustering(n_clusters=20)
agglomerative.fit(items_embeddings)
clusters = agglomerative.labels_

# %%
clusters

# %%
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(centers, None, marker='*', markersize=10)
visualizer.show()

# %%
# It runs xmeans on the embeddings matrix and returns clusters:
def cluster_embeddings_by(embeddings_matrix, algorithm, kmax):

    if algorithm == 'xmeans':
        xmeans_instance = xmeans(embeddings_matrix, kmax=kmax, ccore=False)
        xmeans_instance.process()
        clusters = xmeans_instance.get_clusters()
    elif algorithm == 'agglomerative':
#         agglomerative = AgglomerativeClustering(n_clusters=kmax, affinity='cosine', linkage='complete')
#         agglomerative.fit(embeddings_matrix)
#         clusters = agglomerative.labels_
        agglomerative_instance = agglomerative(embeddings_matrix, number_clusters=kmax, ccore=False)
        agglomerative_instance.process()
        clusters = agglomerative_instance.get_clusters()
    elif algorithm == 'optics':
        radius = 0.4
        optics_instance = optics(embeddings_matrix, eps=radius, minpts=30, ccore=False)
        optics_instance.process()
        clusters = optics_instance.get_clusters()
    elif algorithm == 'dbscan':
        radius = 0.4
        dbscan_instance = dbscan(embeddings_matrix, eps=radius, neighbors=30, ccore=False)
        dbscan_instance.process()
        clusters = dbscan_instance.get_clusters()

    return clusters

# %%
# Define the embedding matrix for a group:
def get_group_embeddings_matrix(group_desc, items_list, word_embeddings, word_class,
                                embedding_type=None, embedding_size=50):

    embeddings_matrix = []

    for desc_id in group_desc:
        item_embedding = get_item_embedding(items_list[desc_id], word_embeddings, word_class,
                                                embedding_type=embedding_type, embedding_size=embedding_size)
        embeddings_matrix.append(list(item_embedding))

    return embeddings_matrix

# %%
def translate_id_to_descriptions(ids, descriptions_ids):
    arr = []

    for i in ids:
        arr.append(descriptions_ids[i])
    return arr

# %%
def cluster_on_first_token_groups_emb(itemlist, first_token_groups, word_embeddings,
                                      word_class, embedding_type, it_thread, lower,
                                      upper, algorithm, embedding_size, Result):
    print(it_thread)

    # It creates a list of the the keys of these groups:
    groups = list(first_token_groups.keys())
    # It gets the values of each group (i.e., the ids of the descriptions into that group):
    group_descriptions = list(first_token_groups.values())

    # It defines the dictionary that will have the clustering with first token
    # together with x-means considering a the items embeddings
    # grouped by the first token approach:
    first_token_plus_emb_xmeans = {}
    # Iterator of the first token groups:
    ft_it = lower

    while ft_it <= upper:
        if(len(group_descriptions[ft_it]) > 30):
            embeddings_matrix = get_group_embeddings_matrix(group_descriptions[ft_it],
                                                            itemlist.items_list,
                                                            word_embeddings,
                                                            word_class, embedding_type,
                                                            embedding_size)

            #It applies the clusters on the embeddings matrix:
            kmax = len(group_descriptions[ft_it])/30
            clusters_embeddings = cluster_embeddings_by(embeddings_matrix,
                                                        algorithm=algorithm,
                                                        kmax=kmax)

#             if algorithm == 'agglomerative':
#                 cluster_items = collections.defaultdict(list)
#                 it = 0
#                 for desc_id in group_descriptions[ft_it]:
#                     cluster = clusters_embeddings[it]
#                     cluster_items[cluster].append(it)
#                     it += 1
#                 clusters_embeddings = [cluster_items[i] for i in range(0, len(cluster_items))]

            it = 0
            for c in clusters_embeddings:
                # It translates ids from x-means to actual descriptions (new groups):
                desc_ids = translate_id_to_descriptions(c, group_descriptions[ft_it])
                # It defines the key of the map:
                new_key = groups[ft_it] + '_' + str(it)
                # It sets the maps:
                first_token_plus_emb_xmeans[new_key] = desc_ids
                it = it + 1
        else:
            first_token_plus_emb_xmeans[groups[ft_it]] = group_descriptions[ft_it]
        ft_it = ft_it + 1

    Result[it_thread] = first_token_plus_emb_xmeans

# %%
def get_ranges(group_len, n_threads):
    total_len = group_len
    num_threads = n_threads
    lower = []
    upper = []
    step = int(total_len/num_threads)

    for k in range(num_threads):
        lower.append(0)
        upper.append(0)

    lower[0] = 0
    upper[0] = step

    i = 1
    j = 0
    while (i < num_threads):
        upper[i]  = upper[j] + step
        lower[i]  = upper[j] +  1
        if(i%2 != 0):
            upper[i] = upper[i] + 1

        i = i + 1
        j = j + 1

    upper[n_threads - 1] = upper[n_threads - 1] - 6
    return lower, upper

# %%
# It gets the descriptions processed:
itemlist = ItemList()
itemlist.load_items_from_file('../dados/items_preprocessed.zip', just_words=True)

# %%
# Get the tags of tokens descriptions
word_class = get_tokens_tags()

# %%
# It gets the first tokens of each description and groups
# based on this approach:
first_token_groups = itemlist.get_first_token_groups(just_words=True)
group_len = len(first_token_groups)

# %%
first_token_groups_new = {}
keys_ft = list(first_token_groups.keys())
random.shuffle(keys_ft)
random.shuffle(keys_ft)

for k in keys_ft:
    first_token_groups_new[k] = first_token_groups[k]

# %%
# word embeddings file, each line contains a word embedding
word_embeddings_file = '../../../embeddings/cbow_s50.txt'

# %%
# read word embeddings from file and store them in a map
word_embeddings = load_word_embeddings(word_embeddings_file)

# %%
manager = multiprocessing.Manager()
return_dict = manager.dict()
jobs = []
n_threads = 19

# %%
# It defines the ranges (of the groups) the threads will work on:
thread_ranges = get_ranges(group_len, n_threads)
print('Read ranges')
print(thread_ranges)

# %%
algorithm = 'dbscan'
embedding_size = 50

for i in range(n_threads):
    p = multiprocessing.Process(target=cluster_on_first_token_groups_emb,
    args = (itemlist, first_token_groups_new, word_embeddings, word_class, \
            ['N', 'MED'], i, thread_ranges[0][i], thread_ranges[1][i], algorithm, \
            embedding_size, return_dict))
    jobs.append(p)
    p.start()

# %%
for proc in jobs:
    proc.join()

# %%
len(return_dict)

# %%
dictionary_clusters = {}
for i in range(n_threads):
    try:
        dictionary_clusters.update(return_dict[i])
    except:
        None

# %%
a_file = open("./results/baseline+embeddings/embeddings50_SUB+MED_dbscan.pkl", "wb")
pickle.dump(dictionary_clusters, a_file)
a_file.close()

# %%
import pandas as pd
from collections import Counter

dft = pd.read_csv("../dados/resultados_teste_tcu/hdbscan_emb_50.csv",sep=';')
dft.head(),dft.shape
# Out:
# (   cluster                                               desc
#  0       -1                ['colagenase', '0', '6', 'ui', 'g']
#  1       -1  ['campo', 'operatorio', '45', 'cm', 'x', '50',...
#  2       -1                                     ['kit', 'pet']
#  3       -1      ['tinta', 'relevo', 'para', 'tecido', 'bran']
#  4       -1  ['termometro', 'clinico', 'digital', 'portatil...,
#  (1667928, 2))

# %%
Counter(dft.cluster)
# Out:
# Counter({-1: 934671,
#          8704: 66,
#          8405: 280,
#          2298: 76,
#          1166: 146,
#          1239: 36,
#          7333: 51,
#          3254: 32,
#          5163: 76,
#          7117: 58,
#          3898: 117,
#          7522: 50,
#          137: 39,
#          6073: 141,
#          5246: 52,
#          1885: 46,
#          2146: 76,
#          1044: 39,
#          594: 64,
#          6667: 49,
#          262: 47,
#          8399: 332,
#          7692: 129,
#          4766: 168,
#          3123: 64,
#          4756: 68,
#          7823: 33,
#          2670: 127,
#          8702: 56,
#          6912: 79,
#          6329: 152,
#          5325: 69,
#          8699: 44,
#          7147: 317,
#          6786: 42,
#          2057: 70,
#          5448: 61,
#          3700: 88,
#          3732: 279,
#          224: 132,
#          1054: 79,
#          5584: 64,
#          1616: 62,
#          3657: 246,
#          6838: 39,
#          6870: 172,
#          6371: 88,
#          3950: 88,
#          5001: 70,
#          3216: 78,
#          5127: 63,
#          8833: 79,
#          4365: 210,
#          8054: 32,
#          4251: 38,
#          1373: 55,
#          4061: 148,
#          2088: 91,
#          36: 135,
#          5866: 47,
#          633: 55,
#          5369: 189,
#          3051: 40,
#          973: 195,
#          4526: 91,
#          4221: 160,
#          1023: 160,
#          8474: 342,
#          6862: 95,
#          8472: 155,
#          4989: 59,
#          4683: 121,
#          2805: 85,
#          2729: 120,
#          5221: 82,
#          697: 117,
#          7994: 75,
#          8070: 36,
#          4635: 228,
#          8215: 33,
#          141: 91,
#          2035: 203,
#          6196: 177,
#          8487: 393,
#          1580: 62,
#          5979: 204,
#          174: 31,
#          2749: 62,
#          3333: 175,
#          5023: 96,
#          7725: 98,
#          8693: 50,
#          6886: 140,
#          5622: 74,
#          3134: 206,
#          8209: 194,
#          8045: 106,
#          5233: 65,
#          2683: 73,
#          3016: 101,
#          8224: 133,
#          6439: 60,
#          6623: 404,
#          6216: 166,
#          4194: 39,
#          7559: 72,
#          6869: 123,
#          3129: 36,
#          5410: 64,
#          882: 215,
#          4510: 46,
#          2344: 94,
#          7443: 129,
#          6523: 184,
#          6484: 106,
#          8176: 502,
#          6809: 30,
#          5775: 74,
#          1933: 31,
#          5400: 1030,
#          1362: 93,
#          5481: 64,
#          8466: 38,
#          2036: 54,
#          8581: 7013,
#          3293: 1278,
#          6457: 71,
#          3727: 104,
#          4323: 88,
#          1414: 70,
#          1177: 111,
#          6755: 229,
#          4170: 108,
#          4753: 69,
#          5515: 38,
#          3195: 117,
#          3932: 60,
#          4447: 340,
#          7904: 41,
#          3781: 128,
#          8407: 42,
#          3866: 32,
#          1632: 34,
#          101: 37,
#          8730: 108,
#          3894: 141,
#          2720: 82,
#          5259: 41,
#          2712: 166,
#          1569: 195,
#          7621: 261,
#          97: 44,
#          6409: 170,
#          2850: 167,
#          4736: 48,
#          752: 353,
#          6963: 49,
#          7698: 84,
#          8780: 131,
#          5666: 63,
#          7874: 64,
#          3786: 85,
#          26: 101,
#          1: 6889,
#          2972: 95,
#          6651: 71,
#          7813: 176,
#          8553: 120,
#          8589: 41,
#          6518: 60,
#          8551: 376,
#          830: 108,
#          1280: 208,
#          3060: 1207,
#          467: 73,
#          5652: 94,
#          3266: 54,
#          2663: 168,
#          7895: 81,
#          8688: 35,
#          4313: 242,
#          5950: 238,
#          3392: 35,
#          5171: 47,
#          5630: 52,
#          7912: 79,
#          3146: 73,
#          7881: 57,
#          3569: 540,
#          2272: 33,
#          5186: 119,
#          2983: 47,
#          4362: 809,
#          4345: 46,
#          3899: 119,
#          3480: 64,
#          5120: 220,
#          6911: 110,
#          3689: 46,
#          2253: 46,
#          4198: 82,
#          6267: 166,
#          8017: 45,
#          3408: 40,
#          2716: 78,
#          8425: 64,
#          2692: 216,
#          6764: 145,
#          8286: 111,
#          3756: 48,
#          4183: 477,
#          5833: 122,
#          34: 64,
#          2939: 37,
#          7924: 253,
#          6537: 58,
#          1626: 232,
#          3484: 299,
#          2759: 81,
#          5806: 68,
#          21: 31,
#          8499: 78,
#          7689: 105,
#          8266: 42,
#          3642: 514,
#          2109: 89,
#          6017: 113,
#          1048: 176,
#          1827: 43,
#          7557: 45,
#          1906: 77,
#          4092: 124,
#          6851: 216,
#          2357: 131,
#          3485: 115,
#          3289: 351,
#          1923: 84,
#          8696: 70,
#          31: 56,
#          2455: 133,
#          2564: 52,
#          7553: 387,
#          7069: 42,
#          6333: 365,
#          1914: 66,
#          8722: 246,
#          5217: 33,
#          2506: 224,
#          8138: 498,
#          2836: 263,
#          2713: 46,
#          762: 31,
#          6109: 143,
#          1533: 251,
#          1429: 145,
#          7579: 30,
#          8115: 939,
#          2901: 51,
#          2550: 40,
#          1192: 74,
#          2926: 257,
#          7489: 46,
#          2484: 87,
#          6964: 3391,
#          5498: 68,
#          5010: 52,
#          5407: 104,
#          5183: 138,
#          3096: 461,
#          5831: 121,
#          7263: 90,
#          7515: 149,
#          1241: 73,
#          2198: 179,
#          8442: 697,
#          852: 186,
#          286: 54,
#          1064: 130,
#          2331: 72,
#          1547: 35,
#          7681: 324,
#          8735: 46,
#          1500: 119,
#          5354: 114,
#          3889: 39,
#          2856: 260,
#          476: 36,
#          718: 77,
#          5951: 203,
#          5872: 663,
#          6573: 106,
#          1772: 68,
#          1184: 34,
#          5111: 91,
#          7713: 149,
#          2111: 128,
#          5762: 82,
#          4385: 73,
#          4520: 34,
#          6002: 74,
#          6215: 187,
#          7320: 55,
#          7577: 133,
#          4175: 68,
#          610: 36,
#          4015: 64,
#          1603: 66,
#          2049: 45,
#          2216: 198,
#          8411: 189,
#          1542: 42,
#          1624: 81,
#          6965: 965,
#          4173: 53,
#          5199: 154,
#          2632: 71,
#          7765: 78,
#          4886: 106,
#          5392: 209,
#          5981: 50,
#          8541: 69,
#          7111: 52,
#          5766: 45,
#          5398: 349,
#          1342: 32,
#          201: 67,
#          6122: 32,
#          1808: 150,
#          3692: 121,
#          4986: 174,
#          599: 108,
#          4054: 48,
#          7414: 229,
#          3095: 52,
#          3471: 75,
#          4582: 42,
#          665: 230,
#          2127: 40,
#          3914: 342,
#          8847: 83,
#          4508: 144,
#          702: 47,
#          240: 105,
#          8706: 97,
#          7153: 48,
#          3407: 85,
#          7124: 148,
#          8320: 52,
#          632: 175,
#          8008: 180,
#          6081: 69,
#          7035: 115,
#          8206: 45,
#          8750: 74,
#          5848: 178,
#          4707: 43,
#          3201: 138,
#          3755: 119,
#          2290: 234,
#          7208: 165,
#          3630: 130,
#          6994: 213,
#          3397: 71,
#          7609: 112,
#          887: 44,
#          7252: 85,
#          8402: 144,
#          3059: 89,
#          1768: 68,
#          3935: 129,
#          8028: 57,
#          5289: 32,
#          7008: 107,
#          7168: 126,
#          3070: 96,
#          6488: 127,
#          5117: 35,
#          7419: 42,
#          2249: 243,
#          1867: 46,
#          3310: 49,
#          7746: 83,
#          4207: 225,
#          8410: 62,
#          6770: 91,
#          3743: 170,
#          329: 145,
#          8127: 98,
#          1910: 95,
#          2515: 168,
#          6184: 82,
#          5764: 87,
#          6478: 85,
#          3299: 75,
#          3358: 145,
#          1397: 99,
#          1225: 81,
#          8450: 254,
#          4905: 36,
#          759: 204,
#          1001: 35,
#          593: 76,
#          2526: 171,
#          2015: 206,
#          3071: 379,
#          3438: 104,
#          6014: 78,
#          4153: 217,
#          5921: 56,
#          5105: 159,
#          6735: 113,
#          2984: 45,
#          1387: 287,
#          1706: 1005,
#          8380: 392,
#          7623: 83,
#          3062: 34,
#          3812: 222,
#          5456: 83,
#          982: 139,
#          7156: 62,
#          2754: 311,
#          4247: 222,
#          8879: 89,
#          1899: 115,
#          7350: 55,
#          8715: 150,
#          3540: 689,
#          8769: 57,
#          8443: 607,
#          783: 65,
#          8533: 835,
#          2018: 38,
#          2386: 35,
#          480: 57,
#          8361: 338,
#          7922: 219,
#          7142: 90,
#          166: 60,
#          7877: 51,
#          1783: 64,
#          1072: 51,
#          5580: 153,
#          1447: 136,
#          3402: 346,
#          8557: 267,
#          7510: 72,
#          6140: 46,
#          8401: 260,
#          4042: 33,
#          8392: 135,
#          6936: 41,
#          7996: 356,
#          7249: 215,
#          742: 35,
#          8800: 302,
#          5800: 70,
#          7585: 188,
#          7445: 228,
#          6995: 40,
#          7304: 229,
#          8334: 68,
#          5797: 188,
#          5693: 143,
#          6790: 58,
#          8537: 61,
#          1725: 89,
#          8492: 65,
#          2561: 82,
#          7530: 42,
#          3841: 285,
#          8445: 62,
#          1129: 92,
#          5126: 151,
#          3439: 67,
#          7966: 234,
#          1463: 72,
#          657: 55,
#          8639: 77,
#          3587: 232,
#          2267: 31,
#          378: 255,
#          1415: 64,
#          303: 38,
#          6974: 41,
#          994: 99,
#          1548: 32,
#          4963: 129,
#          6772: 92,
#          8393: 276,
#          7390: 37,
#          3617: 81,
#          8120: 273,
#          3613: 51,
#          5471: 207,
#          5782: 41,
#          4470: 47,
#          7827: 93,
#          5695: 71,
#          7291: 60,
#          7373: 509,
#          6169: 47,
#          1902: 45,
#          4760: 202,
#          8298: 687,
#          7141: 63,
#          544: 40,
#          8172: 298,
#          2651: 82,
#          3466: 48,
#          6321: 169,
#          3082: 202,
#          3831: 44,
#          8246: 275,
#          5670: 101,
#          2728: 44,
#          5141: 80,
#          370: 174,
#          7934: 193,
#          6627: 51,
#          754: 93,
#          3922: 76,
#          1992: 491,
#          4306: 57,
#          4081: 106,
#          1339: 99,
#          5742: 38,
#          801: 77,
#          7337: 115,
#          7972: 54,
#          4062: 841,
#          2106: 140,
#          3736: 162,
#          1105: 108,
#          2372: 323,
#          3607: 55,
#          6320: 92,
#          6031: 48,
#          8413: 208,
#          8646: 361,
#          282: 323,
#          636: 106,
#          7266: 131,
#          4677: 66,
#          8521: 68,
#          58: 44,
#          772: 40,
#          5783: 56,
#          4621: 85,
#          5465: 223,
#          6944: 526,
#          6935: 37,
#          7420: 120,
#          8378: 230,
#          138: 49,
#          5625: 34,
#          3094: 176,
#          3321: 85,
#          7739: 31,
#          2697: 68,
#          5335: 239,
#          6411: 79,
#          7137: 261,
#          3951: 87,
#          4088: 127,
#          3235: 32,
#          3536: 58,
#          7865: 37,
#          3317: 142,
#          4296: 61,
#          3202: 50,
#          7029: 60,
#          7211: 460,
#          3396: 37,
#          3754: 83,
#          1096: 37,
#          7622: 86,
#          6456: 212,
#          825: 109,
#          2094: 70,
#          1443: 61,
#          3210: 50,
#          501: 43,
#          5791: 151,
#          8676: 132,
#          3476: 50,
#          1797: 102,
#          5859: 47,
#          4131: 34,
#          8404: 264,
#          4455: 32,
#          2258: 172,
#          2910: 45,
#          8718: 39,
#          5750: 83,
#          210: 180,
#          4812: 98,
#          3931: 113,
#          7288: 41,
#          946: 178,
#          743: 38,
#          7846: 79,
#          7943: 412,
#          6274: 132,
#          5890: 170,
#          3965: 76,
#          6973: 181,
#          6640: 77,
#          6134: 58,
#          7105: 45,
#          1625: 134,
#          6026: 67,
#          3924: 35,
#          1958: 81,
#          6102: 94,
#          3348: 96,
#          8019: 53,
#          1601: 297,
#          6372: 139,
#          8623: 39,
#          2961: 74,
#          7687: 71,
#          3269: 182,
#          2078: 47,
#          4039: 200,
#          3199: 38,
#          4862: 68,
#          967: 113,
#          6830: 154,
#          8275: 135,
#          2209: 333,
#          8773: 294,
#          5798: 59,
#          1279: 36,
#          8075: 36,
#          5283: 53,
#          1053: 227,
#          8140: 57,
#          8107: 59,
#          8458: 682,
#          6442: 124,
#          6414: 161,
#          5081: 44,
#          8826: 101,
#          892: 39,
#          5619: 31,
#          7948: 589,
#          6712: 71,
#          4774: 57,
#          6037: 76,
#          3567: 370,
#          7319: 42,
#          3599: 77,
#          8248: 182,
#          2724: 42,
#          4340: 59,
#          1465: 278,
#          5210: 397,
#          6117: 68,
#          5415: 77,
#          7928: 83,
#          6901: 201,
#          154: 83,
#          250: 125,
#          8836: 441,
#          1826: 73,
#          4383: 107,
#          8424: 75,
#          4078: 46,
#          8322: 76,
#          2398: 74,
#          7926: 98,
#          8583: 87,
#          5729: 36,
#          5328: 51,
#          6149: 165,
#          3283: 78,
#          4667: 239,
#          7835: 59,
#          761: 53,
#          2744: 34,
#          16: 37,
#          214: 633,
#          8235: 534,
#          6306: 76,
#          6877: 346,
#          1349: 47,
#          1996: 173,
#          607: 73,
#          7657: 56,
#          7244: 214,
#          1766: 76,
#          2133: 260,
#          1769: 104,
#          5090: 89,
#          6383: 40,
#          7759: 46,
#          6956: 48,
#          5144: 78,
#          5934: 96,
#          856: 79,
#          438: 130,
#          7811: 91,
#          6174: 45,
#          5913: 71,
#          7377: 48,
#          7524: 31,
#          8523: 145,
#          4601: 69,
#          7121: 684,
#          5947: 54,
#          11: 41,
#          6682: 66,
#          7606: 34,
#          4931: 199,
#          1781: 156,
#          3412: 130,
#          2070: 52,
#          1744: 66,
#          6430: 53,
#          6369: 125,
#          7198: 140,
#          3709: 79,
#          4695: 38,
#          7197: 136,
#          7732: 179,
#          4399: 88,
#          2128: 66,
#          6311: 71,
#          1843: 41,
#          4047: 101,
#          7971: 97,
#          853: 39,
#          3742: 77,
#          1247: 36,
#          8015: 146,
#          8121: 150,
#          6684: 143,
#          1327: 40,
#          694: 120,
#          8385: 454,
#          928: 40,
#          6012: 79,
#          2441: 72,
#          2269: 106,
#          5658: 30,
#          2016: 142,
#          790: 74,
#          2470: 39,
#          7250: 78,
#          1303: 57,
#          8837: 32,
#          2452: 62,
#          7089: 63,
#          1727: 208,
#          8777: 47,
#          979: 288,
#          6011: 350,
#          162: 72,
#          5207: 131,
#          391: 157,
#          1095: 46,
#          6458: 159,
#          8175: 539,
#          6363: 72,
#          7109: 158,
#          2987: 145,
#          2241: 72,
#          5770: 267,
#          4494: 83,
#          1409: 35,
#          995: 186,
#          6076: 91,
#          5012: 213,
#          1275: 58,
#          8287: 94,
#          388: 48,
#          8257: 72,
#          475: 199,
#          490: 85,
#          7108: 124,
#          8076: 46,
#          5769: 98,
#          8134: 102,
#          6716: 178,
#          827: 316,
#          8353: 105,
#          7604: 78,
#          4242: 109,
#          7964: 509,
#          696: 40,
#          5196: 33,
#          7758: 64,
#          3795: 110,
#          7857: 36,
#          8412: 273,
#          3114: 193,
#          381: 104,
#          7103: 76,
#          367: 82,
#          1256: 149,
#          6367: 143,
#          998: 67,
#          1707: 650,
#          2974: 52,
#          784: 91,
#          1428: 41,
#          4684: 365,
#          6024: 102,
#          2464: 222,
#          1219: 34,
#          3103: 39,
#          1033: 72,
#          1718: 300,
#          3433: 45,
#          7294: 94,
#          4299: 111,
#          8270: 221,
#          5639: 91,
#          2469: 92,
#          3601: 60,
#          4445: 32,
#          4473: 106,
#          7159: 71,
#          49: 79,
#          713: 58,
#          3157: 115,
#          662: 30,
#          8150: 227,
#          8471: 315,
#          3574: 92,
#          5172: 128,
#          6654: 123,
#          3217: 56,
#          3464: 79,
#          4817: 70,
#          8747: 250,
#          581: 108,
#          6192: 108,
#          5972: 74,
#          5841: 184,
#          6114: 232,
#          4669: 108,
#          7627: 88,
#          5444: 36,
#          756: 43,
#          4351: 131,
#          5526: 63,
#          7506: 34,
#          2555: 88,
#          6855: 175,
#          3585: 45,
#          3969: 76,
#          1863: 82,
#          769: 41,
#          3423: 47,
#          4540: 106,
#          2742: 70,
#          6702: 158,
#          5330: 111,
#          4942: 179,
#          297: 135,
#          7571: 224,
#          139: 33,
#          7514: 58,
#          1118: 33,
#          706: 264,
#          7851: 77,
#          1504: 40,
#          4431: 98,
#          7635: 87,
#          2449: 139,
#          6893: 59,
#          4208: 39,
#          7702: 340,
#          3420: 263,
#          5740: 74,
#          4433: 32,
#          1405: 144,
#          1593: 117,
#          1919: 53,
#          2425: 102,
#          1619: 93,
#          2195: 199,
#          3002: 47,
#          679: 52,
#          4408: 89,
#          8403: 136,
#          1321: 153,
#          3520: 48,
#          7518: 92,
#          6423: 67,
#          4984: 41,
#          5992: 86,
#          8036: 42,
#          6245: 75,
#          4326: 296,
#          4527: 77,
#          1791: 203,
#          5919: 108,
#          6928: 70,
#          7872: 112,
#          7009: 57,
#          724: 33,
#          2497: 105,
#          8831: 223,
#          941: 131,
#          8097: 1049,
#          2876: 128,
#          4992: 49,
#          8423: 128,
#          4577: 95,
#          8631: 50,
#          1563: 68,
#          5052: 139,
#          5055: 172,
#          7472: 58,
#          1937: 61,
#          3927: 44,
#          4264: 76,
#          1450: 319,
#          255: 67,
#          1994: 162,
#          7637: 66,
#          7736: 539,
#          4007: 114,
#          444: 119,
#          2246: 193,
#          6597: 38,
#          6762: 165,
#          3355: 190,
#          2603: 139,
#          3159: 45,
#          8040: 96,
#          2471: 69,
#          2629: 218,
#          6704: 63,
#          8770: 47,
#          6243: 102,
#          2638: 108,
#          4550: 111,
#          586: 86,
#          1561: 116,
#          4656: 252,
#          5512: 42,
#          1928: 273,
#          4127: 122,
#          6053: 157,
#          1128: 33,
#          1335: 30,
#          1613: 40,
#          7301: 84,
#          8302: 79,
#          3007: 48,
#          5598: 106,
#          7791: 66,
#          4471: 60,
#          8802: 110,
#          7655: 96,
#          4164: 57,
#          4983: 40,
#          2511: 57,
#          8376: 189,
#          5054: 282,
#          8748: 122,
#          6331: 51,
#          434: 45,
#          1620: 34,
#          7643: 190,
#          8223: 195,
#          5386: 100,
#          960: 59,
#          5930: 52,
#          5912: 39,
#          2583: 139,
#          7883: 65,
#          2364: 70,
#          6472: 104,
#          808: 182,
#          7461: 33,
#          6400: 96,
#          7143: 308,
#          4858: 50,
#          8575: 138,
#          7694: 36,
#          5887: 158,
#          6252: 53,
#          6669: 64,
#          8479: 299,
#          2358: 128,
#          1431: 74,
#          4334: 138,
#          4478: 62,
#          549: 82,
#          5198: 40,
#          3176: 40,
#          5212: 147,
#          404: 214,
#          966: 43,
#          6066: 106,
#          ...})

# %%
# for x in dft[(dft.desc.str.contains('campo'))
#             & (dft.desc.str.contains('operatorio') )
#             & (dft.cluster == -1)].desc:
#     print(x)
# Out:
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'constituido', 'de', '4', 'camadas', 'de', 'gaze', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overloque', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embaladaem', 'pacote', 'com', '50', 'pecas', 'com', 'registro', 'no', 'm', 's']
# ['campo', 'operatorio', '23', 'x', '25']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm']
# ['campo', 'operatorio', '23', 'x', '25', 'c', '50']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '25', 'x', '25', 'cm', 'c', '50', 'und']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'tamanho', '25', 'x', '23', 'cm', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '25', 'x', '23', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente']
# ['conjunto', 'odontologico', 'composto', 'de', 'cadeira', 'odontologica', 'eletrica', 'e', 'automatica', 'circuito', 'eletrico', 'inteligente', 'para', 'o', 'inicio', 'e', 'final', 'de', 'trabalho', 'base', 'com', 'dimensao', 'que', 'permite', 'aproximacao', 'do', 'cd', 'asb', 'ao', 'campo', 'operatorio', 'fabricada', 'em', 'ferro', 'fundido', 'sistema', 'tipo', 'pantografico', 'de', 'elevacao', 'movimentos', 'silenciosos', 'e', 'suaves', 'do', 'assento', 'e', 'encosto', 'acionados', 'por', 'dois', 'motoredutores', 'eletricos', 'articulacao', 'central', 'unica', 'entre', 'assento', 'e', 'encosto', 'comando', 'de', 'pe', 'movel', 'com', 'os', 'movimentos', 'de', 'subida', 'e', 'descida', 'do', 'assento', 'e', 'encosto', 'volta', 'a', 'zero', 'sincronizado', 'liga', 'e', 'desliga', 'do', 'refletor', 'com', 'quatro', 'intensidades', 'de', 'luz', 'programaveis', 'tres', 'posicoes', 'de', 'trabalho', 'programaveis', 'com', 'movimentos', 'automaticos', 'e', 'sincronizados', 'de', 'elevacao', 'e', 'inclinacao', 'interrupcao', 'dos', 'movimentos', 'automaticos', 'com', 'um', 'simples', 'toque', 'em', 'qualquer', 'comando', 'estruturas', 'do', 'assento', 'e', 'encosto', 'fabricadas', 'em', 'vergalhoes', 'e', 'chapas', 'de', 'aco', 'dobrado', 'encosto', 'revestido', 'em', 'poliestireno', 'partes', 'metalicas', 'com', 'banho', 'quimico', 'de', 'zinco', 'capas', 'de', 'poliestireno', 'e', 'abs', 'de', 'cant']
# ['675', 'compressa', 'de', 'campo', 'operatorio', '30', 'gr']
# ['campo', 'operatorio', 'nao', 'descartavel', '35', 'cm', 'x', '35', 'cm']
# ['campo', 'operatorio', 'comprimento', '50', 'cm', 'tecido', '100', 'algodao', 'simples', '45', 'cm', 'x', '50', 'cm', '15', 'fios', 'por', 'cm', 'acabamento', 'com', 'ponto', 'overlock', 'branco', 'quatro', 'camadas', 'cantos', 'arredondados', 'cadarco', 'duplo', 'minimo', '18', 'cm', 'pacote', 'c', '50', 'unid']
# ['3', '0971', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'com']
# ['compressa', 'campo', 'operatorio', '23', 'x', '26', 'cm', '50', 'und']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'com', 'filamento', 'radiopaco', 'apresentacao', 'pacote', 'com', '50', 'unidades']
# ['compressas', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'campo', 'operatorio', 'tecido', 'quadruplo', 'quatro', 'camadas', 'com', 'cadarco', '26', 'g', 'unid', '100', 'algodao', 'nao', 'e']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', '15', 'fios']
# ['campo', 'operatorio', '13', 'f', '45', 'x', '50', 'cm']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadassobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'nao', 'esteril', 'sem', 'filamento', 'radiopaco', 'em', 'tecido', 'absorvente', 'isento', 'de', 'amido', 'dextrina', 'corantes', 'corretivos', 'azulados', 'opticos', 'alcalis', 'e', 'acidos', 'cor', 'branca', 'com', 'amarracoes', 'que', 'evitem', 'o', 'deslizamento', 'das', 'mesmas', 'bordas', 'com', 'cantos', 'arredondados', 'cadarco', 'medindo', 'aproximadamente', '18', 'cm', 'peso', 'de', '20', 'gramas', 'por', 'com', 'data', 'de', 'fabricacao', 'e', 'validade', 'numero', 'do', 'lote', 'e', 'registro', 'no', 'ms']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'sem', 'fio', 'radiopaco', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades', 'confeccionado', 'c', 'quatro', 'camadas', 'em', 'tecido', 'macioe', 'neutro', 'altamente', 'absorvente', 'isento', 'de', 'impurezas', 'contendo', 'externamente', 'dados', 'de', 'identificacao', 'procedencia', 'tipo', 'e', 'data', 'de', 'esterilizacao', 'validade', 'numero', 'de', 'lote', 'validade', 'minima', '24', 'meses']
# ['lencol', 'de', 'borracha', 'uso', 'odonto', 'aplicacao', 'para', 'isolamento', 'absolutos', 'do', 'campo', 'operatorio', 'apresentacao', 'espessura', '5', 'x', '5', 'materia', 'prima', 'latex', 'cor', 'azul']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco', 'pacote', 'com', '50', 'unidades', 'cor', 'branca']
# ['684', 'campo', 'operatorio', '23', 'x', '25', '50', 'x', '1']
# ['clorexidina', '2', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'de', 'campo', 'operatorio', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsia']
# ['campo', 'operatorio', '23', 'x', '25']
# ['compressa', 'campo', 'operatorio', '25', 'x', '28', 'cm', 'com', '4', 'camadas']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'pct', 'c', '50', 'unid', 'cremer']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'constituido', 'de', '4', 'camadas', 'de', 'gaze', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overlok', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embalada', 'em', 'pacote', 'com', '50', 'pecas', 'com', 'registro', 'no', 'm', 's']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'pc', '50', 'un', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'elaborada', 'com', 'tecido', '100', 'algodao', 'com', 'quatro', 'camadas', 'de', 'gaze', 'sobrepostas', 'fixadas', 'entre', 'si', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', '50', 'und']
# ['compressa', 'cirurgica', 'para', 'campo', 'operatorio', 'esteril', '30', 'cm', 'x', '30', 'cm']
# ['alcool', 'iodado', 'a', '1', 'indicado', 'para', 'antissepsia', 'da', 'pele', 'em', 'procedimentos', 'invasivos', 'e', 'para', 'demarcacao', 'no', 'campo', 'operatorio', 'com', 'dados', 'de', 'fabricacao', 'procedencia', 'validade', 'vencimento', 'e', 'registro', 'no', 'ms', 'laudo', 'de', 'testes', 'do', 'incqs', 'ou', 'laboratorio', 'credenciado', 'atividade', 'antimicrobiana', 'irritabilidade', 'dermica', 'e', 'ocular', 'embalado', 'em', 'frasco', 'de', 'plastico', 'rigido', 'frasco', 'de', '1', 'litro']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressa', 'para', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'de', 'algodao']
# ['compressa', 'cirurgica', '45', 'cm', 'x', '50', 'cm', 'campo', 'operatorio', 'confecionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'sobreposto', 'tipo', 'tela', 'de', 'forma', 'a', 'evitar', 'deslizamento', 'das', 'camadas', 'com', 'no', 'minimo', '25', 'gramas', 'e', 'com', 'fio', 'radiopaco', 'possuir', 'costuras', 'para', 'evitar', 'desfiamentodas', 'laterias', 'e', 'dispositivos', 'para', 'fixacao', 'em', 'forma', 'de', 'cadarco', 'duplo', 'formando', 'uma', 'alca', 'livre', 'contendo', 'no', 'minimo', '30', 'cm', 'de', 'comprimento', 'dever', 'ser', 'isentas', 'de', 'substancias', 'gordurosas', 'amido', 'corantes', 'alvejantes', 'manchas', 'fios', 'soltos', 'e', 'rasgos', 'embaladas', 'em', 'pacotes', 'com', '50', 'unidades', 'o', 'produto', 'devera', 'atender', 'na', 'nbr', 'sob', 'pena', 'de', 'desclassificacao', 'data', 'de', 'validade', 'superior', 'a', '24', 'meses', 'da', 'data', 'de', 'entrega']
# ['campo', 'operatorio', '45', 'x', '50', 'cm', 'com', '50', 'unid']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'campo', 'operatorio', '23', 'x', '26', 'cm', '50', 'und']
# ['1', '0573', 'compressa', 'campo', 'operatorio', '23', 'x', '25', '50', 'x', '1']
# ['compressa', 'campo', 'operatorio', 'compressa', 'de', 'gaze', 'com', 'cadarco', '45', 'x', '50', 'cm', 'em', 'puro', 'algodao', 'com', '4', 'camadas', 'branca', 'alva', 'validade', '5', 'anos']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', '27', 'gramas', 'nao', 'esteril', '4', 'camadas', 'em', 'tecido', 'de', '100', 'algodao', 'possuindo', 'trama', 'e', 'urdume', 'reguladores', 'com', 'ausencia', 'de', 'fiapos', 'alvejante', 'optico', 'amido', 'e', 'sujidade', 'com', 'alca', 'fixada', 'na', 'borda', 'acabamento', 'com', 'aureola', 'e', 'bainha', 'em', 'overlock', 'embalado', 'em', 'pacotes', 'com', '50', 'unidades', 'com', 'peso', 'minimo', 'de', '1', '350', 'kg', 'o', 'produto', 'devera', 'atender', 'na', 'integra', 'as', 'especificacoes']
# ['clorexidina', '0', '5', 'alcoolico', 'para', 'uso', 'na', 'antissepsia', 'do', 'campo', 'operatorio', 'produto', 'pronto', 'uso', 'sem', 'enxague', 'acondicionado', 'em', 'embalagens', 'de', '1', 'litro', 'contendo', 'os', 'dados', 'impressos', 'de', 'identificacao', 'codigo', 'lote', 'data', 'de', 'fabricacao', 'validade']
# ['2124', 'compressa', 'campo', 'operatorio', '45', 'x', '50', '50', 'x', '1']
# ['compressas', 'cirurgicas', 'campo', 'operatorio', 'nao', 'esteril', '45', 'x', '50', 'tipo', 'i', 'medindo', '45', 'x', '50', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'sobreposto']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '23', 'x', '25', 'constituido', 'de', '4', 'camadas', 'de', 'gaze', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overlok', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso11', '10', 'g', 'embalada', 'em', 'pacote', 'com', '50', 'pecas', 'com', 'registro', 'no', 'm', 's']
# ['compressa', 'campo', 'operatorio', 'compressa', 'de', 'gaze', 'com', 'cadarco', '45', 'x', '50', 'cm', 'em', 'puro', 'algodao', 'com', '4', 'camadas', 'branca', 'alva', 'validade', '5', 'anos']
# ['campo', 'operatorio', 'simples', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'tipo', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['campo', 'operatorio', '23', 'x', '25', 'cm', 'c', '50', 'unid']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'ou', 'sem', 'fio', 'radiopaco', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'cont']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco', 'em', 'tecido', 'absorvente', 'isento', 'de', 'amido', 'dextrina', 'corantes', 'corretivos', 'azulados', 'opticos', 'alcalis', 'eacidos', 'cor', 'branca', 'com', 'amarracoes', 'queevitem', 'o', 'deslizamento', 'das', 'mesmas', 'bordas', 'com', 'cantos', 'arredondados', 'cadarco', 'medindo', 'aproximadamente', '18', 'cm', 'peso', 'de', '20', 'gramas', 'por', 'unidade', 'embalagem', 'esteril', 'em', 'papel', 'grau', 'cirgico', 'com', 'abertura', 'em', 'petala', 'com', 'dados', 'dede', 'identificacao', 'tipo', 'de', 'esterilizacao', 'data', 'de', 'fabricacao', 'e', 'validade', 'numero', 'do', 'lote', 'e', 'registro', 'no', 'ms']
# ['compressa', 'cirurgica', 'para', 'campo', 'operatorio', '45', 'x', '50', 'cm', '50', 'unidades', 'pacotes']
# ['compressa', 'cirrgica', 'campo', 'operatorio', 'ampla', 'concorrencia']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'descartavel', 'nbr', 'tam', '45', 'x', '50']
# ['campo', 'operatorio', '45', 'x', '50', 'cm', 'com', '50', 'unid']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'compressas', 'cirurgicas', 'campo', 'operatorio', 'esteril', 'pre', 'lavado', 'medindo', 'no', 'minimo', '25', 'x', '28', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'sobreposto', 'tipo', 'tela', 'fixadas', 'entre', 'si', 'de', 'forma', 'a', 'evitar', 'deslizamento', 'das', 'camadas', 'com', 'no', 'minimo', '20', 'gramas', 'por', 'unidade', 'e', 'filamento', 'radiopaco', 'possuir', 'costuras', 'para', 'evitar', 'desfiamento', 'das', 'laterais', 'e', 'dispositivo', 'para', 'fixacao', 'em', 'forma', 'de', 'cadarco', 'duplo', 'formando', 'uma', 'alca', 'livre', 'contendo', 'no', 'minimo', '30', 'cm', 'de', 'comprimento', 'a', 'compressa', 'deve', 'ser', 'isentas', 'de', 'substancias', 'gordurosas', 'amido', 'corante', 'corretivo', 'alvejantes', 'optico', 'manchas', 'impurezas', 'fios', 'soltos', 'rasgos', 'e', 'quaisquer', 'outros', 'tipos', 'de', 'defeitos', 'que', 'possam', 'afetar', 'seu', 'desempenho', 'durante', 'o', 'uso', 'embaladas', 'em', 'pacotes', 'de', 'papel', 'grau', 'cirurgico', 'com', 'filme', 'termoplastico', 'contendo', '5', 'unidades', 'o', 'produto', 'devera', 'atender', 'na', 'integra', 'as', 'especificacoes', 'nbr', '14', '767']
# ['campo', 'operatorio', '23', 'x', '25', 'cm', 'c', '50', 'unid']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'descartavel', 'tecido', '100', 'algodao', 'quatro', 'camadas', 'com', 'cadarco', 'e', 'costuras', 'duplas', 'em', 'tecido', 'com', 'alta', 'absorcao', 'gramatura', 'aproximada', 'de', '40', 'g', 'na', 'cor', 'branca', 'com', 'fio', 'radiopaco', 'sem', 'alejante', 'optico', 'e', 'amido', 'no', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'cirurgica', '45', 'x', '50', 'cm', 'campo', 'operatorio', 'nao', 'esteril', 'tecido', 'com', 'alta', 'absorcao', 'gramatura', 'aproximada', 'de', '25', 'g', '100', 'algodao', '4', 'camadas', 'com', 'cadarco', 'e', 'costuras', 'duplas', 'na', 'cor', 'branca', 'com', 'fio', 'radiopaco', 'sem', 'alvejante', 'optico', 'e', 'amido', 'no', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades', 'me', 'epp']
# ['campo', 'operatorio', '23', 'x', '25', 'cm', 'c', '50', 'unid']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'podendo', 'variar', '10', 'para', 'ou', 'para', 'tipo', 'descartavel', 'nao', 'esteril', 'com', 'filamento', 'radiopaco']
# ['campo', 'operatorio', '45', 'x', '50', 'c', '50', 'uni']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '25', 'x', '23', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', 'nao', 'esteril45']
# ['compressacampo', 'operatorio', '23', 'cm', 'x', '25', 'cm', 'alva', 'c50', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'c100', 'emtecidoquadruplo', 'sem', 'fio', 'radiopaco']
# ['compressa', 'cirugica', 'campo', 'operatorio', 'tamanho', '23', 'cm', 'x', '25', 'cm']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'cirurgica', 'para', 'campo', 'operatorio', 'esteril', 'prelavado', 'embalada', 'em', 'envelopes', 'de', 'papel', 'grau', 'cirurgico', 'e', 'filme', 'cada', 'envelope', 'contem', '5', 'unidades', 'embalados', 'em', 'filme', 'plastico', 'especial', 'que', 'permite', 'transferencia', 'asseptica']
# ['campo', 'operatorio', '23', 'x', '25', 'c', '50']
# ['clorexidina', '0', '5', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'de', 'campo', 'operatorio', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsi']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'pc', '50', 'un', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'elaborada', 'com', 'tecido', '100', 'algodao', 'com', 'quatro', 'camadas', 'de', 'gaze', 'sobrepostas', 'fixadas', 'entre', 'si', 'pacote', 'com', '50', 'unidades']
# ['compressas', 'cirurgicas', 'campo', 'operatorio', 'nao', 'esteril', 'tipo', '1', 'medindo', '45', 'x', '50', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'embaladas', 'em', 'pacotes', 'de', '50', 'unidades']
# ['campo', 'operatorio', '40', 'x', '40', 'cm', 'com', '4', 'camadas', 'tecido', '100', 'algodao', 'cru']
# ['compressa', 'para', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'de', 'algodaocompressa', 'para', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'de', 'algodao']
# ['compressa', 'para', 'campo', 'operatorio', 'nao', 'esteril', 'em', 'gaze', 'hidrofila', '100', 'algodao', 'quatro', 'camadas', 'costura', 'dupla', 'tipo', 'tela', 'de', 'algodao', 'presa', 'por', 'friso', 'a', 'cada', '10', 'cm', 'de', 'cor', 'branca', 'alvejada', 'absorvente', 'macia', 'e', 'isenta', 'de', 'impurezas', 'com', 'cadarco', 'duplo', '45', 'cm', 'x', '50', 'cm', 'apresentacao', 'pacote', 'om', '50', 'und']
# ['campo', 'operatorio', '50', 'x', '45', '4', 'camadas100', 'algodao', '38', 'gr', 'uni']
# ['compressas', 'cirurgicas', 'grande', 'campo', 'operatorio']
# ['compressa', 'de', 'gase', 'cirurgica', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '45', 'x', '50', 'cm', 'pct', 'c', '50', 'unid']
# ['compressas', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm', '100', 'algodao', 'elaboradas', 'com', 'tecido', 'quadruplo', '4', 'camadas', 'com', 'cadarco', '30', 'g', 'unidade', 'indicado', 'para', 'cirurgias', 'em', 'geral', 'para', 'absorver', 'sangue', 'e', 'secrecoes', 'liquidas', 'cirurgias', 'cavitarias', 'como', 'anteparo', 'atraumatico', 'de', 'visceras', 'e', 'tecidos', 'embalagem', 'com', '50', 'unidades']
# ['clorexidina', '2', 'formula', 'de', 'gluconato', 'de', 'clprexidina', '2', 'alcool', 'etilico', '2', 'tenoativo', 'emoliente', 'agua', 'qsp', '100', 'solucao', 'degermante', 'antisepsia', 're', 'cirurgica', 'preparacao', 'campo', 'operatorio', 'e', 'banho', 'de', 'pacientes', 'embalagem', 'contendo', 'composicao', 'quimica', 'lote', 'registro', 'no', 'ministerio', 'da', 'saude', 'responsavel', 'instrucoes', 'de', 'uso', 'e', 'precaucoes', 'data', 'de', 'fabricacao', 'e', 'validade', 'almotolia', 'de', '100', 'ml', 'com', 'bico', 'dosador']
# ['compressas', 'cirurgicas', 'campo', 'operatorio', 'nao', 'esteril', 'tipo', '1', 'medindo', '45', 'x', '50', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'embaladas', 'em', 'pacotes', 'de', '50', 'unidades']
# ['campo', 'operatorio', 'tecido', '100', 'algodao', 'com', 'fio', 'radiopaco', '45', 'cm', '50', 'cm', '15', 'fio', 'cm2', 'branca', '4', 'camadas', 'cantos', 'arredondados', 'cadarco', 'duplo', 'minimo', '18', 'cm']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm']
# ['2124', 'compressa', 'campo', 'operatorio', '45', 'x', '50', '50', 'x', '1']
# ['compressa', 'cirurgica', 'para', 'campo', 'operatorio', 'esteril', 'prelavado', 'embalada', 'em', 'envelopes', 'de', 'papel', 'grau', 'cirurgico', 'e', 'filme', 'cada', 'envelope', 'contem', '5', 'unidades', 'embalados', 'em', 'filme', 'plastico', 'especial', 'que', 'permite', 'transferencia', 'asseptica']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'alva', '38', 'g', '4', 'camadas', 'com', 'cadarco', 'pacote', 'com', '50', 'unidades', '50', 'cm', 'x', '45', 'cm', 'elaborada', 'em', 'tecido', 'quadruplo', 'quatro', 'camadas', '100', 'algodao', 'altamente', 'absorvente', 'macio', 'e', 'isento', 'de', 'impurezas', 'as', 'camadas', 'de', 'tecido', 'possuem']
# ['clorexidina', '2', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'de', 'campo', 'operatorio', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsia']
# ['campo', 'operatorio', '50', 'x', '50', 'cm', '50', 'unid', '9']
# ['campo', 'operatorio', '40', 'x', '50', 'mts']
# ['compressa', 'campo', 'operatorio', 'compressa', 'de', 'gaze', 'com', 'cadarco', '45', 'x', '50', 'cm', 'em', 'puro', 'algodao', 'com', '4', 'camadas', 'branca', 'alva', 'validade', '5', 'anos']
# ['campo', 'operatorio', 'nao', 'esteril23']
# ['compressa', 'de', 'campo', 'operatorio', '100', 'algodao', '45', 'x', '50', 'cm']
# ['campo', 'operatorio', 'compressa', 'cirurgica', 'tam', '45', 'x', '50', 'cm', '100', 'algodao', 'c', '4', 'camadas', 'c', 'trama', 'uniforme', 'c', 'cardaco', 'e', 'acabamento', 'nas', 'bordas', 'pac', 'c', '50', 'und']
# ['51', '0010', 'campo', 'operatorio', 'descartavel', '45', 'cm', 'x', '50', 'cm']
# ['campo', 'operatorio', 'nao', 'esteril', '45', 'x', '50', 'tamanho', '45', 'cm', 'x', '50', 'cm', 'gramatura', '25', 'g', 'leve', '40', 'fios', '100', 'algodao', 'nao', 'esteril', 'composto', 'de', 'ligamento', 'tela', 'tafeta', 'embalados', 'em', 'embalagens', 'plasticas', 'produto', 'alvejado', 'isentos', 'de', 'impureza', 'alvejante', 'optico', 'e', 'residuo', 'de', 'amido']
# ['campo', 'operatorio', 'campos', 'operatorios', '45', 'x', '50', 'campos', 'operatorios', 'constituido', 'de', 'quatro', 'camadas', 'de', 'gaze', 'hidrofila', 'na', 'cor', 'branca', 'unidas', 'por', 'costura', 'reforcada', 'nos', 'quatros', 'cantos', 'com', 'bordas', 'devidamente', 'acabadas', 'em', 'forma', 'de', 'alca', 'fixado', 'na', 'margem', 'do', 'quadrante', 'superior', 'externo', 'tamanho', '45', 'x', '50']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'esteril']
# ['lencol', 'de', 'borracha', 'para', 'isolamento', 'absoluto', 'do', 'campo', 'operatorio', 'lencol', 'descartavel', 'produzido', 'com', 'latex', 'natural', 'uniforme', 'e', 'sem', 'estrias', 'espessura', 'media', 'muito', 'resistente', 'nao', 'rasga', 'durante', 'os', 'procedimentos', 'cor', 'azul', 'tamanho', '13', '5', 'cm', 'x', '13', '5', 'cm', 'aromatizado', 'mentolado', 'ou', 'tutti', 'frutti', 'apresentacao', 'caixa', 'em', 'formato', 'gaveta', 'com', '26', 'unidades', 'com', 'fabricante', 'lote', 'e', 'data', 'de', 'validade', 'impressas', 'registro', 'na', 'anvisa', 'validade', 'minima', 'de', '2', 'anos', 'apos', 'data', 'de', 'entrega', 'no', 'almoxarifado', 'da', 'prefeitura', 'de', 'pocos', 'de', 'caldas', 'os', 'concorrentes', 'deverao', 'apresentar', 'produto', 'a', 'fim', 'verificacao', 'da', 'conformidade', 'com', 'as', 'caracteristaicas', 'do', 'item']
# ['campo', 'operatorio', 'nao', 'esteril23']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'constituido', 'de', '4', 'camadas', 'de', 'gaze', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overloque', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embalada', 'em', 'pacote', 'com', '50', 'pecas', 'com', 'registro', 'no', 'm', 's']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'de', 'campo', 'operatorio', 'nao', 'esteril', '100', 'algodao', '45', 'x', '50', 'cm', 'simples', 'livre']
# ['campo', 'operatorio', '23', 'x', '25', 'com', '50']
# ['compressa', 'cir', 'campo', 'operatorio', '45', 'x', '50']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco']
# ['campo', 'operatorio', 'campos', 'operatorios', '23', 'x', '25', 'campos', 'operatorios', 'constituido', 'de', 'quatro', 'camadas', 'de', 'gaze', 'hidrofila', 'na', 'cor', 'branca', 'unidas', 'por', 'costura', 'reforcada', 'nos', 'quatros', 'cantos', 'com', 'bordas', 'devidamente', 'acabadas', 'em', 'forma', 'de', 'alca', 'fixado', 'na', 'margem', 'do', 'quadrante', 'superior', 'externo']
# ['3', '0971', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'com']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco']
# ['campo', 'cirurgico', 'operatorio', 'tnt']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'o']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco', 'pacote', 'com', '50', 'unidades', 'cor', 'branca']
# ['lencol', 'de', 'borracha', 'uso', 'odonto', 'aplicacao', 'para', 'isolamento', 'absolutos', 'do', 'campo', 'operatorio', 'apresentacao', 'espessura', '5', 'x', '5', 'materia', 'prima', 'latex', 'cor', 'azul']
# ['iodopovina', '10', 'pvpi', 'degermante', 'pvp', 'i', 'solucao', 'com', 'tenso', 'ativos', 'ou', 'determante', 'eum', 'antisseptico', 'a', 'base', 'de', 'iodopolividona', 'contendo', 'tenso', 'ativos', 'e', 'agentes', 'umectantes', 'responsaveis', 'pela', 'anti', 'sepsia', 'das', 'maos', 'e', 'antebracos', 'da', 'equipe', 'cirurgica', 'e', 'descontamincao', 'do', 'campo', 'operatorio', 'uso', 'adulto', 'e', 'pediatrico', 'conforme', 'orientacaomedica', 'composicao', 'iodopolivina', '10', 'excipientes', 'qsp', 'fosfato', 'dissodico', 'laurealeter', 'sulfato', 'de', 'sodio', 'glicerina', 'acido', 'citrico', 'iodato', 'de', 'potassio', 'e', 'agua', 'deionizada', 'descricao', 'frasco', 'de', '1000', 'ml', 'solucao', 'de', 'isopolividona', 'a', '10', 'com', 'tensoativos', 'registro', 'na', 'anvisa', '1', '3', '382', '8']
# ['campo', 'operatorio', '23', 'x', '25', 'c', '50', 'uni']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'cm', 'constituindo', 'de', '4', 'camadas', 'de', 'gases', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overloque', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embaladas', 'em', 'pacote', 'com', '50', 'pecas', 'procedencia', 'nacional']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'cm', '4', 'camadas', 'c', 'cadarco', 'pacote', 'com', '50']
# ['clorexidina', '2', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'de', 'campo', 'operatorio', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsia']
# ['compressas', 'cirurgicas', 'campo', 'operatorio', 'nao', 'esteril', 'tipo', '1', 'medindo', '45', 'x', '50', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'embaladas', 'em', 'pacotes', 'de', '50', 'unidades']
# ['campo', 'operatorio', '45', 'x', '50', 'cm', 'com', '50', 'unid']
# ['z191', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'esteril', 'pa']
# ['campo', 'operatorio', 'duplo', '1', '60', 'x', '1', '60', 'm', '100', 'algodao']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'cm', 'constituido', 'de', '4', 'camadas', 'de', 'gazes', 'sobrepostas', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cmcm', 'constituido', 'de', '4', 'camadas', 'de', 'gazes', 'sobrepostas', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cada', 'camada', 'pacote', 'com', '50', 'pecas']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'em', 'tecido', 'de', '100', 'algodao', '15', 'fios', 'cm2', 'medindo', '45', 'x', '50', 'cm']
# ['compressa', 'campo', 'operatorio', 'nao', 'esteril', '23', 'x', '25', 'cm', '4', 'camadas', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', '23', 'x', '25', 'com', '50', 'unds']
# ['campo', 'operatorio', '23', 'x', '25']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'pct', '50', 'un']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'ou', 'sem', 'fio', 'radiopaco', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'cont']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'em', 'tecido', 'de', '100', 'algodao', '15', 'fios', 'cm2', 'medindo', '45', 'x', '50', 'cm']
# ['lencol', 'de', 'borracha', 'uso', 'odonto', 'aplicacao', 'para', 'isolamento', 'absolutos', 'do', 'campo', 'operatorio', 'apresentacao', 'espessura', '5', 'x', '5', 'materia', 'prima', 'latex', 'cor', 'azul']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '25', 'cm', 'x', '23', 'cm', '4', 'camadas', 'com', 'cadarco', 'radiopaco', '100', 'algodao', 'nao', 'esteril', 'pacote', 'c', '50', 'unid']
# ['compressa', 'campo', 'operatorio', 'nao', 'esteril', '45', 'x', '50', 'cm']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco', 'pacote', 'com', '50', 'unidades', 'cor', 'branca']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', '13', 'fios', '8', 'dobras', 'com', '50', 'und']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'dimensao', '45', 'cm', 'x', '50', 'cm', 'quatro', 'camadas', 'e', '100', 'algodao', 'pc', 'c', '50', 'un']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'dimensao', '45', 'cm', 'x', '50', 'cm', 'quatro', 'camadas', 'e', '100', 'algodao', 'pc', 'c', '50', 'un']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressa', 'campo', 'operatorio', 'elaboradas', 'com', 'tecido', 'quadruplo', 'quatro', 'camadas', '100', 'algodao', 'altamente', 'absorvente', 'isento', 'de', 'substancias', 'gordurosas', 'amido', 'e', 'alvejantes', 'opticos', 'as', 'camadas', 'de', 'tecido', 'devem', 'possuir', 'amarracoes', 'evitando', 'que', 'uma', 'camada', 'deslize', 'sobre', 'a', 'outra', 'no', 'uso', 'as', 'bordas', 'devem', 'possuir', 'costura', 'para', 'evitar', 'o', 'desfiamento', 'e', 'uma', 'das', 'bordas', 'deve', 'apresentar', 'cadarco', 'duplo', 'nao', 'esteril', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', '100', 'puro', 'algodao', 'macio', 'e', 'extra', 'absorvente', 'tamanho', '45', 'cm', 'x', '50', 'cm', 'dermatologicamente', 'testado', 'produto', 'descartavel', 'devidamente', 'registrado', 'no', 'ministerio', 'da', 'saude']
# ['campo', 'operatorio', 'compressa', 'cirurgica', '45', 'x', '50', 'pct', 'c', '50', 'unid']
# ['compressa', 'cirugica', 'campo', 'operatorio', 'tamanho', '45', 'x', '50', 'cm']
# ['campo', 'operatorio', '23', 'x', '25']
# ['compressa', 'cirurgica', '45', 'x', '50', 'cm', 'campo', 'operatorio', 'nao', 'esteril', 'tecido', 'com', 'alta', 'absorcao', 'gramatura', 'aproximada', 'de', '25', 'g', '100', 'algodao', '4', 'camadas', 'com', 'cadarco', 'e', 'costuras', 'duplas', 'na', 'cor', 'branca', 'com', 'fio', 'radiopaco', 'sem', 'alvejante', 'optico', 'e', 'amido', 'no', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', '4', 'camadas', 'com', 'cadarco', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'tamanho', '45', 'x', '50', 'em', 'pcts', 'com', '50', 'unidades']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'tamanho', '45', 'x', '50', 'cm', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '45', 'x', '50', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente']
# ['2124', 'compressa', 'campo', 'operatorio', '45', 'x', '50', '50', 'x', '1']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', '35', 'gramas', 'compressa', 'de', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'nao', 'esteril', '4', 'camadas', 'em', 'tecido', '100', 'algodao', 'possuindo', 'trama', 'e', 'urdume', 'regulares', 'com', 'ausencia', 'de', 'fiapos', 'alvejante', 'optico', 'amido', 'e', 'sujidade', 'com', 'alca', 'fixada', 'na', 'borda', 'acabamento', 'com', 'aureola', 'e', 'bainha', 'em', 'overlock', 'embalado', 'em', 'pacotes', 'com', '50', 'unidades', 'com', 'peso', 'minimo', 'de', '1', '750', 'kg', 'o', 'produto', 'devera', 'atender', 'na', 'integra', 'as', 'especificacoes', 'da', 'nbr', '14', '767', 'registro', 'anvisa']
# ['campo', 'operatorio', '23', 'x', '25', 'com', '50']
# ['campo', 'operatorio', 'cota']
# ['1659', 'compressa', 'campo', 'operatorio', '25', 'cm', 'x', '28', 'cm']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '25', 'x', '23', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', 'nao', 'esteril', '23', 'cm', 'x', '25', 'cm', 'c', '50']
# ['campo', 'operatorio', 'quatro', 'camadas', '45', 'x', '50', 'cm', '50', 'x1', 'und']
# ['compressa', 'para', 'campo', 'operatorio', 'nao', 'esteril', 'em', 'gaze', 'hidrofila', '100', 'algodao', 'quatro', 'camadas', 'costura', 'dupla', 'tipo', 'tela', 'de', 'algodao', 'presa', 'por', 'friso', 'a', 'cada', '10', 'cm', 'de', 'cor', 'branca', 'alvejada', 'absorvente', 'macia', 'e', 'isenta', 'de', 'impurezas', 'com', 'cadarco', 'duplo', '45', 'cm', 'x', '50', 'cm', 'apresentacao', 'pacote', 'om', '50', 'und']
# ['compressas', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'sao', 'elaboradas', 'com', 'tecido', 'quadruplo', '4', 'camadas', '100', 'algodao', 'nao', 'esteril', '4', 'camadas', 'com', 'cadarco', 'nidia', '30', 'g', 'por', 'unidade', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'puro', 'algodao', 'camadas', 'com', 'cadarco', 'tamanho', '23', 'x', '25', 'cm', 'pacote', 'com', '100', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '23', 'cm', 'x', '25', 'cm']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '23', 'cm', 'x', '25', 'cm']
# ['compressa', 'campo', 'operatorio', '23', 'x', '25', 'cm', '50', 'und']
# ['compressas', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'compressas', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm', '100', 'algodao', 'elaboradas', 'com', 'tecido', 'quadruplo', '4', 'camadas', 'com', 'cadarco', '30', 'g', 'unidade', 'indicado', 'para', 'cirurgias', 'em', 'geral', 'para', 'absorver', 'sangue', 'e', 'secrecoes', 'liquida']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'cm', 'constituindo', 'de', '4', 'camadas', 'de', 'gases', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm', 'aproximadamente', 'em', 'cada', 'camada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overloque', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embaladas', 'em', 'pacote', 'com', '50', 'pecas', 'procedencia', 'nacional']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'compressa', 'cirurgica', 'campo', 'operatorio', 'alva', '38', 'g', '4', 'camadas', 'com', 'cadarco', 'pacote', 'com', '50', 'unidades', '50', 'cm', 'x', '45', 'cm', 'elaborada', 'em', 'tecido', 'quadruplo', 'quatro', 'camadas', '100', 'algodao', 'altamente', 'absorvente', 'macio', 'e', 'isento', 'de', 'i']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressas', 'cirurgica', 'campo', 'operatorio', 'com', '13', 'fios', 'de', 'algodao', 'cm2', '23', 'cm', 'x', '25', 'cm', 'c', '50', 'unid']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'com', 'filamento', 'radiopaco']
# ['campo', 'operatorio', '100', 'algodao', 'com', 'cadarco', 'tamanho', '45', 'x', '50', 'cm', '13', 'fios', '4', 'camadas', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', '23', 'x', '25', 'com', '50']
# ['campo', 'operatorio', 'c', '50', 'unidades', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'com', '50', 'unidades']
# ['clorexidina', '0', '5', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'de', 'campo', 'operatorio', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsi']
# ['campo', 'operatorio', 'simples', 'medida', '45', 'x', '50', 'cm', 'com', '13', 'fio', 'cm2']
# ['campo', 'operatorio', 'fenestrado', 'nao', 'descartavel', 'em', 'brim', '100', 'algodao', '45', 'x', '45', 'cm']
# ['foco', 'cirurgico', 'de', 'teto', 'com', 'duas', 'cupulas', 'sistema', 'de', 'iluminacao', 'a', 'led', 'equipamento', 'com', 'cupula', 'em', 'fibra', 'de', 'vidro', 'estrutura', 'emaco', 'com', 'pintura', 'epoxi', 'uso', 'grandese', 'medios', 'procedimentos', 'luminancia', 'sistema', 'de', 'eliminacao', 'de', 'sombras', 'com', 'filtro', 'de', 'radiacao', 'termica', 'sem', 'incidencia', 'de', 'calor', 'no', 'campo', 'operatorio', 'ajuste', 'do', 'foco', 'o', 'ajuste', 'de', 'foco', 'no', 'campo', 'operatorio', 'e', 'realizado', 'atraves', 'de', 'manoplas', 'esterilizaveis', 'em', 'aluminio', 'temperatura', 'de', 'cor', '5000', 'k', 'vida', 'util', 'dos', 'leds', 'aproximadamente', '50', '000', 'horas', 'dimmer', 'regulador', 'de', 'intensidade', 'de', 'luminancia', 'entre', '10', 'a', '100', 'da', 'potencia', 'do', 'foco', 'localizado', 'na', 'propria', 'estrutura', 'do', 'foco', 'cirurgico', 'movimentos', 'leves', 'e', 'precisos', 'onde', 'podemos', 'realizar', 'torcao', 'flexao', 'basculante', 'vertical', 'e', 'circular', 'giro', 'de', '360', 'sem', 'o', 'uso', 'de', 'contra', 'pesos', 'com', 'sistema', 'de', 'freio', 'quemantem', 'a', 'cupula', 'na', 'posicao', 'estabelecida', 'diametro', 'da', 'cupula', '587', 'mm', 'luminanciano', 'campo', 'operatorio', 'minimo', 'de', '240', '000', 'lux', '120', '000', 'lux', 'por', 'cupula', 'profundidade', 'da', 'coluna', 'luminosa', '1000', 'mm', 'indice', 'de', 'rep']
# ['compressa', 'campo', 'operatorio', 'nao', 'esteril', '23', 'cm', 'x', '25', 'cm', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '23', 'cm', 'x', '25', 'cm']
# ['campo', 'operatorio', 'tipo', 'tecido', '100', 'algodao', 'simples', 'comp45', 'larg50', 'textura', '15', 'fioscm2', 'material', 'acabam', 'c', 'ponto', 'overlock', 'cor', 'branca', 'caracteristicas', 'adicionais', '4', 'camadas', 'cantos', 'arredondados', 'tipo', 'uso', 'cadarco', 'duplo', 'minimo', '18', 'cm', 'pcte', 'c', '50', 'uni']
# ['compressa', 'cirugica', 'campo', 'operatorio', 'tamanho', '23', 'cm', 'x', '25', 'cm']
# ['compressa', 'campo', 'operatorio', '23']
# ['campo', 'operatorio', '45', 'x', '50', 'c', '50', 'uni']
# ['campo', 'operatorio', '23', 'x', '25', 'cm', 'c', '50', 'unid']
# ['campo', 'operatorio', '42', 'x', '53', 'confeccionado', 'em', 'americano', 'cru', 'duplo', 'com', '56', 'fios', 'por', 'cm2', 'e', 'gramatura', 'de', '200', 'gramas', 'por', 'm2', 'com', 'dimensoes', '42', 'x', '53', 'cm', 'silkado', 'com']
# ['campo', 'operatorio', '45', 'x', '50', 'tamanho', 'g']
# ['compressa', 'campo', 'operatorio', '23', 'x', '25', 'cm', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', '50', 'x', '45', '4', 'camadas', '100', 'algodao', '38', 'gr', 'unidade']
# ['campo', 'operatorio', 'comprimento', '50', 'cm', 'tipo', 'impermeavel', 'largura', '50', 'cm', 'textura', 'hidrorrepelente', 'barreira', 'fluidos', 'e', 'microorganismo', 's', 'material', 'polipropileno', 'nao', 'tecido', 'esterilidade', 'esteril', 'tipo', 'embalagem', 'embalagem', 'dupla', 'pacote', 'com', '10', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '25', 'x', '25', 'com', '50', 'und']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'ou', 'sem', 'fio', 'radiopaco', 'a', 'compressa', 'resulta', 'do', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', '4']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '45', 'x', '50', 'com', '50', 'und']
# ['campo', 'operatorio', 'esteril', 'pre', 'lavado', '45', 'x', '50', 'cm']
# ['campo', 'operatorio', '23', 'x', '25']
# ['compressa', 'campo', 'operatorio', '23', 'x', '25', 'cm', '50', 'und']
# ['1', '0573', 'compressa', 'campo', 'operatorio', '23', 'x', '25', '50', 'x', '1']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'com', '50', 'unidades']
# ['campo', 'operatorio', '1', 'x', '1', 'tecido', 'algodao']
# ['compressa', 'para', 'campo', 'operatorio', 'nao', 'esteril', 'em', 'gaze', 'hidrofila', '100', 'algodao', 'quatro', 'camadas', 'costura', 'dupla', 'tipo', 'tela', 'de', 'algodao', 'presa', 'por', 'friso', 'a', 'cada', '10', 'cm', 'de', 'cor', 'branca', 'alvejada', 'absorvente', 'macia', 'e', 'isenta', 'de', 'impurezas', 'com', 'cadarco', 'duplo', '45', 'cm', 'x', '50', 'cm', 'apresentacao', 'pacote', 'om', '50', 'und']
# ['campo', 'operatorio', 'tipo', 'tecido', '100', 'algodao', 'simples', 'comp45', 'larg50', 'textura', '15', 'fioscm2', 'material', 'acabam', 'c', 'ponto', 'overlock', 'cor', 'branca', 'caracteristicas', 'adicionais', '4', 'camadas', 'cantos', 'arredondados', 'tipo', 'uso', 'cadarco', 'duplo', 'minimo', '18', 'cm', 'pcte', 'c', '50', 'uni']
# ['campo', 'operatorio', '100', 'algodao', 'com', 'cadarco', 'tamanho', '45', 'x', '50', 'cm', '13', 'fios', '4', 'camadas', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'descartavel', 'tecido', '100', 'algodao', 'quatro', 'camadas', 'com', 'cadarco', 'e', 'costuras', 'duplas', 'em', 'tecido', 'com', 'alta', 'absorcao', 'gramatura', 'aproximada', 'de', '40', 'g', 'na', 'cor', 'branca', 'com', 'fio', 'radiopaco', 'sem', 'alejante', 'optico', 'e', 'amido', 'no', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '45', 'x', '50', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'tipo', 'campo', 'operatorio', 'em', 'tecido', 'absorvente', '100', 'algodao', 'medindo', '45', 'x', '50', 'cm', 'esteril', 'c']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'com', 'filamento', 'radiopaco', 'apresentacao', 'pacote', 'com', '50', 'unidades']
# ['campo', 'operatorio', 'nao', 'descartavel', '50', 'x', '50', 'cm']
# ['51', '0010', 'campo', 'operatorio', 'descartavel', '45', 'cm', 'x', '50', 'cm']
# ['1395', 'campo', 'operatorio', '23', 'x', '25', 'c', '50']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'com', 'filamento', 'radiopaco', 'apresentacao', 'pacote', 'com', '50', 'unidades']
# ['solucao', 'de', 'digluconato', 'de', 'clorexidina', 'a', '0', '5', '1', 'litro', 'solucao', 'alccolica', 'topica', 'utilizado', 'no', 'preparo', 'do', 'campo', 'operatorio', 'embalagem', 'de', '1', 'litro', 'contendo', 'dados', 'de', 'identificacao', 'lote', 'validade', 'e', 'registro', 'ms', 'com', 'qualidade', 'igual', 'ou', 'superior', 'a', 'rioquimica']
# ['campo', 'operatorio', 'compressa', 'cirurgica', '45', 'x', '50', 'pct', 'c', '50', 'unid', 'similar', 'ou', 'superior', 'a', 'marca', 'biotextil']
# ['compressa', 'cirurgica', 'de', 'campo', 'operatorio', '23', 'x', '25']
# ['1395', 'campo', 'operatorio', '23', 'x', '25', 'c', '50']
# ['compressa', 'de', 'campo', 'operatorio', 'sem', 'radiopaco', 'medindo', '45', 'x', '50', 'constituido', 'de', '4', 'camadas', 'de', 'gaze', 'sobreposta', 'contendo', '15', '8', 'x', '7', 'fios', 'por', 'cm2', 'aproximadamente', 'em', 'cadacamada', 'cor', 'branca', 'bordas', 'devidamente', 'acabadas', 'atraves', 'do', 'ponto', 'overlok', 'formato', 'retangular', 'provido', 'de', 'alca', 'cantos', 'arredondados', 'peso', '41', '40', 'g', 'embalada', 'em', 'pacote', 'com', '50', 'pecas', 'com', 'registro', 'no', 'm', 's']
# ['campo', 'operatorio', '35', 'g', '45', 'x', '50', 'c', '50', '4', 'camadas', 'c', 'cadarco', 'plascap', 'mb', 'textil']
# ...
# ['51', '0009', 'campo', 'operatorio', 'descart', '25', 'cm', 'x', '28', 'cm']
# ['campo', 'operatorio', '50', 'x', '50', 'cm', '50', 'unid', '9']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '25', 'x', '23', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '4', 'camadas', 'de', 'gaze', 'com', 'cadarco', '45', 'cm', 'x', '50', 'cm', 'tipo', '27', 'pacote', 'contem', '50', 'unidades', '100', 'algodao']
# ['campo', 'simples', 'operatorio', '1', '00', 'x', '1', '00']
# ['campo', 'operatorio', 'nao', 'esteril45']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'descartavel', 'tecido', '100', 'algodao', '4', 'camadas', 'com', 'cadarco', 'e', 'costuras', 'duplas', 'em', 'tecido', 'em', 'alta', 'absorcao', 'gramatura', 'aproximadamente', 'de', '40', 'g', 'na', 'cor', 'branca', 'com', 'fio', 'radiopaco', 'sem', 'alvejante', 'optico', 'e', 'amido', 'no', 'tamanho', '45', 'x', '50', 'cm', 'pacote', 'com', '50', 'unidades', 'referencia', 'cremer', 'bio', 'textil', 'ou', 'similar']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'o']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm', '38', 'g', 'pacote', 'contendo', '50', 'unidades']
# ['campo', 'operatorio', 'compressa', 'cirurgica', '45', 'x', '50', 'pct', 'c', '50', 'unid']
# ['a', 'compressa', 'cirurgica', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'e', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'a', 'compressa', 'result']
# ['campo', 'operatorio', '45', 'x', '50', 'c', '50', 'und', 'c', 'cadarco']
# ['compressacampo', 'operatorio', '23', 'cm', 'x', '25', 'cm', 'alva', 'c50', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'c100', 'emtecidoquadruplo', 'sem', 'fio', 'radiopaco']
# ['25', 'campo', 'operatorio', '25', 'x', '28', 'cm', 'c', '4', 'camadas', 'pct']
# ['campo', 'operatorio', 'compressa', 'cirurgica', 'tecido', 'em', 'gaze']
# ['foco', 'cirurgico', 'teto', '3', 'l', 'com', 'no', 'minimo', '50', 'leds', 'de', 'iluminacao', 'de', 'fixacao', 'em', 'teto', 'articulacao', 'para', 'movimentacao', 'do', 'braco', 'partes', 'metalicas', 'revestidas', 'com', 'pintura', 'eletrotastica', 'a', 'po', 'na', 'cor', 'branco', 'gelo', 'desenvolvido', 'para', 'cirurgia', 'de', 'pequeno', 'com', 'iluminacao', 'mais', 'abrangente', 'no', 'campo', 'operatorio']
# ['iodopovina', '10', 'pvpi', 'topico', 'anti', 'septico', 'a', 'base', 'de', 'iodopovina', 'em', 'solucao', 'aquosa', 'e', 'uma', 'preparacao', 'ativa', 'contra', 'uma', 'ampla', 'gama', 'de', 'microorganismos', 'cuja', 'acao', 'anti', 'septica', 'rapida', 'e', 'de', 'efeito', 'residual', 'e', 'garantida', 'pelo', 'iodopovidona', 'um', 'complexo', 'quimico', 'estavel', 'que', 'libera', 'o', 'iodo', 'progressivamente', 'produto', 'destinado', 'ao', 'uso', 'de', 'hospitais', 'e', 'um', 'anti', 'septico', 'hospitalar', 'indicado', 'para', 'curativos', 'em', 'geral', 'queimaduras', 'traumatismos', 'ferimentos', 'superficiais', 'da', 'pele', 'e', 'na', 'anti', 'sepsia', 'complementar', 'do', 'campo', 'operatorio', 'frasco', 'de', '1', 'litro']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'alva', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'pct', 'com', '50', 'unid']
# ['675', 'compressa', 'de', 'campo', 'operatorio', '30', 'gr']
# ['campo', 'operatorio', '42', 'x', '53', 'confeccionado', 'em', 'americano', 'cru', 'duplo', 'com', '56', 'fios', 'por', 'cm2', 'e', 'gramatura', 'de', '200', 'gramas', 'por', 'm2', 'com', 'dimensoes', '42', 'x', '53', 'cm', 'silkado', 'com']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressa', 'de', 'gase', 'cirurgica', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '45', 'x', '50', 'cm', 'pct', 'c', '50', 'unid']
# ['solucao', 'de', 'digluconato', 'de', 'clorexidina', 'a', '0', '5', '1', 'litro', 'solucao', 'alccolica', 'topica', 'utilizado', 'no', 'preparo', 'do', 'campo', 'operatorio', 'embalagem', 'de', '1', 'litro', 'contendo', 'dados', 'de', 'identificacao', 'lote', 'validade', 'e', 'registro', 'ms', 'com', 'qualidade', 'igual', 'ou', 'superior', 'a', 'rioquimica']
# ['campo', 'operatorio', 'nao', 'esteril45']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', '50', 'und']
# ['campo', 'operatorio', 'esteril', 'campo', 'operatorio', 'esteril', 'medindo', '25', 'cm', 'x', '28', 'cm', 'cf', 'portaria', '106', '3', 'inmetro', 'e', 'abnt', 'nbr', 'em', 'trama', 'de', 'croche', 'de', 'fo']
# ['campo', 'operatorio', '45', 'x', '50', 'com', '50', 'compressa']
# ['compressa', 'de', 'campo', 'operatorio', '50', 'x', '45', 'cm', '11', 'fios']
# ['campo', 'operatorio', 'compressa', 'cirurgica', 'light', 'linha', 'hospitalar', '27', '50', 'compressas', '4', 'camadas', 'com', 'cadarco']
# ['1', '0573', 'compressa', 'campo', 'operatorio', '23', 'x', '25', '50', 'x', '1']
# ['compressa', 'campo', 'operatorio', '23', 'x', '25', 'cm', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'pct', 'c', '50', 'unid', 'cremer']
# ['campo', 'operatorio', '8', 'dob', '50', 'x', '50']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'compressa', 'cirurgica', 'campo', 'operatorio', 'alva', 'gramatura', '26', 'com', 'cadarco', 'pacote', 'esteril', 'com', '5', 'unidades', '50', 'cm', 'x', '45', 'cm', '100', 'algodao', 'altamente', 'absorvente', 'macio', 'e', 'isento', 'de', 'impurezas', 'as', 'camadas', 'de', 'tecido', 'possuem', 'am']
# ['campo', 'operatorio', '45', 'x', '50', 'cm', 'a', 'compressa', 'cirurgica', 'e', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido']
# ['espatula', 'de', 'insercao', 'n', '1', 'para', 'resina', 'composta', 'indicada', 'para', 'restauracao', 'de', 'resina', 'composta', 'pontas', 'antiaderentes', 'revestidas', 'de', 'titanio', 'pontas', 'flexiveis', 'e', 'alinhadas', 'de', 'maneira', 'oposta', 'permitindo', 'facil', 'preparacao', 'e', 'melhor', 'visao', 'dentro', 'do', 'campo', 'operatorio', 'cabo', 'oco', 'e', 'grosso', '8', 'mm', 'aco', 'inoxidavel', 'de', 'alta', 'qualidade', 'autoclavavel', 'apresentacao', 'embalagem', 'com', 'uma', 'unidade', 'nome', 'do', 'fabricante', 'e', 'numero', 'do', 'instrumento', 'impressos', 'no', 'produto', 'fabricante', 'lote', 'e', 'data', 'de', 'validade', 'impressas', 'na', 'embalagem', 'garantia', 'indeterminada', 'contra', 'defeitos', 'de', 'fabricacao', 'registro', 'na', 'anvisa', 'os', 'concorrentes', 'deverao', 'apresentar', 'prospecto', 'dos', 'produtos', 'no', 'momento', 'da', 'licitacao', 'com', 'bula', 'que', 'comprovem', 'as', 'caracteristicas', 'solicitadas']
# ['campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'c', '35', 'g', 'compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', 'confeccionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'com', 'fio', 'radiopaco', 'com', 'entrelacamento', 'das', 'quatro', 'camadas', 'do', 'tecido', 'que', 'a', 'compoem', 'para', 'evitar', 'o', 'deslizamento', 'entre', 'as', 'mesmas', 'cadarco', 'duplo', 'em', 'forma', 'de', 'alca', 'costura', 'nas', 'laterias', 'que', 'permite', 'maior', 'seguranca', 'nao', 'solta', 'fiapos', 'medida', '45', 'x', '50', 'cm', 'e', 'gramatura', '35', 'gramas']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'com', '50', 'unid']
# ['campo', 'operatorio', 'simples', '1', '40', 'x', '1', '40', 'm', '100', 'algodao']
# ['compressa', 'cirurgica', 'para', 'campo', 'operatorio', 'esteril', '30', 'cm', 'x', '30', 'cm']
# ['clorexedine', '0', '2', 'e', 'uma', 'solucao', 'aquosa', 'de', 'indicada', 'para', 'preparo', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsia', 'da', 'pele', 'frasco', 'de', '1', 'litro', 'apresentar', 'amostra', 'para', 'analise']
# ['campo', 'operatorio', 'nao', 'esterio']
# ['compressas', 'cirurgicas', 'campo', 'operatorio', 'nao', 'esteril', 'tipo', '1', 'medindo', '45', 'x', '50', 'cm', 'confeccionadas', 'com', 'fios', '100', 'algodao', 'embaladas', 'em', 'pacotes', 'de', '50', 'unidades']
# ['clorexidina', 'alcoolica', 'solucao', 'alcoolica', 'de', 'digluconato', 'de', 'clorexidina', '0', '5', 'indicada', 'para', 'preparo', 'do', 'campo', 'operatorio', 'e', 'para', 'antissepsia', 'da', 'pele', 'frasco', 'de', 'de', '1', 'litro']
# ['solucao', 'de', 'digluconato', 'de', 'clorexidina', 'a', '0', '5', '1', 'litro', 'solucao', 'alccolica', 'topica', 'utilizado', 'no', 'preparo', 'do', 'campo', 'operatorio', 'embalagem', 'de', '1', 'litro', 'contendo', 'dados', 'de', 'identificacao', 'lote', 'validade', 'e', 'registro', 'ms', 'com', 'qualidade', 'igual', 'ou', 'superior', 'a', 'rioquimica']
# ['campo', 'operatorio', 'descartavel', 'possui', 'barreira', 'microbiana', 'permite', 'respirabilidade', 'da', 'pele', 'impermeavel', 'a', 'liquidos', 'e', 'microorganismos', 'possui', 'um', 'anel', 'semi', 'rigido', 'que', 'facilita', 'a', 'sua', 'insercao', 'na', 'incisao', 'e', 'ajuda', 'na', 'retracao', 'das', 'bordas', 'no', 'sitio', 'cirurgico', 'possui', 'uma', 'pelicula', 'impermeavel', 'e', 'translucida', 'impermeavel', 'que', 'elimina', 'o', 'contato', 'direto', 'das', 'bordas', 'do', 'sitio', 'cirurgico', 'com', 'instrumentos', 'conteudo', 'visceral', 'e', 'luvas', 'retem', 'a', 'umidade', 'das', 'bordas', 'da', 'incisao', 'cirurgica', 'permite', 'a', 'vascularizacao', 'das', 'bordas', 'da', 'incisao', 'possui', 'um', 'acabamento', 'fosco', 'para', 'reduzir', 'o', 'brilho', 'da', 'superficie', 'do', 'campo', 'contem', 'quatro', 'bordas', 'adesivas', 'uma', 'em', 'cada', 'extremo', 'para', 'manter', 'o', 'campo', 'fixo', 'aos', 'demais', 'campos', 'cirurgicos', 'o', 'adesivo', 'das', 'bordas', 'e', 'acrilico', 'e', 'hipoalergenico', 'sensivel', 'a', 'pressao', 'semlatex', 'tamanho', 'total', '90', 'cm', 'x', '90', 'cm', 'diametro', 'do', 'anel', '27', 'cm']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'tamanho', '25', 'x', '23', 'cm', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '25', 'x', '23', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', '100', 'algodao', '4', 'camadas', 'sobrepostas', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'sem', 'filamento', 'radiopaco']
# ['campo', 'operatorio', 'simples', 'medida', '45', 'x', '50', 'cm', 'com', '13', 'fio', 'cm2']
# ['compressa', 'cirurgia', 'campo', 'operatorio', '45', 'x', '50', 'pacote']
# ['clorexidina', 'alcoolica', 'para', 'antissepsiado', 'campo', 'operatorio', 'an', 'tissepsia', 'das', 'maos', 'contendo', '0', '5', 'de', 'digliconato', 'de', 'clorexidina']
# ['compressa', 'campo', 'operatorio', 'nao', 'esteril', '4', 'camadas', 'com', 'cadarco', '100', 'puro', 'algodao', 'macio', 'e', 'extra', 'absorvente', 'tamanho', '45', 'cm', 'x', '50', 'cm', '26', 'g', 'unidade', 'contem', '50', 'unidades']
# ['compressa', 'campo', 'operatorio', '45', 'x', '50', 'cm', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'tipo', 'campo', 'operatorio', 'materia', 'prima', 'tecido', 'absorvente', '100', 'algodao', 'dimensoes', '45', 'x', '50', 'cm', 'tipo', 'esteril', 'com', 'filamento', 'radiopaco', 'apresentacao', 'pacote', 'com', '50', 'unidades']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'dimensao', '45', 'cm', 'x', '50', 'cm', 'quatro', 'camadas', 'e', '100', 'algodao', 'pc', 'c', '50', 'un']
# ['compressa', 'cirurgica', 'campo', 'operatorio', 'nao', 'esteril', '45', 'cm', 'x', '50', 'cm']
# ['compressa', 'cirurgica', 'campo', 'operatorio', '25', 'x', '25', 'com', '50', 'und']
# ['campo', 'operatorio', '45', 'x', '50', 'c', '50', 'uni']
# ['compressa', 'campo', 'operatorio', '45', 'cm', 'x', '50', 'cm', 'pacote', 'com', '50', 'und']
# ['campo', 'operatorio', '4', 'camadas']
# ['campo', 'operatorio', '43', 'x', '43', 'cm', 'confeccionado', 'em', 'americano', 'cru', 'duplo', 'com', '56', 'fios', 'por', 'cm2', 'e', 'gramatura', 'de', '200', 'gramas', 'por', 'm2', 'com', 'dimensoes', '43', 'x', '43', 'cm', 'silkad']
# ['campo', 'operatorio', 'em', 'tecido', '100', 'algodao', 'tam', '45', 'x', '50', 'cm', 'c', '50', 'un']
# ['compressa', 'de', 'gaze', 'cirurgica', '100', 'algodao', 'campo', 'operatorio', 'sem', 'fio', 'radiopaco', '4', 'camadas', 'com', 'cadarco', 'tamanho', '45', 'x', '50', 'cm', 'produto', 'nao', 'esteril', 'e', 'altamente', 'absorvente', 'pacote', 'com', '50', 'unidades']
# ['clorexidina', 'alcoolica', 'para', 'antissepsiado', 'campo', 'operatorio', 'antissepsia', 'das', 'maos', 'contendo', '0', '5', 'de', 'digliconato', 'de', 'clorexidina', 'apresentar', 'ficha', 'tecnica', 'e', 'notificacao', 'na', 'anvisa', 'ms', 'medicamento', 'de', 'notificacao', 'simplificada', 'rdc', 'anvisa', 'n', '199', '2006', 'afe', 'n', '1', '1', '520', '1', 'caixa', '30', 'almotolia', 'de', '100', 'ml']
# ['compressa', 'cirurgica', '45', 'cm', 'x', '50', 'cm', 'campo', 'operatorio', 'confecionada', 'com', 'fios', '100', 'algodao', 'em', 'tecido', 'quadruplo', 'sobreposto', 'tipo', 'tela', 'de', 'forma', 'a', 'evitar', 'deslizamento', 'das', 'camadas', 'com', 'no', 'minimo', '25', 'gramas', 'e', 'com', 'fio', 'radiopaco', 'possuir', 'costuras', 'para', 'evitar', 'desfiamentodas', 'laterias', 'e', 'dispositivos', 'para', 'fixacao', 'em', 'forma', 'de', 'cadarco', 'duplo', 'formando', 'uma', 'alca', 'livre', 'contendo', 'no', 'minimo', '30', 'cm', 'de', 'comprimento', 'dever', 'ser', 'isentas', 'de', 'substancias', 'gordurosas', 'amido', 'corantes', 'alvejantes', 'manchas', 'fios', 'soltos', 'e', 'rasgos', 'embaladas', 'em', 'pacotes', 'com', '50', 'unidades', 'o', 'produto', 'devera', 'atender', 'na', 'nbr', 'sob', 'pena', 'de', 'desclassificacao', 'data', 'de', 'validade', 'superior', 'a', '24', 'meses', 'da', 'data', 'de', 'entrega']
# ['3', '0972', 'compressa', 'de', 'campo', 'operatorio', '45', 'x', '50', 'sem']

# %%
df_samp = dft.sample(frac=0.002)
df_samp.shape
# Out:
# (3336, 2)

# %%
import numpy as np
from sklearn.manifold import TSNE
emb_2_plot = get_items_embeddings_weighted(df_samp.desc.values, word_embeddings, None)

# %%
projection = TSNE().fit_transform(emb_2_plot)
plt.scatter(*projection.T, s = 5, alpha=0.4)
