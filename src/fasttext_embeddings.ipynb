# %%
from gensim.models import FastText, KeyedVectors
from gensim.models.fasttext import load_facebook_model
from gensim.models.wrappers.fasttext import FastText as FT_wrapper
from gensim.models.fasttext import FastText as FT_gensim

# %% [markdown]
# # Load pretrained model

# %%
model_file = '../dados/embeddings/models/fasttext/sg/output/items'

# %%
loaded_model = FT_gensim.load(model_file)

# %%
loaded_model.wv.vocab
# Out:
# {',': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4210>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4f10>,
#  '</s>': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4e90>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4b90>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4dd0>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7f7698ac47d0>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4890>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4390>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7f7698ac48d0>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x7f7698ac46d0>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7f7698ac43d0>,
#  'em': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4e10>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4c90>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4150>,
#  'que': <gensim.models.keyedvectors.Vocab at 0x7f7698ac4a50>,
# ...

# %%
loaded_model.wv['etanol']
# Out:
# array([-0.36323193,  2.8368099 ,  0.11036361, -1.0445222 , -0.7589327 ,
#         0.94927526,  0.8338536 , -0.87032336, -1.1989257 ,  0.40110356,
#        -0.79623204,  1.0728095 ,  0.80997086,  0.17878276,  0.0154666 ,
#         0.97512555, -0.17826848, -0.94382566, -0.3773376 ,  0.5492427 ,
#         1.0399419 , -0.23850612,  0.28342935, -0.70678955,  0.66774124,
#        -0.34993196,  0.10340276,  0.43848425, -0.23254901,  0.12010094,
#         0.00404224, -0.01220209, -0.6819548 , -0.26108193, -0.03516954,
#        -0.15844235,  0.41835842,  0.5978824 ,  0.45247746, -0.39779   ,
#         0.7635994 ,  0.47009283,  0.14364329, -0.4982984 , -0.06071561,
#         0.41599882, -0.08247913, -0.98262185, -0.0302561 ,  0.15104346,
#         0.04560889, -0.2414474 ,  0.39969406, -0.3250893 ,  0.70868963,
#        -0.02806728, -0.4570175 ,  0.1157188 ,  0.1505713 , -0.18988186,
#        -0.24091358,  0.06901357, -0.20558316, -0.02784031,  0.28979793,
# ...

# %% [markdown]
# # Load word vectors

# %%
vectors_file = '../dados/embeddings/models/fasttext/sg/output/items_embeddings.vec'

# %%
vectors = KeyedVectors.load_word2vec_format(vectors_file, binary=False, unicode_errors='ignore')

# %%
vectors['etanol']
# Out:
# array([-0.36323193,  2.8368099 ,  0.11036361, -1.0445222 , -0.7589327 ,
#         0.94927526,  0.8338536 , -0.87032336, -1.1989257 ,  0.40110356,
#        -0.79623204,  1.0728095 ,  0.80997086,  0.17878276,  0.0154666 ,
#         0.97512555, -0.17826848, -0.94382566, -0.3773376 ,  0.5492427 ,
#         1.0399419 , -0.23850612,  0.28342935, -0.70678955,  0.66774124,
#        -0.34993196,  0.10340276,  0.43848425, -0.23254901,  0.12010094,
#         0.00404224, -0.01220209, -0.6819548 , -0.26108193, -0.03516954,
#        -0.15844235,  0.41835842,  0.5978824 ,  0.45247746, -0.39779   ,
#         0.7635994 ,  0.47009283,  0.14364329, -0.4982984 , -0.06071561,
#         0.41599882, -0.08247913, -0.98262185, -0.0302561 ,  0.15104346,
#         0.04560889, -0.2414474 ,  0.39969406, -0.3250893 ,  0.70868963,
#        -0.02806728, -0.4570175 ,  0.1157188 ,  0.1505713 , -0.18988186,
#        -0.24091358,  0.06901357, -0.20558316, -0.02784031,  0.28979793,
# ...
