# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import math
import multiprocessing
from item.item_list import (
    ItemList,
    Item
)
from nlp.utils import (
    plot_histogram,
    get_completetext,
    plot_wordcloud,
    print_statistics,
    groups_frequency_sort)
from nlp.grouping import (
    get_groups,
    get_groups_size,
    get_unigram_groups,
    get_two_tokens_groups,
    get_first_token_groups,
    get_bigram_groups,
    get_first_two_groups,
    groups_frequency_sort
)
from nlp.pos_tagging import (
    get_tokens_tags
)
from nlp.word_embeddings import (
    load_word_embeddings,
    get_item_embedding,
    get_items_embeddings,
    get_items_similarities
)
from item.clustering.evaluate import (
    get_score_pickle,
    evaluate_results_pickle,
    evaluate_results
)
from item.clustering.utils import (
    load_clustering_results_pickle,
    load_clustering_results,
    load_models_pickle
)
from item.item_representation import (
    load_items_embeddings,
    get_group_embeddings_matrix,
    get_words_plus_categories_embeddings,
    normalize
)

from hdbscan.prediction import approximate_predict

# %%
clustering_model, reducer_model = load_models_pickle('./precificacao/word2vec_cbow50/v3/SUB+MED+unit+num_concat_umap_hdbscan_euclidean/')

# %%
# It gets the descriptions processed:
itemlist = ItemList()
itemlist.load_items_from_file('../dados/items_preprocessed_v3_train.zip')

# %%
# Get the tags of tokens descriptions
word_class = get_tokens_tags(itemlist.unique_words)

# %%
# word embeddings file, each line contains a word embedding
# word_embeddings_file = '../../../embeddings/fasttext/skip_s300.txt'
word_embeddings_file = '../../../embeddings/word2vec/cbow_s50.txt'

# %%
# read word embeddings from file and store them in a map
word_embeddings = load_word_embeddings(word_embeddings_file, itemlist.unique_words)

# %%
#It gets the ranges of the clusters generated by the First Token approach
#This is done in order to the processes work on.
def get_ranges(group_len, n_threads):

    if(n_threads == 1):
        return 0, (group_len - 1)    

    total_len = group_len
    num_threads = n_threads
    lower = []
    upper = []
    step = int(total_len/num_threads)

    for k in range(num_threads):
        lower.append(0)
        upper.append(0)

    lower[0] = 0
    upper[0] = step

    i = 1
    j = 0
    while (i < num_threads):    
        upper[i]  = upper[j] + step
        lower[i]  = upper[j] +  1
        if(i%2 != 0):
            upper[i] = upper[i] + 1
        
        i = i + 1
        j = j + 1

    #Please, check if the final cluster range ends with 18,034 clusters
    #(i.e., the number of clusters generated by First Token).
    #Depending of the number of processes, you may have to change this "-1"
    #for something else.
    upper[n_threads - 1] = group_len - 1 
    return lower, upper

# %%
def get_items_clusters(itemlist, first_token_groups, word_embeddings, word_class,
                       reducer_model, clustering_model, categories, embedding_type,
                       embedding_size, operation, it_thread, lower, upper, results_threads):

    print(it_thread)
    
    # It creates a list of the the keys of these groups:
    groups = list(first_token_groups.keys())

    # It gets the values of each group (i.e., the ids of the descriptions into that group):
    group_descriptions = list(first_token_groups.values())
    
    # Iterator of the first token groups:
    ft_it = lower

    results = []
    
    while ft_it <= upper:
        group = groups[ft_it]
        items = group_descriptions[ft_it]
        if group not in reducer_model:
            for item_id in items:
                cluster_id = '-1'
                cluster_prob = 0
                item_result = {'item_id': item_id, 'cluster': cluster_id,
                               'cluster_prob': cluster_prob, 'price':0}
                results.append(item_result)
        else:
            embeddings_matrix = get_group_embeddings_matrix(items, itemlist.items_list, word_embeddings, word_class,
                                                    categories=categories, embedding_type=embedding_type,
                                                    embedding_size=embedding_size, norm=True, operation=operation)
            # It gets the reduced vector for the item
            embeddings_matrix = reducer_model[group].transform(embeddings_matrix)
            # It gets the item cluster
            clusters = approximate_predict(clustering_model[group], embeddings_matrix)
            # ([4, 5, 6, 7, 8], [0.94, ...])
            for _id, item_id in enumerate(items):
                cluster_id = group + '_' + str(clusters[0][_id])
                cluster_prob = clusters[1][_id]
                item_result = {'item_id': item_id, 'cluster': cluster_id,
                               'cluster_prob': cluster_prob, 'price':itemlist.get_item(item_id).get_item_dict()['preço']}
                results.append(item_result)
        ft_it = ft_it + 1
        
    results_threads[it_thread] = results

# %%
def predict_items_clusters(itemlist, word_embeddings, word_class, reducer_model,
                           clustering_model, categories=None, embedding_type=None,
                           embedding_size=50, operation='mean', n_threads=10):

    # It gets the first tokens of each description and groups
    # based on this approach:
    first_token_groups = itemlist.get_first_token_groups()
    group_len = len(first_token_groups)

    first_token_groups_new = {}
    keys_ft = list(first_token_groups.keys())
    random.shuffle(keys_ft)
    random.shuffle(keys_ft)

    for k in keys_ft:
        first_token_groups_new[k] = first_token_groups[k]
    
    manager = multiprocessing.Manager()
    results_threads = manager.dict()
    jobs = []

    # It defines the ranges (of the groups) the threads will work on:
    thread_ranges = get_ranges(group_len, n_threads)
    print('Read ranges')
    print(thread_ranges)

    for i in range(n_threads):
        p = multiprocessing.Process(target=get_items_clusters, \
                args = (itemlist, first_token_groups_new, word_embeddings, word_class, \
                reducer_model, clustering_model, categories, embedding_type, embedding_size, \
                operation, i, thread_ranges[0][i], thread_ranges[1][i], results_threads))
        jobs.append(p)
        p.start()
        
    for proc in jobs:
        proc.join()

    results = []
    for i in range(n_threads):
        for inst in results_threads[i]:
            results.append(inst)

    return results

# %%
results = predict_items_clusters(itemlist, word_embeddings, word_class, reducer_model, \
                                clustering_model, categories=['unidades_medida', 'números'], \
                                embedding_type=['N', 'MED'], operation='concatenate', n_threads=30)
# Out:
# Read ranges
# ([0, 450, 900, 1349, 1799, 2248, 2698, 3147, 3597, 4046, 4496, 4945, 5395, 5844, 6294, 6743, 7193, 7642, 8092, 8541, 8991, 9440, 9890, 10339, 10789, 11238, 11688, 12137, 12587, 13036], [449, 899, 1348, 1798, 2247, 2697, 3146, 3596, 4045, 4495, 4944, 5394, 5843, 6293, 6742, 7192, 7641, 8091, 8540, 8990, 9439, 9889, 10338, 10788, 11237, 11687, 12136, 12586, 13035, 13497])
# 0
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 1
# 2
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 3
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 4
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 5
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 6
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 7
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 8
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 9
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 10
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 11
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 12
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 13
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 14
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 15
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 16
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 17
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 18
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 19
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 20
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 21
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 22
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 23
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# 24
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# ...
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'
# /dados01/workspace/ufmg.f01dcc/py37/lib/python3.7/site-packages/hdbscan/prediction.py:385: UserWarning: Clusterer does not have any defined clusters, new data will be automatically predicted as noise.
#   warn('Clusterer does not have any defined clusters, new data'

# %%
results
# Out:
# [{'item_id': 1422,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 1.13},
#  {'item_id': 3163,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.648},
#  {'item_id': 16443,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.69},
#  {'item_id': 18711,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 2.15},
#  {'item_id': 25487,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.384},
#  {'item_id': 26155,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.29},
#  {'item_id': 29378,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 1.28},
#  {'item_id': 31677,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.57},
#  {'item_id': 31744,
#   'cluster': 'tioridazina_-1',
#   'cluster_prob': 0.0,
#   'price': 0.4},
#  {'item_id':

#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6956617995741391,
#   'price': 8.8},
#  {'item_id': 468363,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7177998831042287,
#   'price': 54.9},
#  {'item_id': 479919,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7521799811125183,
#   'price': 12.5},
#  {'item_id': 494972,
#   'cluster': 'afastador_2',
#   'cluster_prob': 1.0,
#   'price': 4.79},
#  {'item_id': 495885,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6756435000102776,
#   'price': 75.0},
#  {'item_id': 496138,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7098040782600028,
#   'price': 15.8},
#  {'item_id': 498291,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 15.5},
#  {'item_id': 507026,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7467692228512526,
#   'price': 6.66},
#  {'item_id': 507328,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.5266575393819464,
#   'price': 730.0},
#  {'item_id': 510667,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6520611987529543,
#   'price': 7.9},
#  {'item_id': 517954,
#   'cluster': 'afastador_2',
#   'cluster_prob': 1.0,
#   'price': 16.72},
#  {'item_id': 524135,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6656992298181996,
#   'price': 26.2},
#  {'item_id': 525636,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 780.0},
#  {'item_id': 531998,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6945749053626232,
#   'price': 12.56},
#  {'item_id': 533705,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 6.7},
#  {'item_id': 534347,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6926752968133562,
#   'price': 4.71},
#  {'item_id': 534504,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7103084908563082,
#   'price': 15.8},
#  {'item_id': 535736,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 14.0},
#  {'item_id': 539314,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 21.25},
#  {'item_id': 547722,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6820589867954384,
#   'price': 15.5},
#  {'item_id': 551691,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 570.0},
#  {'item_id': 553090,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.7304037576113882,
#   'price': 6.0},
#  {'item_id': 555964,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.4807540922328855,
#   'price': 14.83},
#  {'item_id': 557103,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8143781784743883,
#   'price': 48.9},
#  {'item_id': 560886,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.3948433994796656,
#   'price': 209.0},
#  {'item_id': 563000,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 327.75},
#  {'item_id': 563341,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8715679934737764,
#   'price': 9.28},
#  {'item_id': 564814,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 12.88},
#  {'item_id': 566964,
#   'cluster': 'afastador_1',
#   'cluster_prob': 0.9990734263026332,
#   'price': 12.6},
#  {'item_id': 572310,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8628346916504779,
#   'price': 8.7},
#  {'item_id': 572677,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8758305003450305,
#   'price': 10.95},
#  {'item_id': 576644,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8879223800880975,
#   'price': 5.25},
#  {'item_id': 577848,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.7368040859900585,
#   'price': 5.25},
#  {'item_id': 581406,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6024575981479177,
#   'price': 55.0},
#  {'item_id': 582719,
#   'cluster': 'afastador_2',
#   'cluster_prob': 1.0,
#   'price': 8.2},
#  {'item_id': 586995,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8358897219133783,
#   'price': 11.4},
#  {'item_id': 590454,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 12.83},
#  {'item_id': 591673,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8644396271902864,
#   'price': 10.2},
#  {'item_id': 597769,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.9909289892403512,
#   'price': 16.25},
#  {'item_id': 597952,
#   'cluster': 'afastador_0',
#   'cluster_prob': 1.0,
#   'price': 6.66},
#  {'item_id': 600030,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 20.5},
#  {'item_id': 600676,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 13.0},
#  {'item_id': 602191,
#   'cluster': 'afastador_2',
#   'cluster_prob': 1.0,
#   'price': 6.7},
#  {'item_id': 604612,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.40550722228325853,
#   'price': 25.0},
#  {'item_id': 607239,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6986201506461507,
#   'price': 5.25},
#  {'item_id': 612343,
#   'cluster': 'afastador_1',
#   'cluster_prob': 0.998828343524886,
#   'price': 13.0},
#  {'item_id': 613560,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8532943580773182,
#   'price': 9.8},
#  {'item_id': 618236,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.895484513586316,
#   'price': 13.8},
#  {'item_id': 621635,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 7.5},
#  {'item_id': 622014,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6687753800945601,
#   'price': 9.98},
#  {'item_id': 622767,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 9.4},
#  {'item_id': 625881,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8515040982344924,
#   'price': 12.8},
#  {'item_id': 628108,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.5462422271260122,
#   'price': 11.0},
#  {'item_id': 629853,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.470496432099759,
#   'price': 6.44},
#  {'item_id': 633023,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8660733609147102,
#   'price': 11.78},
#  {'item_id': 633268,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 15.3},
#  {'item_id': 633780,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 15.0},
#  {'item_id': 635925,
#   'cluster': 'afastador_0',
#   'cluster_prob': 1.0,
#   'price': 4.89},
#  {'item_id': 637853,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6667151791740835,
#   'price': 11.75},
#  {'item_id': 638014,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 11.9},
#  {'item_id': 638960,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9546682855714678,
#   'price': 14.01},
#  {'item_id': 640382,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 32.0},
#  {'item_id': 642542,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9527646833958004,
#   'price': 4.82},
#  {'item_id': 643057,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9616518728436498,
#   'price': 4.59},
#  {'item_id': 644304,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 44.0},
#  {'item_id': 647985,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9888640839250883,
#   'price': 8.55},
#  {'item_id': 655044,
#   'cluster': 'afastador_0',
#   'cluster_prob': 1.0,
#   'price': 10.66},
#  {'item_id': 656166,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 13.5},
#  {'item_id': 657475,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 89.0},
#  {'item_id': 658100,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 14.0},
#  {'item_id': 662985,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.6576515701580078,
#   'price': 9.38},
#  {'item_id': 663196,
#   'cluster': 'afastador_2',
#   'cluster_prob': 1.0,
#   'price': 3.6},
#  {'item_id': 669462,
#   'cluster': 'afastador_0',
#   'cluster_prob': 1.0,
#   'price': 8.0},
#  {'item_id': 675253,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9817988506824994,
#   'price': 4.59},
#  {'item_id': 682516,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 6.56},
#  {'item_id': 696143,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9856404346733275,
#   'price': 15.45},
#  {'item_id': 696788,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.5503155451787051,
#   'price': 745.0},
#  {'item_id': 697687,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.7875621413834278,
#   'price': 8.82},
#  {'item_id': 698239,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 17.16},
#  {'item_id': 702745,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6938632715734508,
#   'price': 6.2},
#  {'item_id': 705096,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9240829131495786,
#   'price': 11.45},
#  {'item_id': 706722,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.6760385997660485,
#   'price': 5.59},
#  {'item_id': 708989,
#   'cluster': 'afastador_2',
#   'cluster_prob': 0.7588610950712494,
#   'price': 5.4},
#  {'item_id': 709286,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 24.0},
#  {'item_id': 718911,
#   'cluster': 'afastador_0',
#   'cluster_prob': 1.0,
#   'price': 62.59},
#  {'item_id': 720618,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 83.0},
#  {'item_id': 724260,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.9482485270770292,
#   'price': 7.9},
#  {'item_id': 726358,
#   'cluster': 'afastador_3',
#   'cluster_prob': 1.0,
#   'price': 5.4},
#  {'item_id': 732472,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.950433614225441,
#   'price': 5.2},
#  {'item_id': 733189,
#   'cluster': 'afastador_-1',
#   'cluster_prob': 0.0,
#   'price': 14.15},
#  {'item_id': 736702,
#   'cluster': 'afastador_0',
#   'cluster_prob': 0.8990485360575068,
#   'price': 4.8},
#  {'item_id': 742803,
#   'cluster': 'afastador_1',
#   'cluster_prob': 1.0,
#   'price': 10.9},
#  {'item_id': 743965,
#   'cluster': 'afastador_3',
# ...
#   'price': 11.3},
#  {'item_id': 1179933,
#   'cluster': 'povidona_0',
#   'cluster_prob': 1.0,
#   'price': 27.0},
#  {'item_id': 1187594,
#   'cluster': 'povidona_0',
#   'cluster_prob': 0.749275026685071,
#   'price': 15.9},
#  {'item_id': 1192133,
#   'cluster': 'povidona_0',
#   'cluster_prob': 1.0,
#   'price': 15.5},
#  {'item_id': 1193981,
#   'cluster': 'povidona_1',
#   'cluster_prob': 1.0,
#   'price': 15.03},
#  {'item_id': 1095517, 'cluster': '-1', 'cluster_prob': 0, 'price': 0},
#  {'item_id': 
 'cluster': '-1', 'cluster_prob': 0, 'price': 0},
#  {'item_id': 706672, 'cluster': '-1', 'cluster_prob': 0, 'price': 0},
#  {'item_id': 871, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 13.9},
#  {'item_id': 1135, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 9.9},
#  {'item_id': 1913, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 6.5},
#  {'item_id': 3412, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 23.0},
#  {'item_id': 3791, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 3.8},
#  {'item_id': 4773,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.7105348668281525,
#   'price': 24.9},
#  {'item_id': 5013, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 14.99},
#  {'item_id': 5141,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.7379126125328273,
#   'price': 13.8},
#  {'item_id': 7709, 'cluster': 'faca_9', 'cluster_prob': 1.0, 'price': 10.66},
#  {'item_id': 11180,
#   'cluster': 'faca_8',
#   'cluster_prob': 0.12238722714269668,
#   'price': 7.58},
#  {'item_id': 12997,
#   'cluster': 'faca_2',
#   'cluster_prob': 0.6776455056953301,
#   'price': 29.0},
#  {'item_id': 13970, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 7.3},
#  {'item_id': 15068, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 14.95},
#  {'item_id': 15220,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.786191257430987,
#   'price': 2.9},
#  {'item_id': 15383,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.7484889735970428,
#   'price': 3.64},
#  {'item_id': 15876,
#   'cluster': 'faca_8',
#   'cluster_prob': 0.11135166541488947,
#   'price': 20.95},
#  {'item_id': 16406,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.9837803845076473,
#   'price': 24.0},
#  {'item_id': 17437,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.19263949708468756,
#   'price': 4.24},
#  {'item_id': 19226, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 7.8},
#  {'item_id': 19705,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.9850261535690521,
#   'price': 3.0},
#  {'item_id': 19829,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.7160290274708722,
#   'price': 10.0},
#  {'item_id': 20210,
#   'cluster': 'faca_8',
#   'cluster_prob': 0.9787572507187693,
#   'price': 2.25},
#  {'item_id': 20818, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 5.7},
#  {'item_id': 22567,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.6888816967371888,
#   'price': 12.9},
#  {'item_id': 22971,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.926921384344318,
#   'price': 9.0},
#  {'item_id': 23390, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 26.16},
#  {'item_id': 24842, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 40.6},
#  {'item_id': 25263,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.159585263556727,
#   'price': 14.2},
#  {'item_id': 26595,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.6996805967006217,
#   'price': 14.9},
#  {'item_id': 27604,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.6741418412155079,
#   'price': 9.8},
#  {'item_id': 28176,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.5604535896006754,
#   'price': 5.5},
#  {'item_id': 29759,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.5991676788310116,
#   'price': 7.98},
#  {'item_id': 30194,
#   'cluster': 'faca_1',
#   'cluster_prob': 0.8452004928947554,
#   'price': 8.05},
#  {'item_id': 30395,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.15158331144368473,
#   'price': 4.1},
#  {'item_id': 31098,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.876083071134907,
#   'price': 3.6},
#  {'item_id': 31761, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 15.0},
#  {'item_id': 32119, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 11.9},
#  {'item_id': 32868,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.8934259982953088,
#   'price': 2.45},
#  {'item_id': 34413,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.14969666887189678,
#   'price': 8.85},
#  {'item_id': 34658,
#   'cluster': 'faca_7',
#   'cluster_prob': 0.24302430803654118,
#   'price': 28.5},
#  {'item_id': 35212, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 12.99},
#  {'item_id': 35926,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.7799488515608185,
#   'price': 2.5},
#  {'item_id': 36514, 'cluster': 'faca_9', 'cluster_prob': 1.0, 'price': 7.9},
#  {'item_id': 36719,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.8685505919652164,
#   'price': 2.4},
#  {'item_id': 37013,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.9068821334071091,
#   'price': 12.0},
#  {'item_id': 38080, 'cluster': 'faca_4', 'cluster_prob': 1.0, 'price': 13.5},
#  {'item_id': 42481, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 3.06},
#  {'item_id': 43528, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 10.9},
#  {'item_id': 44215, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 76.0},
#  {'item_id': 44779, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 22.0},
#  {'item_id': 45320,
#   'cluster': 'faca_6',
#   'cluster_prob': 0.9971157734756421,
#   'price': 6.0},
#  {'item_id': 45779,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.6333823350919011,
#   'price': 16.5},
#  {'item_id': 47295, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 8.5},
#  {'item_id': 48053,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.7738683805768573,
#   'price': 13.09},
#  {'item_id': 53116, 'cluster': 'faca_9', 'cluster_prob': 1.0, 'price': 15.99},
#  {'item_id': 53139, 'cluster': 'faca_8', 'cluster_prob': 1.0, 'price': 8.9},
#  {'item_id': 57278, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 1.5},
#  {'item_id': 57490, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 12.0},
#  {'item_id': 59089, 'cluster': 'faca_1', 'cluster_prob': 1.0, 'price': 8.9},
#  {'item_id': 62063,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.6504149329025389,
#   'price': 7.05},
#  {'item_id': 63136,
#   'cluster': 'faca_1',
#   'cluster_prob': 0.9947739799381746,
#   'price': 6.85},
#  {'item_id': 63313,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.7945956881280446,
#   'price': 2.49},
#  {'item_id': 63473, 'cluster': 'faca_6', 'cluster_prob': 1.0, 'price': 6.0},
#  {'item_id': 63520, 'cluster': 'faca_5', 'cluster_prob': 1.0, 'price': 28.65},
#  {'item_id': 64669, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 34.0},
#  {'item_id': 67305, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 16.4},
#  {'item_id': 67860,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.9113177593085637,
#   'price': 8.9},
#  {'item_id': 69714,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.8307389940831901,
#   'price': 2.19},
#  {'item_id': 71666, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 16.0},
#  {'item_id': 72697,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.5778838588283376,
#   'price': 1.28},
#  {'item_id': 72735, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 10.85},
#  {'item_id': 72758, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 4.5},
#  {'item_id': 73215,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.6723961345210785,
#   'price': 1.7},
#  {'item_id': 73907, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 4.28},
#  {'item_id': 74153, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 8.5},
#  {'item_id': 74414,
#   'cluster': 'faca_2',
#   'cluster_prob': 0.8532839468563738,
#   'price': 9.0},
#  {'item_id': 74707,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.6906408052143155,
#   'price': 4.27},
#  {'item_id': 75494,
#   'cluster': 'faca_5',
#   'cluster_prob': 0.6470198178852941,
#   'price': 6.3},
#  {'item_id': 75999, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 85.0},
#  {'item_id': 76885,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.8686368400463048,
#   'price': 24.0},
#  {'item_id': 76908,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.808328181805212,
#   'price': 2.0},
#  {'item_id': 77700, 'cluster': 'faca_8', 'cluster_prob': 1.0, 'price': 17.99},
#  {'item_id': 78760,
#   'cluster': 'faca_8',
#   'cluster_prob': 0.10981213753221888,
#   'price': 1.9},
#  {'item_id': 78827, 'cluster': 'faca_-1', 'cluster_prob': 0.0, 'price': 10.9},
#  {'item_id': 78912,
#   'cluster': 'faca_3',
#   'cluster_prob': 0.7272649925484037,
#   'price': 2.29},
#  {'item_id': 80465,
#   'cluster': 'faca_8',
#   'cluster_prob': 0.11049835658198402,
#   'price': 32.5},
#  {'item_id': 81056, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 6.58},
#  {'item_id': 82866,
#   'cluster': 'faca_0',
#   'cluster_prob': 0.7055882810009283,
#   'price': 54.0},
#  {'item_id': 83072, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 4.08},
#  {'item_id': 83956, 'cluster': 'faca_7', 'cluster_prob': 1.0, 'price': 6.5},
#  {'item_id': 84008,
#   'cluster': 'faca_1',
#   'cluster_prob': 0.7300637263774954,
#   'price': 10.96},
#  ...]

# %%
results_df=pd.DataFrame.from_dict(results)
results_df.head(50)
# Out:
#     item_id         cluster  cluster_prob  price
# 0      1422  tioridazina_-1           0.0  1.130
# 1      3163  tioridazina_-1           0.0  0.648
# 2     16443  tioridazina_-1           0.0  0.690
# 3     18711  tioridazina_-1           0.0  2.150
# 4     25487  tioridazina_-1           0.0  0.384
# 5     26155  tioridazina_-1           0.0  0.290
# 6     29378  tioridazina_-1           0.0  1.280
# 7     31677  tioridazina_-1           0.0  0.570
# 8     31744  tioridazina_-1           0.0  0.400
# 9     36374  tioridazina_-1           0.0  0.600
# 10    41089  tioridazina_-1           0.0  0.692
# 11    42451  tioridazina_-1           0.0  2.700
# 12    48552  tioridazina_-1           0.0  0.670
# 13    49588  tioridazina_-1           0.0  0.420
# 14    65869  tioridazina_-1           0.0  0.399
# 15    74396  tioridazina_-1           0.0  1.070
# 16    80137  tioridazina_-1           0.0  0.400
# 17    80843  tioridazina_-1           0.0  0.670
# 18    82352  tioridazina_-1           0.0  0.230
# 19    87771  tioridazina_-1           0.0  0.660
# 20    91281  tioridazina_-1           0.0  2.650
# 21    96280  tioridazina_-1           0.0  0.690
# 22    96553  tioridazina_-1           0.0  0.680
# 23   103009  tioridazina_-1           0.0  0.800
# 24   104167  tioridazina_-1           0.0  0.290
# 25   112541  tioridazina_-1           0.0  0.400
# 26   113445  tioridazina_-1           0.0  0.480
# 27   119434  tioridazina_-1           0.0  0.640
# 28   120704  tioridazina_-1           0.0  0.648
# 29   125485  tioridazina_-1           0.0  2.288
# 30   125626  tioridazina_-1           0.0  0.394
# 31   126948  tioridazina_-1           0.0  0.450
# 32   130945  tioridazina_-1           0.0  0.300
# 33   133431  tioridazina_-1           0.0  0.674
# 34   137070  tioridazina_-1           0.0  0.420
# 35   141384  tioridazina_-1           0.0  0.350
# 36   142532  tioridazina_-1           0.0  0.660
# 37   147738  tioridazina_-1           0.0  0.470
# 38   154283  tioridazina_-1           0.0  0.390
# 39   155280  tioridazina_-1           0.0  0.480
# 40   160190  tioridazina_-1           0.0  0.650
# 41   163316  tioridazina_-1           0.0  0.701
# 42   174868  tioridazina_-1           0.0  0.330
# 43   178051  tioridazina_-1           0.0  0.320
# 44   184302  tioridazina_-1           0.0  0.640
# 45   193297  tioridazina_-1           0.0  0.730
# 46   193582  tioridazina_-1           0.0  0.420
# 47   200465  tioridazina_-1           0.0  0.940
# 48   203942  tioridazina_-1           0.0  0.670
# 49   204511  tioridazina_-1           0.0  0.600

# %%
results_grouped=results_df.groupby(['cluster'], as_index=False)['price'].mean()
results_grouped=results_grouped.rename(columns = {'price':'mean'})
results_grouped['count']=results_df.groupby(['cluster'], as_index=False)['price'].count().transform('price')
results_grouped['max']=results_df.groupby(['cluster'], as_index=False)['price'].max().transform('price')
results_grouped['min']=results_df.groupby(['cluster'], as_index=False)['price'].min().transform('price')
results_grouped['median']=results_df.groupby(['cluster'], as_index=False)['price'].median().transform('price')
results_grouped['std']=results_df.groupby(['cluster'])['price'].std().reset_index().transform('price')
results_grouped['var']=results_df.groupby(['cluster'])['price'].var().reset_index().transform('price')
results_grouped['quantile_1']=results_df.groupby(['cluster'])['price'].quantile(q=0.25).reset_index().transform('price')
results_grouped['quantile_3']=results_df.groupby(['cluster'])['price'].quantile(q=0.75).reset_index().transform('price')

results_grouped.head(50)
#'avg', 'quartil_1', 'median', 'quartil_3', 'std', 'var', 'max', 'min'
# Out:
#            cluster        mean  count       max      min     median  \
# 0               -1    0.000000  52056      0.00    0.000    0.00000
# 1          a100_-1   46.885645     62     97.00   20.500   49.11000
# 2            a1_-1   28.665309     81     95.00    7.800   30.00000
# 3          a250_-1   63.258889     36     81.00   37.430   65.89000
# 4             a2_0   34.049750     40    102.81    7.800   33.82500
# 5             a2_1   32.900345     87     95.00    8.190   33.40000
# 6            a3_-1   37.400000      8     59.30   31.740   33.85000
# 7             a3_0   33.729577     71    151.22    0.400   34.00000
# 8             a3_1   35.828496    133    120.00    8.190   33.40000
# 9           a50_-1   35.490938     32    195.50    4.200   18.85000
# 10          aas_-1    2.020022    115     34.50    0.010    0.02500
# 11       abacate_0   16.771351     37     62.00    1.110    4.99000
# 12       abacate_1    6.992203     59     95.00    0.400    4.20000
# 13      abacaxi_-1    4.763662     71      7.50    2.700    4.50000
# 14       abacaxi_0  141.653728    228  10780.00    1.300    4.57000
# 15       abacaxi_1    4.177097     31      6.00    1.300    4.29000
# 16       abacaxi_2    4.755772    123     30.42    1.900    4.38000
# 17     abafador_-1   22.485254     59    320.00    0.650   12.00000
# 18    abaixador_-1    3.054792     72     12.66    0.025    2.69000
# 19     abaixador_0    3.516479     71     48.90    2.100    2.77000
# 20     abaixador_1    3.703966     58     25.00    1.900    2.78500
# 21     abaixador_2    6.777268    661    945.00    0.020    2.96000
# 22     abalador_-1  644.324571     35   1150.00  450.000  590.00000
# 23          abd_-1   22.831545     42    540.00    0.110    0.18450
# 24       abobora_0    2.443425     73      5.00    1.190    2.30000
# 25       abobora_1  158.680833     48   3190.00    1.300    2.49500
# 26       abobora_2   25.822241    116   1350.00    0.170    2.50000
# 27       abobora_3    4.295975    159    149.00    0.800    2.20000
# 28       abobora_4    2.363824     34      4.90    1.100    2.22500
# 29        abobra_0    3.250484     62      8.15    0.800    3.18000
# 30        abobra_1   12.269865    148   1350.00    0.300    3.19000
# 31      abowath_-1   17.411606    155    238.00    0.190    0.92000
# 32  abracadeira_-1    5.421616     99     89.00    0.020    1.40000
# 33   abracadeira_0   10.401883    195    169.30    0.030    2.30000
# 34   abracadeira_1    2.654773     44     15.80    0.170    1.20000
# 35  abracadeira_10    7.876980    100    101.00    0.060    2.53565
# 36  abracadeira_11    3.174103     39     30.00    0.070    0.27000
# 47   46.553113    2167.192348     3.60000    15.27000
# 48   24.300902     590.533842     0.39000     2.70000
# 49   33.173515    1100.482130     1.20000     3.04750

# %%
results_grouped.to_csv("../dados/precificacao/train_groups_infos.csv", index=False)

# %%
results_df.to_csv("../dados/precificacao/train_item_groups.csv", index=False)

# %%
results_grouped[results_grouped['cluster'].str.contains('arroz')].head(50)
# Out:
#       cluster        mean  count       max   min  median          std  \
# 924  arroz_-1   10.779787     47     18.00  3.20   12.40     3.982711
# 925   arroz_0   11.401538    117     95.00  2.05   11.29     8.334750
# 926   arroz_1   13.443860     57    101.70  3.25   11.80    12.089579
# 927   arroz_2   14.864727     55     71.40  2.60   12.65    12.899615
# 928   arroz_3   16.297808     73    100.10  1.89   12.16    20.085490
# 929   arroz_4   22.085000     54    180.00  2.55   12.62    30.238378
# 930   arroz_5  310.235517     87  26000.00  1.65   12.00  2786.259986
# 931   arroz_6  213.207726    321  34091.75  1.69   11.90  2496.704778
#
#               var  quantile_1  quantile_3
# 924  1.586198e+01       8.340     12.9900
# 925  6.946805e+01      10.150     12.4600
# 926  1.461579e+02      10.800     13.3100
# 927  1.664001e+02      11.045     13.6000
# 928  4.034269e+02      10.240     13.2400
# 929  9.143595e+02      10.260     14.6875
# 930  7.763245e+06      11.020     13.4550
# 931  6.233535e+06       9.650     13.8000

# %%
results_grouped = pd.read_csv("../dados/precificacao/train_groups_infos.csv")
results_grouped.head()
# Out:
#    cluster       mean  count     max    min  median        std         var  \
# 0       -1   0.000000  52056    0.00   0.00   0.000   0.000000    0.000000
# 1  a100_-1  46.885645     62   97.00  20.50  49.110  15.102414  228.082910
# 2    a1_-1  28.665309     81   95.00   7.80  30.000  18.866133  355.930968
# 3  a250_-1  63.258889     36   81.00  37.43  65.890  13.929107  194.020033
# 4     a2_0  34.049750     40  102.81   7.80  33.825  19.689069  387.659438
#
#    quantile_1  quantile_3
# 0      0.0000      0.0000
# 1     33.5225     56.0000
# 2     10.3500     38.7500
# 3     49.5000     73.8675
# 4     16.8950     40.7950

# %%
results_grouped['dsc_unidade_medida'] = 'Unidade'
results_grouped.head()
# Out:
#    cluster       mean  count     max    min  median        std         var  \
# 0       -1   0.000000  52056    0.00   0.00   0.000   0.000000    0.000000
# 1  a100_-1  46.885645     62   97.00  20.50  49.110  15.102414  228.082910
# 2    a1_-1  28.665309     81   95.00   7.80  30.000  18.866133  355.930968
# 3  a250_-1  63.258889     36   81.00  37.43  65.890  13.929107  194.020033
# 4     a2_0  34.049750     40  102.81   7.80  33.825  19.689069  387.659438
#
#    quantile_1  quantile_3 dsc_unidade_medida
# 0      0.0000      0.0000            Unidade
# 1     33.5225     56.0000            Unidade
# 2     10.3500     38.7500            Unidade
# 3     49.5000     73.8675            Unidade
# 4     16.8950     40.7950            Unidade

# %%
results_grouped.to_csv("../dados/precificacao/train_groups_infos_un.csv", index=False)

# %%
results_grouped = pd.read_csv("../dados/precificacao/train_groups_infos_un.csv")
results_grouped = results_grouped[(results_grouped['cluster']=='a100_-1') & (results_grouped['dsc_unidade_medida'] == 'Unidade')] 
results_grouped['mean'].values[0]
# Out:
# 46.88564516129034
